# %% [markdown]
# ライブラリの呼び出し

# %%
import sys
import os

# 現在の作業ディレクトリを基にプロジェクトのルートディレクトリを設定
project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
sys.path.append(project_root)
project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..','..','..','..'))
sys.path.append(project_root)
print(project_root)
# Out:
# c:\Users\keisu\Desktop\研究元ファイル\abnormal\research_abnormal

# %%
#必要ライブラリのインストール
from src import data
from functions import model_basic
from custom_Class import custom_earlystopping
import config

# %%
#モジュールの再リロード
import importlib
import src
import functions.model_basic
import functions.model_function
import custom_Class.custom_earlystopping

importlib.reload(data)
importlib.reload(custom_Class.custom_earlystopping)
importlib.reload(functions.model_basic)
importlib.reload(functions.model_function)
# Out:
# <module 'functions.model_function' from 'c:\\Users\\keisu\\Desktop\\研究元ファイル\\abnormal\\research_abnormal\\develop\\search\\search_skip\\functions\\model_function.py'>

# %% [markdown]
# データの読み込み

# %%
#データの読み込み及び加工、コラムリストの取得
data_ex, data_original = data.data_complete()
# Out:
# キャッシュファイルからデータを読み込みます

# %% [markdown]
# ハイパーパラメータの設定

# %%
#ハイパーパラメータの設定

#最大エポック数
max_epochs = 100000

#ノード数
units = 11

# シード値の準備
seeds = [50,51,52,53]


# 学習バッチサイズ
batch_size=64


# 学習条件のパラメータ
threshold_avg = 0.0010
threshold_max = 0.0020

# 何期間連続して予測を行うか
num = 3

#　初期化回数
num_retry = 4

#　詳細な出力
detail_log = True

# ログのカウンター
log_counter = 1000

#学習率
learning_rate = 1e-3

#トレーニング開始日
train_start = "2016/6/01 00:00:00"

#テスト開始日
test_start = "2018/6/01 00:00:00"

# early stoppingの設定
early_stopping_params = {
        "monitor" : "loss",
        'restore_best_weights' : True,
        "detail_log" : detail_log,
        "mode" : "min",
        "threshold_avg" : threshold_avg,  # 平均再構成誤差の閾値
        "threshold_max" : threshold_max, 
        "log_counter" : log_counter # 最大再構成誤差の閾値  
    }



params = {"max_epochs":max_epochs, "unit":units, "seeds":seeds, "units":units,  
           "batch_size":batch_size,"num":num, "train_start" : train_start, "test_start" : test_start,
    "num_retry": num_retry, "learning_rate":learning_rate, "early_stopping_params":early_stopping_params}

# %%
#実験の実行及び結果の格納
abnormal_scores, thresholds = model_basic.result(data_ex , params)
# Out:
# =====================================================================================
# 1回目の期間のモデル
# 該当期間の確認
# はじまり(train)2016/6/01 00:00:00
# 終わり(train)2018/6/01 00:00:00
# はじまり(test)2018/6/01 00:00:00
# 終わり(test)2018/7/01 00:00:00
# 1回目の期間のモデル作成開始
# 1回目の期間のトレーニングデータ数:17161
#
# ===== unit2=10 の探索開始 =====
# unit2=10 に対するunit13探索開始点: 22
# ----------------------------------------------------------------------
# [unit10探索] unit13=22, unit2=10
# 学習期間: 1
# 閾値を下回りませんでした
# 閾値を下回りませんでした
# 閾値を下回りませんでした
# 閾値を下回りませんでした
# 全ての初期値で閾値を下回るモデルは見つかりませんでした (units_1_3=22, units_2=10)
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------
# [unit10探索] unit13=44, unit2=10
# 学習期間: 1
# ✅ 有効なモデルが見つかったので並列処理を中断します
# 🎉 最良モデル更新: unit13=44, unit2=10, 合計=98
# [探索の開始] unit13=33, unit2=10
# 学習期間: 1
# ✅ 有効なモデルが見つかったので並列処理を中断します
# 🎉 最良モデル更新: unit13=33, unit2=10, 合計=76
# ------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# [再帰探索] unit13=27, unit2=10
# 学習期間: 1
# ✅ 有効なモデルが見つかったので並列処理を中断します
# ✅ 閾値を下回りました: unit13=27
# ----------------------------------------------------------------------------------------------------------------
# [再帰探索] unit13=24, unit2=10
# 学習期間: 1
# ✅ 有効なモデルが見つかったので並列処理を中断します
# ✅ 閾値を下回りました: unit13=24
# ----------------------------------------------------------------------------------------------------------------
# [再帰探索] unit13=23, unit2=10
# 学習期間: 1
# 閾値を下回りませんでした
# 閾値を下回りませんでした
# 閾値を下回りませんでした
# 閾値を下回りませんでした
# 全ての初期値で閾値を下回るモデルは見つかりませんでした (units_1_3=23, units_2=10)
# ----------------------------------------------------------------------------------------------------------------
# ===========================================================================
# ✅ unit2=10 に対して決定された unit13=24
#
# ===== unit2=9 の探索開始 =====
# unit2=9 に対するunit13探索開始点: 24
# [探索の開始] unit13=24, unit2=9
# 学習期間: 1
# 閾値を下回りませんでした
# 閾値を下回りませんでした
# 閾値を下回りませんでした
# 閾値を下回りませんでした
# 全ての初期値で閾値を下回るモデルは見つかりませんでした (units_1_3=24, units_2=9)
# ----------------------------------------------------------------------------------------------------------------
# unit2=9 に対するunit13=24 でも閾値を下回らなかったので以降の探索を完全に終了します
# 探索を終了します
#
# ===== 最適構成の出力 =====
# 最適ノード数: unit13=24, unit2=10
# 合計ノード数: 58
# 1回目の期間のモデル作成終了
# 537/537 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 最も再構成誤差が大きかったインデックス番号：1489
# 学習データの中に外れ値が発見されたので以降ではモデルの学習を行いません
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 1期間での結果の概要
# トレーニングデータに対する再構成誤差の最大値かつ閾値
# 0.0019911243709606484
# トレーニングデータに対する再構成誤差:0.0005766563409714343
# トレーニングデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.000353
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.000552
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.000254
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.000334
# processor_unit_units_status_cpu_board_cpu_core_temp    0.000570
# processor_unit_units_status_cpu_board_gpu_core_temp    0.000384
# processor_unit_units_status_cpu_board_cpu_core_vol     0.000182
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.000560
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.000365
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.000165
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.001226
# dtype: float64
# テストデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.000588
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.000482
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.002009
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.000527
# processor_unit_units_status_cpu_board_cpu_core_temp    0.000959
# processor_unit_units_status_cpu_board_gpu_core_temp    0.000668
# processor_unit_units_status_cpu_board_cpu_core_vol     0.000547
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.000504
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.000368
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.000117
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.000914
# dtype: float64
# 閾値データの各特徴量ごとの再構成誤差
# processor_unit_units_status_cpu_board_cpu_fan          0.000950
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.000116
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.000461
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.000113
# processor_unit_units_status_cpu_board_cpu_core_temp    0.000514
# processor_unit_units_status_cpu_board_gpu_core_temp    0.000784
# processor_unit_units_status_cpu_board_cpu_core_vol     0.000748
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.002937
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.000878
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.000565
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.005596
# Name: 1489, dtype: float64
# trainの日付の最大値:2018/6/01 00:00:00
# testの日付の最大値:2018/7/01 00:00:00
# 異常値と閾値の保存
# =====================================================================================
# 2回目の期間のモデル
# 該当期間の確認
# はじまり(train)2016/7/01 00:00:00
# 終わり(train)2018/7/01 00:00:00
# はじまり(test)2018/7/01 00:00:00
# 終わり(test)2018/8/01 00:00:00
# 2回目の期間のモデル作成開始
# 2回目の期間のトレーニングデータ数:17141
# 2回目の期間においてはすでにあるモデルを使用します
# 181/536 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step
# c:\Users\keisu\Desktop\研究元ファイル\abnormal\research_abnormal\develop\search\search_skip\functions\model_basic.py:173: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   abnormal_scores = pd.concat([abnormal_scores,abnormal_score_df])
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 0s 542us/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step
# 最も再構成誤差が大きかったインデックス番号：16870
# 次の期間でも学習を続けます
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2期間での結果の概要
# トレーニングデータに対する再構成誤差の最大値かつ閾値
# 0.0019911243709606484
# トレーニングデータに対する再構成誤差:0.0005766563409714343
# トレーニングデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.000353
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.000552
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.000254
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.000334
# processor_unit_units_status_cpu_board_cpu_core_temp    0.000570
# processor_unit_units_status_cpu_board_gpu_core_temp    0.000384
# processor_unit_units_status_cpu_board_cpu_core_vol     0.000182
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.000560
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.000365
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.000165
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.001226
# dtype: float64
# テストデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.000587
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.000451
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.003461
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.000669
# processor_unit_units_status_cpu_board_cpu_core_temp    0.001514
# processor_unit_units_status_cpu_board_gpu_core_temp    0.001093
# processor_unit_units_status_cpu_board_cpu_core_vol     0.000752
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.000491
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.000415
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.000129
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.000834
# dtype: float64
# 閾値データの各特徴量ごとの再構成誤差
# processor_unit_units_status_cpu_board_cpu_fan          0.000950
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.000116
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.000461
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.000113
# processor_unit_units_status_cpu_board_cpu_core_temp    0.000514
# processor_unit_units_status_cpu_board_gpu_core_temp    0.000784
# processor_unit_units_status_cpu_board_cpu_core_vol     0.000748
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.002937
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.000878
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.000565
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.005596
# Name: 1489, dtype: float64
# trainの日付の最大値:2018/7/01 00:00:00
# testの日付の最大値:2018/8/01 00:00:00
# 異常値と閾値の保存
# =====================================================================================
# 3回目の期間のモデル
# 該当期間の確認
# はじまり(train)2016/8/01 00:00:00
# 終わり(train)2018/8/01 00:00:00
# はじまり(test)2018/8/01 00:00:00
# 終わり(test)2018/9/01 00:00:00
# 3回目の期間のモデル作成開始
# 3回目の期間のトレーニングデータ数:17129
# 3回目の期間においてはすでにあるモデルを使用します
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 0s 533us/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step
# 最も再構成誤差が大きかったインデックス番号：17111
# 次の期間でも学習を続けます
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 3期間での結果の概要
# トレーニングデータに対する再構成誤差の最大値かつ閾値
# 0.0019911243709606484
# トレーニングデータに対する再構成誤差:0.0005766563409714343
# トレーニングデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.000353
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.000552
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.000254
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.000334
# processor_unit_units_status_cpu_board_cpu_core_temp    0.000570
# processor_unit_units_status_cpu_board_gpu_core_temp    0.000384
# processor_unit_units_status_cpu_board_cpu_core_vol     0.000182
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.000560
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.000365
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.000165
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.001226
# dtype: float64
# テストデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.004256
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.002355
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.029326
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.008623
# processor_unit_units_status_cpu_board_cpu_core_temp    0.009916
# processor_unit_units_status_cpu_board_gpu_core_temp    0.008192
# processor_unit_units_status_cpu_board_cpu_core_vol     0.002847
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.000417
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.001228
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.000192
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.002376
# dtype: float64
# 閾値データの各特徴量ごとの再構成誤差
# processor_unit_units_status_cpu_board_cpu_fan          0.000950
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.000116
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.000461
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.000113
# processor_unit_units_status_cpu_board_cpu_core_temp    0.000514
# processor_unit_units_status_cpu_board_gpu_core_temp    0.000784
# processor_unit_units_status_cpu_board_cpu_core_vol     0.000748
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.002937
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.000878
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.000565
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.005596
# Name: 1489, dtype: float64
# trainの日付の最大値:2018/8/01 00:00:00
# testの日付の最大値:2018/9/01 00:00:00
# 異常値と閾値の保存
# data_exの日付の最大値:2019-02-04 23:00:02
# data_exのデータ数:26425
# data_exの最終月に含まれるデータ数:96
# 実行時間: 198513.695032 秒
