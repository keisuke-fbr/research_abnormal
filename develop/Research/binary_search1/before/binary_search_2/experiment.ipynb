# %% [markdown]
# # ライブラリの呼び出し

# %%
import sys
import os

# 現在の作業ディレクトリを基にプロジェクトのルートディレクトリを設定
project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
sys.path.append(project_root)
project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..', '..', '..', '..'))
sys.path.append(project_root)
print(project_root)
# Out:
# c:\Users\keisu\Desktop\研究元ファイル\abnormal\research_abnormal

# %%
# 必要ライブラリのインストール
from src import data
from functions import model_basic
from custom_Class import custom_earlystopping
import config

# %%
# モジュールの再リロード
import importlib
import src
import functions.model_basic
import functions.model_function
import custom_Class.custom_earlystopping

importlib.reload(data)
importlib.reload(custom_Class.custom_earlystopping)
importlib.reload(functions.model_basic)
importlib.reload(functions.model_function)
# Out:
# <module 'functions.model_function' from 'c:\\Users\\keisu\\Desktop\\研究元ファイル\\abnormal\\research_abnormal\\develop\\Research\\binary_search1\\functions\\model_function.py'>

# %% [markdown]
# # データの読み込み

# %%
# データの読み込み及び加工、コラムリストの取得
# data_ex: 正規化済みデータ
# data_original: 正規化前データ（基準値計算用）
data_ex, data_original = data.data_complete()
# Out:
# キャッシュファイルからデータを読み込みます

# %% [markdown]
# # ハイパーパラメータの設定

# %%
# ハイパーパラメータの設定

# オートエンコーダのパラメータ
max_epochs = 100000     # 最大エポック
batch_size = 64          # 学習バッチサイズ
learning_rate = 1e-3     # 学習率
num = 3                  # 期間予測数
unit = 11                # 入力データの特徴数
num_retry = 4            # 初期値振り直し回数
seed_start = 50          # シード値の最初の値

# データに関して
train_start = "2016/6/01 00:00:00"   # トレーニング開始日
test_start = "2018/6/01 00:00:00"    # テスト開始日

# ログに関して
log_counter = 1000       # ログの出力エポック数
detail_log = True        # 詳細ログ出力フラグ

# パラメータをまとめる
params = {
    "max_epochs": max_epochs,
    "batch_size": batch_size,
    "learning_rate": learning_rate,
    "num": num,
    "unit": unit,
    "num_retry": num_retry,
    "seed_start": seed_start,
    "train_start": train_start,
    "test_start": test_start,
    "log_counter": log_counter,
    "detail_log": detail_log
}

# %% [markdown]
# # 実験の実行

# %%
# 実験の実行及び結果の格納
abnormal_scores, thresholds = model_basic.result(data_ex, data_original, params)
# Out:
# =====================================================================================
# 1回目の期間のモデル
# 該当期間の確認
# はじまり(train)2016/6/01 00:00:00
# 終わり(train)2018/6/01 00:00:00
# はじまり(test)2018/6/01 00:00:00
# 終わり(test)2018/7/01 00:00:00
# 1回目の期間のモデル作成開始
# 1回目の期間のトレーニングデータ数:17161
# 特徴量: processor_unit_units_status_cpu_board_cpu_fan, 最大値: 1.00001, 桁数: 1, 基準値: 0.1
# 特徴量: processor_unit_units_status_cpu_board_cpu_bd_fan1, 最大値: 0.9708129197080279, 桁数: 1, 基準値: 0.1
# 特徴量: processor_unit_units_status_cpu_board_cpu_bd_fan2, 最大値: 0.9399923477493378, 桁数: 1, 基準値: 0.1
# 特徴量: processor_unit_units_status_cpu_board_cpu_bd_temp, 最大値: 1.00001, 桁数: 1, 基準値: 0.1
# 特徴量: processor_unit_units_status_cpu_board_cpu_core_temp, 最大値: 1.00001, 桁数: 1, 基準値: 0.1
# 特徴量: processor_unit_units_status_cpu_board_gpu_core_temp, 最大値: 0.9000099999999999, 桁数: 1, 基準値: 0.1
# 特徴量: processor_unit_units_status_cpu_board_cpu_core_vol, 最大値: 0.968670968660969, 桁数: 1, 基準値: 0.1
# 特徴量: processor_unit_units_status_cpu_board_cpu_bd_vbat, 最大値: 1e-05, 桁数: 1, 基準値: 0.1
# 特徴量: processor_unit_units_status_cpu_board_cpu_bd_p3_3v, 最大値: 0.6800100000000068, 桁数: 1, 基準値: 0.1
# 特徴量: processor_unit_units_status_cpu_board_cpu_bd_p5v, 最大値: 1.00001, 桁数: 1, 基準値: 0.1
# 特徴量: processor_unit_units_status_cpu_board_cpu_bd_p12v, 最大値: 1.00001, 桁数: 1, 基準値: 0.1
#
# ===== unit2=10 の探索開始 =====
# unit2=10 に対するunit13探索開始点: 22
# ----------------------------------------------------------------------
# [unit10探索] unit13=22, unit2=10
# 学習期間: 1
# ✅ 有効なモデルが見つかったので並列処理を中断します
# 🎉 最良モデル更新: unit13=22, unit2=10, 合計=54
# [探索の開始] unit13=17, unit2=10
# 学習期間: 1
# ✅ 有効なモデルが見つかったので並列処理を中断します
# 🎉 最良モデル更新: unit13=17, unit2=10, 合計=44
# ------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# [再帰探索] unit13=14, unit2=10
# 学習期間: 1
# ✅ 有効なモデルが見つかったので並列処理を中断します
# ✅ 閾値を下回りました: unit13=14
# ----------------------------------------------------------------------------------------------------------------
# [再帰探索] unit13=13, unit2=10
# 学習期間: 1
# ✅ 有効なモデルが見つかったので並列処理を中断します
# ✅ 閾値を下回りました: unit13=13
# ===========================================================================
# ✅ unit2=10 に対して決定された unit13=13
#
# ===== unit2=9 の探索開始 =====
# unit2=9 に対するunit13探索開始点: 13
# [探索の開始] unit13=13, unit2=9
# 学習期間: 1
# ✅ 有効なモデルが見つかったので並列処理を中断します
# 🎉 最良モデル更新: unit13=13, unit2=9, 合計=35
# ------------------------------------------------------------------------------------------
# ===========================================================================
# ✅ unit2=9 に対して決定された unit13=13
#
# ===== unit2=8 の探索開始 =====
# unit2=8 に対するunit13探索開始点: 13
# [探索の開始] unit13=13, unit2=8
# 学習期間: 1
# ✅ 有効なモデルが見つかったので並列処理を中断します
# 🎉 最良モデル更新: unit13=13, unit2=8, 合計=34
# ------------------------------------------------------------------------------------------
# ===========================================================================
# ✅ unit2=8 に対して決定された unit13=13
#
# ===== unit2=7 の探索開始 =====
# unit2=7 に対するunit13探索開始点: 13
# [探索の開始] unit13=13, unit2=7
# 学習期間: 1
# 閾値を下回りませんでした
# 閾値を下回りませんでした
# 閾値を下回りませんでした
# 閾値を下回りませんでした
# 全ての初期値で閾値を下回るモデルは見つかりませんでした (unit13=13, unit2=7)
# ----------------------------------------------------------------------------------------------------------------
# unit2=7 に対するunit13=13 でも閾値を下回らなかったので以降の探索を完全に終了します
# 探索を終了します
#
# ===== 最適構成の出力 =====
# 最適ノード数: unit13=13, unit2=8
# 合計ノード数: 34
# 1回目の期間のモデル作成終了
# 537/537 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 185us/step
# 最も再構成誤差が大きかったインデックス番号：6626
# 学習データの中に外れ値が発見されたので以降ではモデルの学習を行いません
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 1期間での結果の概要
# トレーニングデータに対する再構成誤差の最大値かつ閾値
# 0.05434026743253428
# トレーニングデータに対する再構成誤差:0.016372359224637336
# トレーニングデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.020642
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.006618
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.017349
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.018075
# processor_unit_units_status_cpu_board_cpu_core_temp    0.013859
# processor_unit_units_status_cpu_board_gpu_core_temp    0.015323
# processor_unit_units_status_cpu_board_cpu_core_vol     0.008008
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.015399
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.005417
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.006731
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.010150
# dtype: float64
# テストデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.034009
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.014003
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.076137
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.023359
# processor_unit_units_status_cpu_board_cpu_core_temp    0.011045
# processor_unit_units_status_cpu_board_gpu_core_temp    0.016510
# processor_unit_units_status_cpu_board_cpu_core_vol     0.009010
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.013615
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.006421
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.005866
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.004800
# dtype: float64
# 閾値データの各特徴量ごとの再構成誤差
# processor_unit_units_status_cpu_board_cpu_fan          0.081597
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.024692
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.036262
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.068302
# processor_unit_units_status_cpu_board_cpu_core_temp    0.099137
# processor_unit_units_status_cpu_board_gpu_core_temp    0.054248
# processor_unit_units_status_cpu_board_cpu_core_vol     0.016297
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.031299
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.018905
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.001976
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.069686
# Name: 6626, dtype: float64
# trainの日付の最大値:2018/6/01 00:00:00
# testの日付の最大値:2018/7/01 00:00:00
# 異常値と閾値の保存
# =====================================================================================
# 2回目の期間のモデル
# 該当期間の確認
# はじまり(train)2016/7/01 00:00:00
# 終わり(train)2018/7/01 00:00:00
# はじまり(test)2018/7/01 00:00:00
# 終わり(test)2018/8/01 00:00:00
# 2回目の期間のモデル作成開始
# 2回目の期間のトレーニングデータ数:17141
# 2回目の期間においてはすでにあるモデルを使用します
# 217/536 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step
# c:\Users\keisu\Desktop\研究元ファイル\abnormal\research_abnormal\develop\Research\binary_search1\functions\model_basic.py:350: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   abnormal_scores = pd.concat([abnormal_scores, abnormal_score_df], ignore_index=True)
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 0s 510us/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step
# 次の期間でも学習を続けます
# trainの日付の最大値:2018/7/01 00:00:00
# testの日付の最大値:2018/8/01 00:00:00
# 異常値と閾値の保存
# =====================================================================================
# 3回目の期間のモデル
# 該当期間の確認
# はじまり(train)2016/8/01 00:00:00
# 終わり(train)2018/8/01 00:00:00
# はじまり(test)2018/8/01 00:00:00
# 終わり(test)2018/9/01 00:00:00
# 3回目の期間のモデル作成開始
# 3回目の期間のトレーニングデータ数:17129
# 3回目の期間においてはすでにあるモデルを使用します
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 0s 524us/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step
# 次の期間でも学習を続けます
# trainの日付の最大値:2018/8/01 00:00:00
# testの日付の最大値:2018/9/01 00:00:00
# 異常値と閾値の保存
# data_exの日付の最大値:2019-02-04 23:00:02
# data_exのデータ数:26425
# data_exの最終月に含まれるデータ数:96
# 実行時間: 70044.663462 秒

# %% [markdown]
# # 結果の確認

# %%
# 異常スコアの確認
print("異常スコア:")
print(abnormal_scores.head(10))
print(f"\n異常スコアのデータ数: {len(abnormal_scores)}")
# Out:
# 異常スコア:
#      measurement_date  anomaly_score
# 0 2018-06-01 00:00:03       0.021909
# 1 2018-06-01 01:00:02       0.020305
# 2 2018-06-01 02:00:02       0.019018
# 3 2018-06-01 03:00:02       0.021598
# 4 2018-06-01 04:00:02       0.023045
# 5 2018-06-01 05:00:02       0.022137
# 6 2018-06-01 06:00:02       0.022297
# 7 2018-06-01 07:00:02       0.019118
# 8 2018-06-01 08:00:02       0.020442
# 9 2018-06-01 09:00:02       0.022569
#
# 異常スコアのデータ数: 2037

# %%
# 閾値の確認
print("閾値:")
print(thresholds)
# Out:
# 閾値:
#            test_start            test_end  threshold_data
# 0  2018/6/01 00:00:00  2018/7/01 00:00:00         0.05434

# %%
# 出力ファイルの確認
import os

def list_files(directory):
    """ディレクトリ内のファイルを再帰的にリスト"""
    for root, dirs, files in os.walk(directory):
        level = root.replace(directory, '').count(os.sep)
        indent = ' ' * 2 * level
        print(f"{indent}{os.path.basename(root)}/")
        subindent = ' ' * 2 * (level + 1)
        for file in files:
            print(f"{subindent}{file}")

print("出力ファイル一覧:")
if os.path.exists("data"):
    list_files("data")
else:
    print("dataディレクトリが存在しません")
# Out:
# 出力ファイル一覧:
# data/
#   anomaly_score/
#     combined_anomaly_scores.csv
#     anomaly_scores_per_period/
#       anomaly_scores_2018-06-01.csv
#       anomaly_scores_2018-07-01.csv
#       anomaly_scores_2018-08-01.csv
#   errors/
#     errors_average_per_features/
#       errors_average_per_features_period1.csv
#     errors_max_per_features/
#       errors_max_per_features_period1.csv
#     errors_per_data/
#       errors_per_data.csv
#   learning_scores/
#     learning_scores_seed50/
#       learning_scores_seed50_period1/
#         learning_scores_seed50_period1_unit13_13_unit2_10.csv
#         learning_scores_seed50_period1_unit13_13_unit2_7.csv
#         learning_scores_seed50_period1_unit13_13_unit2_8.csv
#         learning_scores_seed50_period1_unit13_13_unit2_9.csv
#         learning_scores_seed50_period1_unit13_14_unit2_10.csv
#         learning_scores_seed50_period1_unit13_17_unit2_10.csv
#         learning_scores_seed50_period1_unit13_22_unit2_10.csv
#       learning_scores_seed50_period2/
#       learning_scores_seed50_period3/
#     learning_scores_seed51/
#       learning_scores_seed51_period1/
#         learning_scores_seed51_period1_unit13_13_unit2_10.csv
#         learning_scores_seed51_period1_unit13_13_unit2_7.csv
#         learning_scores_seed51_period1_unit13_13_unit2_8.csv
#         learning_scores_seed51_period1_unit13_13_unit2_9.csv
#         learning_scores_seed51_period1_unit13_14_unit2_10.csv
#         learning_scores_seed51_period1_unit13_17_unit2_10.csv
#         learning_scores_seed51_period1_unit13_22_unit2_10.csv
#       learning_scores_seed51_period2/
#       learning_scores_seed51_period3/
#     learning_scores_seed52/
#       learning_scores_seed52_period1/
#         learning_scores_seed52_period1_unit13_13_unit2_10.csv
#         learning_scores_seed52_period1_unit13_13_unit2_7.csv
#         learning_scores_seed52_period1_unit13_13_unit2_8.csv
#         learning_scores_seed52_period1_unit13_13_unit2_9.csv
#         learning_scores_seed52_period1_unit13_14_unit2_10.csv
#         learning_scores_seed52_period1_unit13_17_unit2_10.csv
#         learning_scores_seed52_period1_unit13_22_unit2_10.csv
#       learning_scores_seed52_period2/
#       learning_scores_seed52_period3/
#     learning_scores_seed53/
#       learning_scores_seed53_period1/
#         learning_scores_seed53_period1_unit13_13_unit2_10.csv
#         learning_scores_seed53_period1_unit13_13_unit2_7.csv
#         learning_scores_seed53_period1_unit13_13_unit2_8.csv
#         learning_scores_seed53_period1_unit13_13_unit2_9.csv
#         learning_scores_seed53_period1_unit13_14_unit2_10.csv
#         learning_scores_seed53_period1_unit13_17_unit2_10.csv
#         learning_scores_seed53_period1_unit13_22_unit2_10.csv
#       learning_scores_seed53_period2/
#       learning_scores_seed53_period3/
#   threshold/
#     combined_threshold_scores.csv
#     threshold_scores_per_period/
#       threshold_scores_2018-06-01.csv
