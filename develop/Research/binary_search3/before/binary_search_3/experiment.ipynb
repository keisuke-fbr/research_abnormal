# %% [markdown]
# # ライブラリの呼び出し

# %%
import sys
import os

# 現在の作業ディレクトリを基にプロジェクトのルートディレクトリを設定
project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
sys.path.append(project_root)
project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..', '..', '..', '..'))
sys.path.append(project_root)
print(project_root)
# Out:
# c:\Users\keisu\Desktop\研究元ファイル\abnormal\research_abnormal

# %%
# 必要ライブラリのインストール
from src import data
from functions import model_basic
from custom_Class import custom_earlystopping
import config

# %%
# モジュールの再リロード
import importlib
import src
import functions.model_basic
import functions.model_function
import custom_Class.custom_earlystopping

importlib.reload(data)
importlib.reload(custom_Class.custom_earlystopping)
importlib.reload(functions.model_basic)
importlib.reload(functions.model_function)
# Out:
# <module 'functions.model_function' from 'c:\\Users\\keisu\\Desktop\\研究元ファイル\\abnormal\\research_abnormal\\develop\\Research\\binary_search3\\functions\\model_function.py'>

# %% [markdown]
# # データの読み込み

# %%
# データの読み込み及び加工、コラムリストの取得
# data_ex: 正規化済みデータ
# data_original: 正規化前データ（基準値計算用）
data_ex, data_original = data.data_complete()
# Out:
# キャッシュファイルからデータを読み込みます

# %%
data_ex.head()
# Out:
#    processor_unit_units_status_cpu_board_cpu_fan  \
# 0                                       0.735761
# 1                                       0.766849
# 2                                       0.797937
# 3                                       0.834207
# 4                                       0.735761
#
#    processor_unit_units_status_cpu_board_cpu_bd_fan1  \
# 0                                           0.562054
# 1                                           0.649645
# 2                                           0.562054
# 3                                           0.562054
# 4                                           0.474463
#
#    processor_unit_units_status_cpu_board_cpu_bd_fan2  \
# 0                                           0.902923
# 1                                           0.913514
# 2                                           0.928518
# 3                                           0.924988
# 4                                           0.924988
#
#    processor_unit_units_status_cpu_board_cpu_bd_temp  \
# 0                                           0.740751
# 1                                           0.777788
# 2                                           0.814825
# 3                                           0.814825
# 4                                           0.777788
#
#    processor_unit_units_status_cpu_board_cpu_core_temp  \
# 0                                           0.638899
# 1                                           0.666677
# 2                                           0.694454
# 3                                           0.694454
# 4                                           0.666677
#
#    processor_unit_units_status_cpu_board_gpu_core_temp  \
# 0                                           0.633343
# 1                                           0.666677
# 2                                           0.700010
# 3                                           0.700010
# 4                                           0.633343
#
#    processor_unit_units_status_cpu_board_cpu_core_vol  \
# 0                                           0.324796
# 1                                           0.977218
# 2                                           0.868956
# 3                                           0.817674
# 4                                           0.524227
#
#    processor_unit_units_status_cpu_board_cpu_bd_vbat  \
# 0                                           0.393949
# 1                                           0.181828
# 2                                           0.181828
# 3                                           0.181828
# 4                                           0.393949
#
#    processor_unit_units_status_cpu_board_cpu_bd_p3_3v  \
# 0                                            0.68001
# 1                                            0.68001
# 2                                            0.84001
# 3                                            0.68001
# 4                                            0.68001
#
#    processor_unit_units_status_cpu_board_cpu_bd_p5v  \
# 0                                           0.00001
# 1                                           0.00001
# 2                                           0.00001
# 3                                           0.00001
# 4                                           0.80001
#
#    processor_unit_units_status_cpu_board_cpu_bd_p12v    measurement_date
# 0                                           0.073539 2015-12-22 06:15:00
# 1                                           0.000010 2015-12-22 07:00:02
# 2                                           0.073539 2015-12-22 08:00:03
# 3                                           0.073539 2015-12-22 09:00:03
# 4                                           0.073539 2015-12-22 10:00:03

# %%
data_original.head()
# Out:
#        processor_unit_units_status_cpu_board_cpu_fan  \
# 16602                                         5787.0
# 16603                                         5793.0
# 16604                                         5800.0
# 16605                                         5806.0
# 16606                                         5806.0
#
#        processor_unit_units_status_cpu_board_cpu_bd_fan1  \
# 16602                                             4587.0
# 16603                                             4591.0
# 16604                                             4595.0
# 16605                                             4603.0
# 16606                                             4591.0
#
#        processor_unit_units_status_cpu_board_cpu_bd_fan2  \
# 16602                                             4695.0
# 16603                                             4699.0
# 16604                                             4716.0
# 16605                                             4720.0
# 16606                                             4716.0
#
#        processor_unit_units_status_cpu_board_cpu_bd_temp  \
# 16602                                               39.0
# 16603                                               40.0
# 16604                                               41.0
# 16605                                               41.0
# 16606                                               40.0
#
#        processor_unit_units_status_cpu_board_cpu_core_temp  \
# 16602                                               51.0
# 16603                                               56.0
# 16604                                               53.0
# 16605                                               54.0
# 16606                                               54.0
#
#        processor_unit_units_status_cpu_board_gpu_core_temp  \
# 16602                                               48.0
# 16603                                               50.0
# 16604                                               51.0
# 16605                                               50.0
# 16606                                               50.0
#
#        processor_unit_units_status_cpu_board_cpu_core_vol  \
# 16602                                              1.113
# 16603                                              1.078
# 16604                                              1.031
# 16605                                              0.961
# 16606                                              1.020
#
#        processor_unit_units_status_cpu_board_cpu_bd_vbat  \
# 16602                                              3.698
# 16603                                              3.698
# 16604                                              3.698
# 16605                                              3.698
# 16606                                              3.698
#
#        processor_unit_units_status_cpu_board_cpu_bd_p3_3v  \
# 16602                                              3.403
# 16603                                              3.403
# 16604                                              3.420
# 16605                                              3.403
# 16606                                              3.420
#
#        processor_unit_units_status_cpu_board_cpu_bd_p5v  \
# 16602                                              5.13
# 16603                                              5.13
# 16604                                              5.13
# 16605                                              5.13
# 16606                                              5.13
#
#        processor_unit_units_status_cpu_board_cpu_bd_p12v    measurement_date
# 16602                                             12.063 2017-12-01 00:00:03
# 16603                                             12.063 2017-12-01 01:00:02
# 16604                                             12.063 2017-12-01 02:00:02
# 16605                                             12.063 2017-12-01 03:00:02
# 16606                                             12.063 2017-12-01 04:00:02

# %% [markdown]
# # パラメータの設定

# %%
# パラメータの設定

# オートエンコーダのパラメータ
max_epochs = 100000   # 最大エポック
batch_size = 64          # 学習バッチサイズ
learning_rate = 1e-3     # 学習率
num = 3                  # 期間予測数
unit = 11                # 入力データの特徴数
num_retry = 4            # 初期値振り直し回数
seed_start = 50          # シード値の最初の値

# データに関して
train_start = "2016/6/01 00:00:00"   # トレーニング開始日
test_start = "2018/6/01 00:00:00"    # テスト開始日

# ログに関して
log_counter = 1       # ログの出力エポック数
detail_log = True        # 詳細ログ出力フラグ

# テスト動作モード
test_mode = True      # Trueの場合、固定基準値を使用
test_threshold = 0.9    # テストモード時の全特徴共通の基準値

# パラメータをまとめる
params = {
    "max_epochs": max_epochs,
    "batch_size": batch_size,
    "learning_rate": learning_rate,
    "num": num,
    "unit": unit,
    "num_retry": num_retry,
    "seed_start": seed_start,
    "train_start": train_start,
    "test_start": test_start,
    "log_counter": log_counter,
    "detail_log": detail_log,
    "test_mode": test_mode,
    "test_threshold": test_threshold
}

# %% [markdown]
# # 実験の実行

# %%
# 実験の実行及び結果の格納
abnormal_scores, thresholds = model_basic.result(data_ex, data_original, params)
# Out:
# =====================================================================================
# 1回目の期間のモデル
# 該当期間の確認
# はじまり(train)2016/6/01 00:00:00
# 終わり(train)2018/6/01 00:00:00
# はじまり(test)2018/6/01 00:00:00
# 終わり(test)2018/7/01 00:00:00
# 1回目の期間のモデル作成開始
# 1回目の期間のトレーニングデータ数:17161
# [テストモード] 全特徴の基準値を 0.9 に設定
#
# ===== unit2=10 の探索開始 =====
# unit2=10 に対するunit13探索開始点: 22
# ----------------------------------------------------------------------
# [unit10探索] unit13=22, unit2=10, lower=12, upper=None
# 学習期間: 1
# ✅ 有効なモデルが見つかりました (seed=52)
# 🎉 最良モデル更新: unit13=22, unit2=10, 合計=54
# [探索の開始] unit13=17, unit2=10
# 学習期間: 1
# ✅ 有効なモデルが見つかりました (seed=52)
# 🎉 最良モデル更新: unit13=17, unit2=10, 合計=44
# ------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# [再帰探索] unit13=14, unit2=10
# 学習期間: 1
# ✅ 有効なモデルが見つかりました (seed=50)
# ✅ 閾値を下回りました: unit13=14
# ----------------------------------------------------------------------------------------------------------------
# [再帰探索] unit13=13, unit2=10
# 学習期間: 1
# ✅ 有効なモデルが見つかりました (seed=52)
# ✅ 閾値を下回りました: unit13=13
# ----------------------------------------------------------------------------------------------------------------
# [再帰探索] unit13=12, unit2=10
# 学習期間: 1
# ✅ 有効なモデルが見つかりました (seed=53)
# ✅ 閾値を下回りました: unit13=12
# [再帰探索終了] unit13=12 は探索済み → 打ち切り
# ===========================================================================
# ✅ unit2=10 に対して決定された unit13=12
#
# ===== unit2=9 の探索開始 =====
# unit2=9 に対するunit13探索開始点: 12
# [探索の開始] unit13=12, unit2=9
# 学習期間: 1
# ✅ 有効なモデルが見つかりました (seed=52)
# 🎉 最良モデル更新: unit13=12, unit2=9, 合計=33
# ------------------------------------------------------------------------------------------
# [再帰探索終了] unit13=12 は探索済み → 打ち切り
# ===========================================================================
# ✅ unit2=9 に対して決定された unit13=12
#
# ===== unit2=8 の探索開始 =====
# unit2=8 に対するunit13探索開始点: 12
# [探索の開始] unit13=12, unit2=8
# 学習期間: 1
# ✅ 有効なモデルが見つかりました (seed=52)
# 🎉 最良モデル更新: unit13=12, unit2=8, 合計=32
# ------------------------------------------------------------------------------------------
# [再帰探索終了] unit13=12 は探索済み → 打ち切り
# ===========================================================================
# ✅ unit2=8 に対して決定された unit13=12
#
# ===== unit2=7 の探索開始 =====
# unit2=7 に対するunit13探索開始点: 12
# [探索の開始] unit13=12, unit2=7
# 学習期間: 1
# ✅ 有効なモデルが見つかりました (seed=53)
# 🎉 最良モデル更新: unit13=12, unit2=7, 合計=31
# ------------------------------------------------------------------------------------------
# [再帰探索終了] unit13=12 は探索済み → 打ち切り
# ===========================================================================
# ✅ unit2=7 に対して決定された unit13=12
#
# ===== unit2=6 の探索開始 =====
# unit2=6 に対するunit13探索開始点: 12
# [探索の開始] unit13=12, unit2=6
# 学習期間: 1
# ✅ 有効なモデルが見つかりました (seed=50)
# 🎉 最良モデル更新: unit13=12, unit2=6, 合計=30
# ------------------------------------------------------------------------------------------
# [再帰探索終了] unit13=12 は探索済み → 打ち切り
# ===========================================================================
# ✅ unit2=6 に対して決定された unit13=12
#
# ===== unit2=5 の探索開始 =====
# unit2=5 に対するunit13探索開始点: 12
# [探索の開始] unit13=12, unit2=5
# 学習期間: 1
# ✅ 有効なモデルが見つかりました (seed=53)
# 🎉 最良モデル更新: unit13=12, unit2=5, 合計=29
# ------------------------------------------------------------------------------------------
# [再帰探索終了] unit13=12 は探索済み → 打ち切り
# ===========================================================================
# ✅ unit2=5 に対して決定された unit13=12
#
# ===== unit2=4 の探索開始 =====
# unit2=4 に対するunit13探索開始点: 12
# [探索の開始] unit13=12, unit2=4
# 学習期間: 1
# ✅ 有効なモデルが見つかりました (seed=50)
# 🎉 最良モデル更新: unit13=12, unit2=4, 合計=28
# ------------------------------------------------------------------------------------------
# [再帰探索終了] unit13=12 は探索済み → 打ち切り
# ===========================================================================
# ✅ unit2=4 に対して決定された unit13=12
#
# ===== unit2=3 の探索開始 =====
# unit2=3 に対するunit13探索開始点: 12
# [探索の開始] unit13=12, unit2=3
# 学習期間: 1
# ✅ 有効なモデルが見つかりました (seed=50)
# 🎉 最良モデル更新: unit13=12, unit2=3, 合計=27
# ------------------------------------------------------------------------------------------
# [再帰探索終了] unit13=12 は探索済み → 打ち切り
# ===========================================================================
# ✅ unit2=3 に対して決定された unit13=12
#
# ===== unit2=2 の探索開始 =====
# unit2=2 に対するunit13探索開始点: 12
# [探索の開始] unit13=12, unit2=2
# 学習期間: 1
# ✅ 有効なモデルが見つかりました (seed=50)
# 🎉 最良モデル更新: unit13=12, unit2=2, 合計=26
# ------------------------------------------------------------------------------------------
# [再帰探索終了] unit13=12 は探索済み → 打ち切り
# ===========================================================================
# ✅ unit2=2 に対して決定された unit13=12
#
# ===== unit2=1 の探索開始 =====
# unit2=1 に対するunit13探索開始点: 12
# [探索の開始] unit13=12, unit2=1
# 学習期間: 1
# ✅ 有効なモデルが見つかりました (seed=51)
# 🎉 最良モデル更新: unit13=12, unit2=1, 合計=25
# ------------------------------------------------------------------------------------------
# [再帰探索終了] unit13=12 は探索済み → 打ち切り
# ===========================================================================
# ✅ unit2=1 に対して決定された unit13=12
#
# ===== 最適構成の出力 =====
# 最適ノード数: unit13=12, unit2=1
# 合計ノード数: 25
# 重み保存: seedが取得できないため -1 を使用します。
# 重み保存: data\weight\weight_seed-1_period1_unit13_12_unit2_1.csv
# 1回目の期間のモデル作成終了
# 537/537 ━━━━━━━━━━━━━━━━━━━━ 0s 348us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 451us/step
# 最も再構成誤差が大きかったインデックス番号：14133
# 次の期間でも学習を続けます
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 1期間での結果の概要
# トレーニングデータに対する再構成誤差の最大値かつ閾値
# 0.40619976575234445
# トレーニングデータに対する再構成誤差:0.2840570335301104
# トレーニングデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.139701
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.135818
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.031839
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.144030
# processor_unit_units_status_cpu_board_cpu_core_temp    0.115508
# processor_unit_units_status_cpu_board_gpu_core_temp    0.131647
# processor_unit_units_status_cpu_board_cpu_core_vol     0.195939
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.434942
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.267787
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.461008
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.452367
# dtype: float64
# テストデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.125362
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.130875
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.080591
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.108028
# processor_unit_units_status_cpu_board_cpu_core_temp    0.089654
# processor_unit_units_status_cpu_board_gpu_core_temp    0.096976
# processor_unit_units_status_cpu_board_cpu_core_vol     0.201123
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.459296
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.260418
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.481122
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.462135
# dtype: float64
# 閾値データ（最大の再構成誤差）の各特徴量ごとの再構成誤差
# processor_unit_units_status_cpu_board_cpu_fan          0.440094
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.345541
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.060837
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.467301
# processor_unit_units_status_cpu_board_cpu_core_temp    0.338460
# processor_unit_units_status_cpu_board_gpu_core_temp    0.463594
# processor_unit_units_status_cpu_board_cpu_core_vol     0.241394
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.458528
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.483542
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.475892
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.470687
# Name: 14133, dtype: float64
# trainの日付の最大値:2018/6/01 00:00:00
# testの日付の最大値:2018/7/01 00:00:00
# 異常値と閾値の保存
# =====================================================================================
# 2回目の期間のモデル
# 該当期間の確認
# はじまり(train)2016/7/01 00:00:00
# 終わり(train)2018/7/01 00:00:00
# はじまり(test)2018/7/01 00:00:00
# 終わり(test)2018/8/01 00:00:00
# 2回目の期間のモデル作成開始
# 2回目の期間のトレーニングデータ数:17141
# [テストモード] 全特徴の基準値を 0.9 に設定
#
# ===== unit2=10 の探索開始 =====
# unit2=10 に対するunit13探索開始点: 22
# ----------------------------------------------------------------------
# [unit10探索] unit13=22, unit2=10, lower=12, upper=None
# 学習期間: 2
# c:\Users\keisu\Desktop\研究元ファイル\abnormal\research_abnormal\develop\Research\binary_search3\functions\model_basic.py:359: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   abnormal_scores = pd.concat([abnormal_scores, abnormal_score_df], ignore_index=True)
# ✅ 有効なモデルが見つかりました (seed=50)
# 🎉 最良モデル更新: unit13=22, unit2=10, 合計=54
# [探索の開始] unit13=17, unit2=10
# 学習期間: 2
# ✅ 有効なモデルが見つかりました (seed=50)
# 🎉 最良モデル更新: unit13=17, unit2=10, 合計=44
# ------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# [再帰探索] unit13=14, unit2=10
# 学習期間: 2
# ✅ 有効なモデルが見つかりました (seed=51)
# ✅ 閾値を下回りました: unit13=14
# ----------------------------------------------------------------------------------------------------------------
# [再帰探索] unit13=13, unit2=10
# 学習期間: 2
# ✅ 有効なモデルが見つかりました (seed=51)
# ✅ 閾値を下回りました: unit13=13
# ----------------------------------------------------------------------------------------------------------------
# [再帰探索] unit13=12, unit2=10
# 学習期間: 2
# ✅ 有効なモデルが見つかりました (seed=50)
# ✅ 閾値を下回りました: unit13=12
# [再帰探索終了] unit13=12 は探索済み → 打ち切り
# ===========================================================================
# ✅ unit2=10 に対して決定された unit13=12
#
# ===== unit2=9 の探索開始 =====
# unit2=9 に対するunit13探索開始点: 12
# [探索の開始] unit13=12, unit2=9
# 学習期間: 2
# ✅ 有効なモデルが見つかりました (seed=53)
# 🎉 最良モデル更新: unit13=12, unit2=9, 合計=33
# ------------------------------------------------------------------------------------------
# [再帰探索終了] unit13=12 は探索済み → 打ち切り
# ===========================================================================
# ✅ unit2=9 に対して決定された unit13=12
#
# ===== unit2=8 の探索開始 =====
# unit2=8 に対するunit13探索開始点: 12
# [探索の開始] unit13=12, unit2=8
# 学習期間: 2
# ✅ 有効なモデルが見つかりました (seed=52)
# 🎉 最良モデル更新: unit13=12, unit2=8, 合計=32
# ------------------------------------------------------------------------------------------
# [再帰探索終了] unit13=12 は探索済み → 打ち切り
# ===========================================================================
# ✅ unit2=8 に対して決定された unit13=12
#
# ===== unit2=7 の探索開始 =====
# unit2=7 に対するunit13探索開始点: 12
# [探索の開始] unit13=12, unit2=7
# 学習期間: 2
# ✅ 有効なモデルが見つかりました (seed=52)
# 🎉 最良モデル更新: unit13=12, unit2=7, 合計=31
# ------------------------------------------------------------------------------------------
# [再帰探索終了] unit13=12 は探索済み → 打ち切り
# ===========================================================================
# ✅ unit2=7 に対して決定された unit13=12
#
# ===== unit2=6 の探索開始 =====
# unit2=6 に対するunit13探索開始点: 12
# [探索の開始] unit13=12, unit2=6
# 学習期間: 2
# ✅ 有効なモデルが見つかりました (seed=52)
# 🎉 最良モデル更新: unit13=12, unit2=6, 合計=30
# ------------------------------------------------------------------------------------------
# [再帰探索終了] unit13=12 は探索済み → 打ち切り
# ===========================================================================
# ✅ unit2=6 に対して決定された unit13=12
#
# ===== unit2=5 の探索開始 =====
# unit2=5 に対するunit13探索開始点: 12
# [探索の開始] unit13=12, unit2=5
# 学習期間: 2
# ✅ 有効なモデルが見つかりました (seed=51)
# 🎉 最良モデル更新: unit13=12, unit2=5, 合計=29
# ------------------------------------------------------------------------------------------
# [再帰探索終了] unit13=12 は探索済み → 打ち切り
# ===========================================================================
# ✅ unit2=5 に対して決定された unit13=12
#
# ===== unit2=4 の探索開始 =====
# unit2=4 に対するunit13探索開始点: 12
# [探索の開始] unit13=12, unit2=4
# 学習期間: 2
# ✅ 有効なモデルが見つかりました (seed=51)
# 🎉 最良モデル更新: unit13=12, unit2=4, 合計=28
# ------------------------------------------------------------------------------------------
# [再帰探索終了] unit13=12 は探索済み → 打ち切り
# ===========================================================================
# ✅ unit2=4 に対して決定された unit13=12
#
# ===== unit2=3 の探索開始 =====
# unit2=3 に対するunit13探索開始点: 12
# [探索の開始] unit13=12, unit2=3
# 学習期間: 2
# ✅ 有効なモデルが見つかりました (seed=53)
# 🎉 最良モデル更新: unit13=12, unit2=3, 合計=27
# ------------------------------------------------------------------------------------------
# [再帰探索終了] unit13=12 は探索済み → 打ち切り
# ===========================================================================
# ✅ unit2=3 に対して決定された unit13=12
#
# ===== unit2=2 の探索開始 =====
# unit2=2 に対するunit13探索開始点: 12
# [探索の開始] unit13=12, unit2=2
# 学習期間: 2
# ✅ 有効なモデルが見つかりました (seed=50)
# 🎉 最良モデル更新: unit13=12, unit2=2, 合計=26
# ------------------------------------------------------------------------------------------
# [再帰探索終了] unit13=12 は探索済み → 打ち切り
# ===========================================================================
# ✅ unit2=2 に対して決定された unit13=12
#
# ===== unit2=1 の探索開始 =====
# unit2=1 に対するunit13探索開始点: 12
# [探索の開始] unit13=12, unit2=1
# 学習期間: 2
# ✅ 有効なモデルが見つかりました (seed=52)
# 🎉 最良モデル更新: unit13=12, unit2=1, 合計=25
# ------------------------------------------------------------------------------------------
# [再帰探索終了] unit13=12 は探索済み → 打ち切り
# ===========================================================================
# ✅ unit2=1 に対して決定された unit13=12
#
# ===== 最適構成の出力 =====
# 最適ノード数: unit13=12, unit2=1
# 合計ノード数: 25
# 重み保存: seedが取得できないため -1 を使用します。
# 重み保存: data\weight\weight_seed-1_period2_unit13_12_unit2_1.csv
# 2回目の期間のモデル作成終了
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 0s 343us/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step
# 最も再構成誤差が大きかったインデックス番号：13463
# 次の期間でも学習を続けます
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2期間での結果の概要
# トレーニングデータに対する再構成誤差の最大値かつ閾値
# 0.4168811848342067
# トレーニングデータに対する再構成誤差:0.28472829333138877
# トレーニングデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.143772
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.136238
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.038698
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.141389
# processor_unit_units_status_cpu_board_cpu_core_temp    0.111370
# processor_unit_units_status_cpu_board_gpu_core_temp    0.131039
# processor_unit_units_status_cpu_board_cpu_core_vol     0.203461
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.440382
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.251728
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.458467
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.453649
# dtype: float64
# テストデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.100335
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.089168
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.098607
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.129518
# processor_unit_units_status_cpu_board_cpu_core_temp    0.117409
# processor_unit_units_status_cpu_board_gpu_core_temp    0.104759
# processor_unit_units_status_cpu_board_cpu_core_vol     0.205785
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.464041
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.204579
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.472459
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.457979
# dtype: float64
# 閾値データ（最大の再構成誤差）の各特徴量ごとの再構成誤差
# processor_unit_units_status_cpu_board_cpu_fan          0.450415
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.348917
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.083870
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.476408
# processor_unit_units_status_cpu_board_cpu_core_temp    0.354376
# processor_unit_units_status_cpu_board_gpu_core_temp    0.478534
# processor_unit_units_status_cpu_board_cpu_core_vol     0.253470
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.462989
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.521228
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.473130
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.473667
# Name: 13463, dtype: float64
# trainの日付の最大値:2018/7/01 00:00:00
# testの日付の最大値:2018/8/01 00:00:00
# 異常値と閾値の保存
# =====================================================================================
# 3回目の期間のモデル
# 該当期間の確認
# はじまり(train)2016/8/01 00:00:00
# 終わり(train)2018/8/01 00:00:00
# はじまり(test)2018/8/01 00:00:00
# 終わり(test)2018/9/01 00:00:00
# 3回目の期間のモデル作成開始
# 3回目の期間のトレーニングデータ数:17129
# [テストモード] 全特徴の基準値を 0.9 に設定
#
# ===== unit2=10 の探索開始 =====
# unit2=10 に対するunit13探索開始点: 22
# ----------------------------------------------------------------------
# [unit10探索] unit13=22, unit2=10, lower=12, upper=None
# 学習期間: 3
# ✅ 有効なモデルが見つかりました (seed=51)
# 🎉 最良モデル更新: unit13=22, unit2=10, 合計=54
# [探索の開始] unit13=17, unit2=10
# 学習期間: 3
# ✅ 有効なモデルが見つかりました (seed=52)
# 🎉 最良モデル更新: unit13=17, unit2=10, 合計=44
# ------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# [再帰探索] unit13=14, unit2=10
# 学習期間: 3
# ✅ 有効なモデルが見つかりました (seed=50)
# ✅ 閾値を下回りました: unit13=14
# ----------------------------------------------------------------------------------------------------------------
# [再帰探索] unit13=13, unit2=10
# 学習期間: 3
# ✅ 有効なモデルが見つかりました (seed=50)
# ✅ 閾値を下回りました: unit13=13
# ----------------------------------------------------------------------------------------------------------------
# [再帰探索] unit13=12, unit2=10
# 学習期間: 3
# ✅ 有効なモデルが見つかりました (seed=52)
# ✅ 閾値を下回りました: unit13=12
# [再帰探索終了] unit13=12 は探索済み → 打ち切り
# ===========================================================================
# ✅ unit2=10 に対して決定された unit13=12
#
# ===== unit2=9 の探索開始 =====
# unit2=9 に対するunit13探索開始点: 12
# [探索の開始] unit13=12, unit2=9
# 学習期間: 3
# ✅ 有効なモデルが見つかりました (seed=51)
# 🎉 最良モデル更新: unit13=12, unit2=9, 合計=33
# ------------------------------------------------------------------------------------------
# [再帰探索終了] unit13=12 は探索済み → 打ち切り
# ===========================================================================
# ✅ unit2=9 に対して決定された unit13=12
#
# ===== unit2=8 の探索開始 =====
# unit2=8 に対するunit13探索開始点: 12
# [探索の開始] unit13=12, unit2=8
# 学習期間: 3
# ✅ 有効なモデルが見つかりました (seed=53)
# 🎉 最良モデル更新: unit13=12, unit2=8, 合計=32
# ------------------------------------------------------------------------------------------
# [再帰探索終了] unit13=12 は探索済み → 打ち切り
# ===========================================================================
# ✅ unit2=8 に対して決定された unit13=12
#
# ===== unit2=7 の探索開始 =====
# unit2=7 に対するunit13探索開始点: 12
# [探索の開始] unit13=12, unit2=7
# 学習期間: 3
# ✅ 有効なモデルが見つかりました (seed=50)
# 🎉 最良モデル更新: unit13=12, unit2=7, 合計=31
# ------------------------------------------------------------------------------------------
# [再帰探索終了] unit13=12 は探索済み → 打ち切り
# ===========================================================================
# ✅ unit2=7 に対して決定された unit13=12
#
# ===== unit2=6 の探索開始 =====
# unit2=6 に対するunit13探索開始点: 12
# [探索の開始] unit13=12, unit2=6
# 学習期間: 3
# ✅ 有効なモデルが見つかりました (seed=51)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 2
#       1 # 実験の実行及び結果の格納
# ----> 2 abnormal_scores, thresholds = model_basic.result(data_ex, data_original, params)
#
# File c:\Users\keisu\Desktop\研究元ファイル\abnormal\research_abnormal\develop\Research\binary_search3\functions\model_basic.py:285, in result(data_ex, data_original, params)
#     281         thresholds = model_function.calculate_thresholds(
#     282             train_data_original, train_data, config.columns_list
#     283         )
#     284     # 各実験ごとの学習済みモデルが返される
# --> 285     model = model_function.search_optimal_units(
#     286         params, train_data, period_log, thresholds, learning_scores_base_path
#     287     )
#     289     print(str(period_log) + "回目の期間のモデル作成終了")
#     290 else:
#
# File c:\Users\keisu\Desktop\研究元ファイル\abnormal\research_abnormal\develop\Research\binary_search3\functions\model_function.py:797, in search_optimal_units(params, train_data, period_log, thresholds, base_path)
#     794 print(f"[探索の開始] unit13={unit13}, unit2={unit_2}")
#     796 # モデルの学習
# --> 797 model, flag_low_threshold = try_init_point(
#     798     params, train_data, unit13, unit_2, period_log, thresholds, base_path
#     799 )
#     801 if not flag_low_threshold and len(searched_unit13) == 1 and unit_2 != max_unit2:
#     802     # 初回の探索で閾値を下回らなかった場合、探索を終了
#     803     print(f"unit2={unit_2} に対するunit13={unit13} でも閾値を下回らなかったので以降の探索を完全に終了します")
#
# File c:\Users\keisu\Desktop\研究元ファイル\abnormal\research_abnormal\develop\Research\binary_search3\functions\model_function.py:627, in try_init_point(params, train_data, unit13, unit2, period_log, thresholds, base_path)
#     624         print(f"閾値を下回りませんでした (seed={seed})")
#     626 pool.close()
# --> 627 pool.join()
#     629 if success_found:
#     630     return model, True
#
# File c:\Users\keisu\AppData\Local\Programs\Python\Python311\Lib\multiprocessing\pool.py:669, in Pool.join(self)
#     667 self._result_handler.join()
#     668 for p in self._pool:
# --> 669     p.join()
#
# File c:\Users\keisu\AppData\Local\Programs\Python\Python311\Lib\multiprocessing\process.py:149, in BaseProcess.join(self, timeout)
#     147 assert self._parent_pid == os.getpid(), 'can only join a child process'
#     148 assert self._popen is not None, 'can only join a started process'
# --> 149 res = self._popen.wait(timeout)
#     150 if res is not None:
#     151     _children.discard(self)
#
# File c:\Users\keisu\AppData\Local\Programs\Python\Python311\Lib\multiprocessing\popen_spawn_win32.py:112, in Popen.wait(self, timeout)
#     109 else:
#     110     msecs = max(0, int(timeout * 1000 + 0.5))
# --> 112 res = _winapi.WaitForSingleObject(int(self._handle), msecs)
#     113 if res == _winapi.WAIT_OBJECT_0:
#     114     code = _winapi.GetExitCodeProcess(self._handle)
#
# KeyboardInterrupt:

# %% [markdown]
# # 結果の確認

# %%
# 異常スコアの確認
print("異常スコア:")
print(abnormal_scores.head(10))
print(f"\n異常スコアのデータ数: {len(abnormal_scores)}")
# Out:
# 異常スコア:
#      measurement_date  anomaly_score
# 0 2018-06-01 00:00:03       0.021909
# 1 2018-06-01 01:00:02       0.020305
# 2 2018-06-01 02:00:02       0.019018
# 3 2018-06-01 03:00:02       0.021598
# 4 2018-06-01 04:00:02       0.023045
# 5 2018-06-01 05:00:02       0.022137
# 6 2018-06-01 06:00:02       0.022297
# 7 2018-06-01 07:00:02       0.019118
# 8 2018-06-01 08:00:02       0.020442
# 9 2018-06-01 09:00:02       0.022569
#
# 異常スコアのデータ数: 2037

# %%
# 閾値の確認
print("閾値:")
print(thresholds)
# Out:
# 閾値:
#            test_start            test_end  threshold_data
# 0  2018/6/01 00:00:00  2018/7/01 00:00:00         0.05434

# %%
# 出力ファイルの確認
import os

def list_files(directory):
    """ディレクトリ内のファイルを再帰的にリスト"""
    for root, dirs, files in os.walk(directory):
        level = root.replace(directory, '').count(os.sep)
        indent = ' ' * 2 * level
        print(f"{indent}{os.path.basename(root)}/")
        subindent = ' ' * 2 * (level + 1)
        for file in files:
            print(f"{subindent}{file}")

print("出力ファイル一覧:")
if os.path.exists("data"):
    list_files("data")
else:
    print("dataディレクトリが存在しません")
# Out:
# 出力ファイル一覧:
# data/
#   anomaly_score/
#     combined_anomaly_scores.csv
#     anomaly_scores_per_period/
#       anomaly_scores_2018-06-01.csv
#       anomaly_scores_2018-07-01.csv
#       anomaly_scores_2018-08-01.csv
#   errors/
#     errors_average_per_features/
#       errors_average_per_features_period1.csv
#     errors_max_per_features/
#       errors_max_per_features_period1.csv
#     errors_per_data/
#       errors_per_data.csv
#   learning_scores/
#     learning_scores_seed50/
#       learning_scores_seed50_period1/
#         learning_scores_seed50_period1_unit13_13_unit2_10.csv
#         learning_scores_seed50_period1_unit13_13_unit2_7.csv
#         learning_scores_seed50_period1_unit13_13_unit2_8.csv
#         learning_scores_seed50_period1_unit13_13_unit2_9.csv
#         learning_scores_seed50_period1_unit13_14_unit2_10.csv
#         learning_scores_seed50_period1_unit13_17_unit2_10.csv
#         learning_scores_seed50_period1_unit13_22_unit2_10.csv
#       learning_scores_seed50_period2/
#       learning_scores_seed50_period3/
#     learning_scores_seed51/
#       learning_scores_seed51_period1/
#         learning_scores_seed51_period1_unit13_13_unit2_10.csv
#         learning_scores_seed51_period1_unit13_13_unit2_7.csv
#         learning_scores_seed51_period1_unit13_13_unit2_8.csv
#         learning_scores_seed51_period1_unit13_13_unit2_9.csv
#         learning_scores_seed51_period1_unit13_14_unit2_10.csv
#         learning_scores_seed51_period1_unit13_17_unit2_10.csv
#         learning_scores_seed51_period1_unit13_22_unit2_10.csv
#       learning_scores_seed51_period2/
#       learning_scores_seed51_period3/
#     learning_scores_seed52/
#       learning_scores_seed52_period1/
#         learning_scores_seed52_period1_unit13_13_unit2_10.csv
#         learning_scores_seed52_period1_unit13_13_unit2_7.csv
#         learning_scores_seed52_period1_unit13_13_unit2_8.csv
#         learning_scores_seed52_period1_unit13_13_unit2_9.csv
#         learning_scores_seed52_period1_unit13_14_unit2_10.csv
#         learning_scores_seed52_period1_unit13_17_unit2_10.csv
#         learning_scores_seed52_period1_unit13_22_unit2_10.csv
#       learning_scores_seed52_period2/
#       learning_scores_seed52_period3/
#     learning_scores_seed53/
#       learning_scores_seed53_period1/
#         learning_scores_seed53_period1_unit13_13_unit2_10.csv
#         learning_scores_seed53_period1_unit13_13_unit2_7.csv
#         learning_scores_seed53_period1_unit13_13_unit2_8.csv
#         learning_scores_seed53_period1_unit13_13_unit2_9.csv
#         learning_scores_seed53_period1_unit13_14_unit2_10.csv
#         learning_scores_seed53_period1_unit13_17_unit2_10.csv
#         learning_scores_seed53_period1_unit13_22_unit2_10.csv
#       learning_scores_seed53_period2/
#       learning_scores_seed53_period3/
#   threshold/
#     combined_threshold_scores.csv
#     threshold_scores_per_period/
#       threshold_scores_2018-06-01.csv
