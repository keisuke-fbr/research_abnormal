# %% [markdown]
# ライブラリの呼び出し

# %%
import sys
import os

# 現在の作業ディレクトリを基にプロジェクトのルートディレクトリを設定
project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..','..','..'))
sys.path.append(project_root)
print(project_root)
# Out:
# c:\Users\keisu\Desktop\研究元ファイル\abnormal\research_abnormal

# %%
#必要ライブラリのインストール
from src import data
from src.model import model_single_node_fixed_max_point_learning
import config

# %%
#モジュールの再リロード
import importlib
import src
import src.data
import src.model
import src.model.model_single_node_fixed_max_point_learning
import src.model_basic_single_node_fixed_max_point_learning
import custom_class.custom_tensorflow

importlib.reload(src.data)
importlib.reload(custom_class.custom_tensorflow)
importlib.reload(src.model.model_single_node_fixed_max_point_learning)
importlib.reload(src.model_basic_single_node_fixed_max_point_learning)
# Out:
# <module 'src.model_basic_single_node_fixed_max_point_learning' from 'c:\\Users\\keisu\\Desktop\\研究元ファイル\\abnormal\\research_abnormal\\src\\model_basic_single_node_fixed_max_point_learning.py'>

# %% [markdown]
# データの読み込み

# %%
#データの読み込み及び加工、コラムリストの取得
data_ex, data_original = data.data_complete()
# Out:
# キャッシュファイルからデータを読み込みます

# %% [markdown]
# ハイパーパラメータの設定

# %%
#ハイパーパラメータの設定

#最大エポック数
max_epochs = 100000

#ノード数
units = 11

#モデル決定の閾値（再構成誤差のパラメータ）
#この閾値を下回ることで十分な性能を持つモデルとする
#今回は使用しない
error_threshold = 1

# シード値の準備
seeds = [50,51,52,53]

# ユニット数の準備
unit13_1 = 40
unit2_1 = 10
unit13_2 = 30
unit2_2 = 5
unit13_3 = 20
unit2_3 = 2

units = [[unit13_1, unit2_1],[unit13_2, unit2_2],[unit13_3, unit2_3]]

# 学習バッチサイズ
batch_size=64

# 監視するエポック数
patience = 1000

# 学習変化の閾値
min_delta = 1e-10

# 何期間連続して予測を行うか
num = 3

#　初期化回数
num_retry = 4

#　詳細な出力
detail_log = 0

#学習率
learning_rate = 1e-3

#トレーニング開始日
train_start = "2016/6/01 00:00:00"

#テスト開始日
test_start = "2018/6/01 00:00:00"

params = {"max_epochs":max_epochs, "units":units,
	"error_threshold":error_threshold, "seeds":seeds, "units":units, 
	"batch_size":batch_size, "patience":patience, "min_delta": min_delta, "num":num, "train_start" : train_start, "test_start" : test_start,
    "num_retry": num_retry, "detail_log":detail_log, "learning_rate":learning_rate}

# %%
#実験の実行及び結果の格納
abnormal_scores, thresholds = model_single_node_fixed_max_point_learning.result(data_ex , params)
# Out:
# =====================================================================================
# 1回目の期間のモデル
# 該当期間の確認
# はじまり(train)2016/6/01 00:00:00
# 終わり(train)2018/6/01 00:00:00
# はじまり(test)2018/6/01 00:00:00
# 終わり(test)2018/7/01 00:00:00
# 1回目の期間のモデル作成開始
# 1回目の期間のトレーニングデータ数:17161
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=40, units_2=10, 試行回数=1, seed値 = 50
# Stopped at epoch 10129 due to early stopping (max error did not improve).
# モデルは収束しました。訓練は 10129 エポックで停止しました。
# トレーニングデータの再構成誤差（平均）：0.002032885374997036
# トレーニングデータの再構成誤差（最大値）：0.003915903433891765
# モデルの更新: シード値=50
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=40, units_2=10, 試行回数=2, seed値 = 51
# Stopped at epoch 8497 due to early stopping (max error did not improve).
# モデルは収束しました。訓練は 8497 エポックで停止しました。
# トレーニングデータの再構成誤差（平均）：0.002171053750263148
# トレーニングデータの再構成誤差（最大値）：0.005121042837096367
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=40, units_2=10, 試行回数=3, seed値 = 52
# Stopped at epoch 6116 due to early stopping (max error did not improve).
# モデルは収束しました。訓練は 6116 エポックで停止しました。
# トレーニングデータの再構成誤差（平均）：0.005141828207032624
# トレーニングデータの再構成誤差（最大値）：0.011169508093355105
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=40, units_2=10, 試行回数=4, seed値 = 53
# Stopped at epoch 4856 due to early stopping (max error did not improve).
# モデルは収束しました。訓練は 4856 エポックで停止しました。
# トレーニングデータの再構成誤差（平均）：0.005495277993525634
# トレーニングデータの再構成誤差（最大値）：0.011525023524988083
# 結果: units_1_3=40, units_2=10,この時の再構成誤差：0.002032885374997036
# 1回目の期間のモデル作成終了
# 537/537 ━━━━━━━━━━━━━━━━━━━━ 0s 491us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 814us/step
# 最も再構成誤差が大きかったインデックス番号：5034
# 学習データの中に外れ値が発見されたので以降ではモデルの学習を行いません
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 1期間での結果の概要
# トレーニングデータに対する再構成誤差の最大値かつ閾値
# 0.003915903433891765
# トレーニングデータに対する再構成誤差:0.002032885374997036
# トレーニングデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.002580
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.000629
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.002605
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.001976
# processor_unit_units_status_cpu_board_cpu_core_temp    0.001411
# processor_unit_units_status_cpu_board_gpu_core_temp    0.002067
# processor_unit_units_status_cpu_board_cpu_core_vol     0.001408
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.001114
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.001220
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.000843
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.002176
# dtype: float64
# テストデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.001872
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.000790
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.001164
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.002957
# processor_unit_units_status_cpu_board_cpu_core_temp    0.001004
# processor_unit_units_status_cpu_board_gpu_core_temp    0.001658
# processor_unit_units_status_cpu_board_cpu_core_vol     0.002091
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.002950
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.001710
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.003973
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.004986
# dtype: float64
# 閾値データの各特徴量ごとの再構成誤差
# processor_unit_units_status_cpu_board_cpu_fan          0.000655
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.001163
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.008169
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.002799
# processor_unit_units_status_cpu_board_cpu_core_temp    0.004466
# processor_unit_units_status_cpu_board_gpu_core_temp    0.002316
# processor_unit_units_status_cpu_board_cpu_core_vol     0.003729
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.001945
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.002715
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.005015
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.004099
# Name: 5034, dtype: float64
# trainの日付の最大値:2018/6/01 00:00:00
# testの日付の最大値:2018/7/01 00:00:00
# 異常値と閾値の保存
# =====================================================================================
# 2回目の期間のモデル
# 該当期間の確認
# はじまり(train)2016/7/01 00:00:00
# 終わり(train)2018/7/01 00:00:00
# はじまり(test)2018/7/01 00:00:00
# 終わり(test)2018/8/01 00:00:00
# 2回目の期間のモデル作成開始
# 2回目の期間のトレーニングデータ数:17141
# 2回目の期間においてはすでにあるモデルを使用します
# 213/536 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step
# c:\Users\keisu\Desktop\研究元ファイル\abnormal\research_abnormal\src\model\model_single_node_fixed_max_point_learning.py:163: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   abnormal_scores = pd.concat([abnormal_scores,abnormal_score_df])
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 0s 473us/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step
# 最も再構成誤差が大きかったインデックス番号：16874
# 次の期間でも学習を続けます
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2期間での結果の概要
# トレーニングデータに対する再構成誤差の最大値かつ閾値
# 0.003915903433891765
# トレーニングデータに対する再構成誤差:0.002032885374997036
# トレーニングデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.002580
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.000629
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.002605
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.001976
# processor_unit_units_status_cpu_board_cpu_core_temp    0.001411
# processor_unit_units_status_cpu_board_gpu_core_temp    0.002067
# processor_unit_units_status_cpu_board_cpu_core_vol     0.001408
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.001114
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.001220
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.000843
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.002176
# dtype: float64
# テストデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.001403
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.000879
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.001729
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.002559
# processor_unit_units_status_cpu_board_cpu_core_temp    0.001734
# processor_unit_units_status_cpu_board_gpu_core_temp    0.001734
# processor_unit_units_status_cpu_board_cpu_core_vol     0.001937
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.003996
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.001474
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.006064
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.006718
# dtype: float64
# 閾値データの各特徴量ごとの再構成誤差
# processor_unit_units_status_cpu_board_cpu_fan          0.000655
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.001163
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.008169
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.002799
# processor_unit_units_status_cpu_board_cpu_core_temp    0.004466
# processor_unit_units_status_cpu_board_gpu_core_temp    0.002316
# processor_unit_units_status_cpu_board_cpu_core_vol     0.003729
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.001945
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.002715
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.005015
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.004099
# Name: 5034, dtype: float64
# trainの日付の最大値:2018/7/01 00:00:00
# testの日付の最大値:2018/8/01 00:00:00
# 異常値と閾値の保存
# =====================================================================================
# 3回目の期間のモデル
# 該当期間の確認
# はじまり(train)2016/8/01 00:00:00
# 終わり(train)2018/8/01 00:00:00
# はじまり(test)2018/8/01 00:00:00
# 終わり(test)2018/9/01 00:00:00
# 3回目の期間のモデル作成開始
# 3回目の期間のトレーニングデータ数:17129
# 3回目の期間においてはすでにあるモデルを使用します
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 0s 498us/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 48us/step
# 最も再構成誤差が大きかったインデックス番号：16169
# 次の期間でも学習を続けます
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 3期間での結果の概要
# トレーニングデータに対する再構成誤差の最大値かつ閾値
# 0.003915903433891765
# トレーニングデータに対する再構成誤差:0.002032885374997036
# トレーニングデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.002580
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.000629
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.002605
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.001976
# processor_unit_units_status_cpu_board_cpu_core_temp    0.001411
# processor_unit_units_status_cpu_board_gpu_core_temp    0.002067
# processor_unit_units_status_cpu_board_cpu_core_vol     0.001408
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.001114
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.001220
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.000843
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.002176
# dtype: float64
# テストデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.009817
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.001893
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.020635
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.002768
# processor_unit_units_status_cpu_board_cpu_core_temp    0.010192
# processor_unit_units_status_cpu_board_gpu_core_temp    0.003625
# processor_unit_units_status_cpu_board_cpu_core_vol     0.005549
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.019424
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.003514
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.059935
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.040193
# dtype: float64
# 閾値データの各特徴量ごとの再構成誤差
# processor_unit_units_status_cpu_board_cpu_fan          0.000655
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.001163
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.008169
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.002799
# processor_unit_units_status_cpu_board_cpu_core_temp    0.004466
# processor_unit_units_status_cpu_board_gpu_core_temp    0.002316
# processor_unit_units_status_cpu_board_cpu_core_vol     0.003729
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.001945
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.002715
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.005015
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.004099
# Name: 5034, dtype: float64
# trainの日付の最大値:2018/8/01 00:00:00
# testの日付の最大値:2018/9/01 00:00:00
# 異常値と閾値の保存
# data_exの日付の最大値:2019-02-04 23:00:02
# data_exのデータ数:26425
# data_exの最終月に含まれるデータ数:96
