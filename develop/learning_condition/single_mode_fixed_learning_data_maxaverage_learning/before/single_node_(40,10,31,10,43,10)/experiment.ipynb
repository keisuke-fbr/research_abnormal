# %% [markdown]
# ライブラリの呼び出し

# %%
import sys
import os

# 現在の作業ディレクトリを基にプロジェクトのルートディレクトリを設定
project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..','..','..'))
sys.path.append(project_root)
print(project_root)
# Out:
# c:\Users\keisu\Desktop\研究元ファイル\abnormal\research_abnormal

# %%
#必要ライブラリのインストール
from src import data
from src.model import model_single_node_fixed_maxaverage_learning
import config

# %%
#モジュールの再リロード
import importlib
import custom_class.custom_learning_average_stopping_maxdata
import src
import src.data
import src.model
import src.model.model_single_node_fixed_maxaverage_learning
import src.model_basic_single_node_fixed_maxaverage_learning
import custom_class.custom_learning_average_stopping_maxdata

importlib.reload(src.data)
importlib.reload(custom_class.custom_learning_average_stopping_maxdata)
importlib.reload(src.model.model_single_node_fixed_maxaverage_learning)
importlib.reload(src.model_basic_single_node_fixed_maxaverage_learning)
# Out:
# <module 'src.model_basic_single_node_fixed_maxaverage_learning' from 'c:\\Users\\keisu\\Desktop\\研究元ファイル\\abnormal\\research_abnormal\\src\\model_basic_single_node_fixed_maxaverage_learning.py'>

# %% [markdown]
# データの読み込み

# %%
#データの読み込み及び加工、コラムリストの取得
data_ex, data_original = data.data_complete()
# Out:
# キャッシュファイルからデータを読み込みます

# %% [markdown]
# ハイパーパラメータの設定

# %%
#ハイパーパラメータの設定

#最大エポック数
max_epochs = 100000

#ノード数
units = 11

#モデル決定の閾値（再構成誤差のパラメータ）
#この閾値を下回ることで十分な性能を持つモデルとする
#今回は使用しない
error_threshold = 1

# シード値の準備
seeds = [50,51,52,53]

# ユニット数の準備
unit13_1 = 40
unit2_1 = 10
unit13_2 = 30
unit2_2 = 5
unit13_3 = 20
unit2_3 = 2

units = [[unit13_1, unit2_1],[unit13_2, unit2_2],[unit13_3, unit2_3]]

# 学習バッチサイズ
batch_size=64

# 監視するエポック数
patience = 1000

# 学習変化の閾値
min_delta = 1e-10

# 最大データの再構成誤差
#max_error_threshold = 0.0015
max_error_threshold = 0.0020

# 何期間連続して予測を行うか
num = 3

#　初期化回数
num_retry = 4

#　詳細な出力
detail_log = True

#学習率
learning_rate = 1e-3

#トレーニング開始日
train_start = "2016/6/01 00:00:00"

#テスト開始日
test_start = "2018/6/01 00:00:00"



params = {"max_epochs":max_epochs, "units":units,
	"error_threshold":error_threshold, "seeds":seeds, "units":units, 
	"batch_size":batch_size, "patience":patience, "min_delta": min_delta, "max_error_threshold":max_error_threshold,"num":num, "train_start" : train_start, "test_start" : test_start,
    "num_retry": num_retry, "detail_log":detail_log, "learning_rate":learning_rate}

# %%
#実験の実行及び結果の格納
abnormal_scores, thresholds = model_single_node_fixed_maxaverage_learning.result(data_ex , params)
# Out:
# ...
# 1回目の期間のモデル
# 該当期間の確認
# はじまり(train)2016/6/01 00:00:00
# 終わり(train)2018/6/01 00:00:00
# はじまり(test)2018/6/01 00:00:00
# 終わり(test)2018/7/01 00:00:00
# 1回目の期間のモデル作成開始
# 1回目の期間のトレーニングデータ数:17161
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=40, units_2=10, 試行回数=1, seed値 = 50
# Epoch 100: Loss = 0.021576, Max Error = 0.117365
# Epoch 200: Loss = 0.015273, Max Error = 0.093430
# Epoch 300: Loss = 0.009696, Max Error = 0.034152
# Epoch 400: Loss = 0.007855, Max Error = 0.026769
# Epoch 500: Loss = 0.006386, Max Error = 0.027396
# Epoch 600: Loss = 0.006281, Max Error = 0.027467
# Epoch 700: Loss = 0.006224, Max Error = 0.027437
# Epoch 800: Loss = 0.006177, Max Error = 0.027365
# Epoch 900: Loss = 0.006142, Max Error = 0.027298
# Epoch 1000: Loss = 0.006114, Max Error = 0.027230
# Epoch 1100: Loss = 0.006089, Max Error = 0.027156
# Epoch 1200: Loss = 0.006067, Max Error = 0.027074
# ...
