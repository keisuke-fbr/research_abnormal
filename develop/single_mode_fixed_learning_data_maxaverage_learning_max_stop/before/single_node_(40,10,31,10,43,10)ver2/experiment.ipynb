# %% [markdown]
# ライブラリの呼び出し

# %%
import sys
import os

# 現在の作業ディレクトリを基にプロジェクトのルートディレクトリを設定
project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..','..','..'))
sys.path.append(project_root)
print(project_root)
# Out:
# c:\Users\keisu\Desktop\研究元ファイル\abnormal\research_abnormal

# %%
#必要ライブラリのインストール
from src import data
from src.model import model_single_node_fixed_maxaverage_learning_max_stop
import config

# %%
#モジュールの再リロード
import importlib
import custom_class.custom_learning_average_stopping_maxdata_max_stop
import src
import src.data
import src.model
import src.model.model_single_node_fixed_maxaverage_learning_max_stop
import src.model_basic_single_node_fixed_maxaverage_learning_max_stop
import custom_class.custom_learning_average_stopping_maxdata_max_stop

importlib.reload(src.data)
importlib.reload(custom_class.custom_learning_average_stopping_maxdata_max_stop)
importlib.reload(src.model.model_single_node_fixed_maxaverage_learning_max_stop)
importlib.reload(src.model_basic_single_node_fixed_maxaverage_learning_max_stop)
# Out:
# <module 'src.model_basic_single_node_fixed_maxaverage_learning_max_stop' from 'c:\\Users\\keisu\\Desktop\\研究元ファイル\\abnormal\\research_abnormal\\src\\model_basic_single_node_fixed_maxaverage_learning_max_stop.py'>

# %% [markdown]
# データの読み込み

# %%
#データの読み込み及び加工、コラムリストの取得
data_ex, data_original = data.data_complete()
# Out:
# キャッシュファイルからデータを読み込みます

# %% [markdown]
# ハイパーパラメータの設定

# %%
#ハイパーパラメータの設定

#最大エポック数
max_epochs = 100000

#ノード数
units = 11

#モデル決定の閾値（再構成誤差のパラメータ）
#この閾値を下回ることで十分な性能を持つモデルとする
#今回は使用しない
error_threshold = 1

# シード値の準備
seeds = [50,51,52,53]

# ユニット数の準備
unit13_1 = 40
unit2_1 = 10
unit13_2 = 30
unit2_2 = 5
unit13_3 = 20
unit2_3 = 2

units = [[unit13_1, unit2_1],[unit13_2, unit2_2],[unit13_3, unit2_3]]

# 学習バッチサイズ
batch_size=64

# 監視するエポック数
patience = 1000

# 学習変化の閾値
min_delta = 1e-10

# 最大データの監視するエポック
patience_max = 1000

# 最大データの閾値
min_delta_max = 1e-10

# 何期間連続して予測を行うか
num = 3

#　初期化回数
num_retry = 4

#　詳細な出力
detail_log = True

#　どこまでの値より大きいデータ点をログの中で数えるか
confirm_datapoint = 0.004

#学習率
learning_rate = 1e-3

#トレーニング開始日
train_start = "2016/6/01 00:00:00"

#テスト開始日
test_start = "2018/6/01 00:00:00"



params = {"max_epochs":max_epochs, "units":units,
	"error_threshold":error_threshold, "seeds":seeds, "units":units, 
	"batch_size":batch_size, "patience":patience, "min_delta": min_delta, "patience_max":patience_max, "min_delta_max" : min_delta_max, "num":num, "train_start" : train_start, "test_start" : test_start,
    "num_retry": num_retry, "detail_log":detail_log, "confirm_datapoint":confirm_datapoint, "learning_rate":learning_rate}

# %%
#実験の実行及び結果の格納
abnormal_scores, thresholds = model_single_node_fixed_maxaverage_learning_max_stop.result(data_ex , params)
# Out:
# =====================================================================================
# 1回目の期間のモデル
# 該当期間の確認
# はじまり(train)2016/6/01 00:00:00
# 終わり(train)2018/6/01 00:00:00
# はじまり(test)2018/6/01 00:00:00
# 終わり(test)2018/7/01 00:00:00
# 1回目の期間のモデル作成開始
# 1回目の期間のトレーニングデータ数:17161
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=40, units_2=10, 試行回数=1, seed値 = 50
# Epoch 100: Loss = 0.021576, Max Error = 0.117365
#   Errors > 0.004: 17148 / 17161 (99.92%)
# Epoch 200: Loss = 0.015273, Max Error = 0.093430
#   Errors > 0.004: 17121 / 17161 (99.77%)
# Epoch 300: Loss = 0.009696, Max Error = 0.034152
#   Errors > 0.004: 15935 / 17161 (92.86%)
# Epoch 400: Loss = 0.007855, Max Error = 0.026769
#   Errors > 0.004: 15756 / 17161 (91.81%)
# Epoch 500: Loss = 0.006386, Max Error = 0.027396
#   Errors > 0.004: 12702 / 17161 (74.02%)
# Epoch 600: Loss = 0.006281, Max Error = 0.027467
#   Errors > 0.004: 12212 / 17161 (71.16%)
# Epoch 700: Loss = 0.006224, Max Error = 0.027437
#   Errors > 0.004: 12009 / 17161 (69.98%)
# Epoch 800: Loss = 0.006177, Max Error = 0.027365
#   Errors > 0.004: 11787 / 17161 (68.68%)
# Epoch 900: Loss = 0.006142, Max Error = 0.027298
#   Errors > 0.004: 11484 / 17161 (66.92%)
# Epoch 1000: Loss = 0.006114, Max Error = 0.027230
#   Errors > 0.004: 11336 / 17161 (66.06%)
# Epoch 1100: Loss = 0.006089, Max Error = 0.027156
#   Errors > 0.004: 11212 / 17161 (65.33%)
# Epoch 1200: Loss = 0.006067, Max Error = 0.027074
#   Errors > 0.004: 11099 / 17161 (64.68%)
# Epoch 1300: Loss = 0.006046, Max Error = 0.026982
#   Errors > 0.004: 10955 / 17161 (63.84%)
# Epoch 1400: Loss = 0.006027, Max Error = 0.026883
#   Errors > 0.004: 10678 / 17161 (62.22%)
# Epoch 1500: Loss = 0.006004, Max Error = 0.026788
#   Errors > 0.004: 10557 / 17161 (61.52%)
# Epoch 1600: Loss = 0.005986, Max Error = 0.026712
#   Errors > 0.004: 10283 / 17161 (59.92%)
# Epoch 1700: Loss = 0.005964, Max Error = 0.026666
#   Errors > 0.004: 10017 / 17161 (58.37%)
# Epoch 1800: Loss = 0.005945, Max Error = 0.026587
#   Errors > 0.004: 9922 / 17161 (57.82%)
# Epoch 1900: Loss = 0.005927, Max Error = 0.026515
#   Errors > 0.004: 9863 / 17161 (57.47%)
# Epoch 2000: Loss = 0.005908, Max Error = 0.026448
#   Errors > 0.004: 9789 / 17161 (57.04%)
# Epoch 2100: Loss = 0.005894, Max Error = 0.026379
#   Errors > 0.004: 9425 / 17161 (54.92%)
# Epoch 2200: Loss = 0.005862, Max Error = 0.026319
#   Errors > 0.004: 9594 / 17161 (55.91%)
# Epoch 2300: Loss = 0.005840, Max Error = 0.026292
#   Errors > 0.004: 9375 / 17161 (54.63%)
# Epoch 2400: Loss = 0.005828, Max Error = 0.026272
#   Errors > 0.004: 9277 / 17161 (54.06%)
# Epoch 2500: Loss = 0.005811, Max Error = 0.026255
#   Errors > 0.004: 9149 / 17161 (53.31%)
# Epoch 2600: Loss = 0.005796, Max Error = 0.026243
#   Errors > 0.004: 9050 / 17161 (52.74%)
# Epoch 2700: Loss = 0.005780, Max Error = 0.026255
#   Errors > 0.004: 8909 / 17161 (51.91%)
# Epoch 2800: Loss = 0.005765, Max Error = 0.026261
#   Errors > 0.004: 8820 / 17161 (51.40%)
# Epoch 2900: Loss = 0.005750, Max Error = 0.026262
#   Errors > 0.004: 8738 / 17161 (50.92%)
# Epoch 3000: Loss = 0.005734, Max Error = 0.026251
#   Errors > 0.004: 8657 / 17161 (50.45%)
# Epoch 3100: Loss = 0.005717, Max Error = 0.026215
#   Errors > 0.004: 8607 / 17161 (50.15%)
# Epoch 3200: Loss = 0.005698, Max Error = 0.026136
#   Errors > 0.004: 8549 / 17161 (49.82%)
# Epoch 3300: Loss = 0.005675, Max Error = 0.025987
#   Errors > 0.004: 8520 / 17161 (49.65%)
# Epoch 3400: Loss = 0.005642, Max Error = 0.025691
#   Errors > 0.004: 8536 / 17161 (49.74%)
# Epoch 3500: Loss = 0.005590, Max Error = 0.025007
#   Errors > 0.004: 8560 / 17161 (49.88%)
# Epoch 3600: Loss = 0.005443, Max Error = 0.022986
#   Errors > 0.004: 9321 / 17161 (54.32%)
# Epoch 3700: Loss = 0.004779, Max Error = 0.016302
#   Errors > 0.004: 7924 / 17161 (46.17%)
# Epoch 3800: Loss = 0.004204, Max Error = 0.015795
#   Errors > 0.004: 4966 / 17161 (28.94%)
# Epoch 3900: Loss = 0.004018, Max Error = 0.014660
#   Errors > 0.004: 5243 / 17161 (30.55%)
# Epoch 4000: Loss = 0.003922, Max Error = 0.014024
#   Errors > 0.004: 4983 / 17161 (29.04%)
# Epoch 4100: Loss = 0.003888, Max Error = 0.013878
#   Errors > 0.004: 4894 / 17161 (28.52%)
# Epoch 4200: Loss = 0.003821, Max Error = 0.013736
#   Errors > 0.004: 4849 / 17161 (28.26%)
# Epoch 4300: Loss = 0.003787, Max Error = 0.013591
#   Errors > 0.004: 4641 / 17161 (27.04%)
# Epoch 4400: Loss = 0.003753, Max Error = 0.013466
#   Errors > 0.004: 4723 / 17161 (27.52%)
# Epoch 4500: Loss = 0.003731, Max Error = 0.013330
#   Errors > 0.004: 4673 / 17161 (27.23%)
# Epoch 4600: Loss = 0.003718, Max Error = 0.013216
#   Errors > 0.004: 4634 / 17161 (27.00%)
# Epoch 4700: Loss = 0.003701, Max Error = 0.013153
#   Errors > 0.004: 4647 / 17161 (27.08%)
# Epoch 4800: Loss = 0.003681, Max Error = 0.013165
#   Errors > 0.004: 4627 / 17161 (26.96%)
# Epoch 4900: Loss = 0.003661, Max Error = 0.013261
#   Errors > 0.004: 4579 / 17161 (26.68%)
# Epoch 5000: Loss = 0.003647, Max Error = 0.013368
#   Errors > 0.004: 4504 / 17161 (26.25%)
# Epoch 5100: Loss = 0.003570, Max Error = 0.013456
#   Errors > 0.004: 4521 / 17161 (26.34%)
# Epoch 5200: Loss = 0.003568, Max Error = 0.013461
#   Errors > 0.004: 4329 / 17161 (25.23%)
# Epoch 5300: Loss = 0.003436, Max Error = 0.013259
#   Errors > 0.004: 4010 / 17161 (23.37%)
# Epoch 5400: Loss = 0.003188, Max Error = 0.012152
#   Errors > 0.004: 3446 / 17161 (20.08%)
# Epoch 5500: Loss = 0.002517, Max Error = 0.009610
#   Errors > 0.004: 1382 / 17161 (8.05%)
# Epoch 5600: Loss = 0.002024, Max Error = 0.009220
#   Errors > 0.004: 292 / 17161 (1.70%)
# Epoch 5700: Loss = 0.001976, Max Error = 0.009198
#   Errors > 0.004: 143 / 17161 (0.83%)
# Epoch 5800: Loss = 0.001757, Max Error = 0.008923
#   Errors > 0.004: 165 / 17161 (0.96%)
# Epoch 5900: Loss = 0.001903, Max Error = 0.009170
#   Errors > 0.004: 166 / 17161 (0.97%)
# Epoch 6000: Loss = 0.001882, Max Error = 0.008634
#   Errors > 0.004: 118 / 17161 (0.69%)
# Epoch 6100: Loss = 0.001607, Max Error = 0.009186
#   Errors > 0.004: 145 / 17161 (0.84%)
# Epoch 6200: Loss = 0.002285, Max Error = 0.009067
#   Errors > 0.004: 283 / 17161 (1.65%)
# Epoch 6300: Loss = 0.001722, Max Error = 0.008444
#   Errors > 0.004: 191 / 17161 (1.11%)
# Epoch 6400: Loss = 0.001980, Max Error = 0.008624
#   Errors > 0.004: 141 / 17161 (0.82%)
# Epoch 6500: Loss = 0.001700, Max Error = 0.008041
#   Errors > 0.004: 136 / 17161 (0.79%)
# Epoch 6600: Loss = 0.001630, Max Error = 0.008027
#   Errors > 0.004: 92 / 17161 (0.54%)
# Epoch 6700: Loss = 0.001841, Max Error = 0.008047
#   Errors > 0.004: 116 / 17161 (0.68%)
# Epoch 6800: Loss = 0.002096, Max Error = 0.008445
#   Errors > 0.004: 289 / 17161 (1.68%)
# Epoch 6900: Loss = 0.001947, Max Error = 0.007126
#   Errors > 0.004: 68 / 17161 (0.40%)
# Epoch 7000: Loss = 0.001552, Max Error = 0.007940
#   Errors > 0.004: 116 / 17161 (0.68%)
# Epoch 7100: Loss = 0.001808, Max Error = 0.007282
#   Errors > 0.004: 72 / 17161 (0.42%)
# Epoch 7200: Loss = 0.002018, Max Error = 0.008246
#   Errors > 0.004: 337 / 17161 (1.96%)
# Epoch 7300: Loss = 0.002032, Max Error = 0.006861
#   Errors > 0.004: 72 / 17161 (0.42%)
# Epoch 7400: Loss = 0.001428, Max Error = 0.007051
#   Errors > 0.004: 89 / 17161 (0.52%)
# Epoch 7500: Loss = 0.002083, Max Error = 0.006928
#   Errors > 0.004: 87 / 17161 (0.51%)
# Epoch 7600: Loss = 0.001412, Max Error = 0.006890
#   Errors > 0.004: 74 / 17161 (0.43%)
# Epoch 7700: Loss = 0.001325, Max Error = 0.007521
#   Errors > 0.004: 127 / 17161 (0.74%)
# Epoch 7800: Loss = 0.001744, Max Error = 0.007145
#   Errors > 0.004: 78 / 17161 (0.45%)
# Epoch 7900: Loss = 0.001886, Max Error = 0.008056
#   Errors > 0.004: 101 / 17161 (0.59%)
# Epoch 8000: Loss = 0.001346, Max Error = 0.006329
#   Errors > 0.004: 53 / 17161 (0.31%)
# Epoch 8100: Loss = 0.001423, Max Error = 0.006601
#   Errors > 0.004: 78 / 17161 (0.45%)
# Epoch 8200: Loss = 0.001415, Max Error = 0.006854
#   Errors > 0.004: 60 / 17161 (0.35%)
# Epoch 8300: Loss = 0.001769, Max Error = 0.006072
#   Errors > 0.004: 55 / 17161 (0.32%)
# Epoch 8400: Loss = 0.001467, Max Error = 0.006490
#   Errors > 0.004: 74 / 17161 (0.43%)
# Epoch 8500: Loss = 0.001374, Max Error = 0.006364
#   Errors > 0.004: 69 / 17161 (0.40%)
# Epoch 8600: Loss = 0.001355, Max Error = 0.006416
#   Errors > 0.004: 38 / 17161 (0.22%)
# Epoch 8700: Loss = 0.001735, Max Error = 0.006556
#   Errors > 0.004: 42 / 17161 (0.24%)
# Epoch 8800: Loss = 0.001451, Max Error = 0.006239
#   Errors > 0.004: 44 / 17161 (0.26%)
# Epoch 8900: Loss = 0.001669, Max Error = 0.006818
#   Errors > 0.004: 53 / 17161 (0.31%)
# Epoch 9000: Loss = 0.001724, Max Error = 0.006463
#   Errors > 0.004: 62 / 17161 (0.36%)
# Epoch 9100: Loss = 0.001445, Max Error = 0.006809
#   Errors > 0.004: 51 / 17161 (0.30%)
# Epoch 9200: Loss = 0.001401, Max Error = 0.007112
#   Errors > 0.004: 43 / 17161 (0.25%)
# Epoch 9300: Loss = 0.001365, Max Error = 0.006483
#   Errors > 0.004: 43 / 17161 (0.25%)
# Epoch 9400: Loss = 0.001414, Max Error = 0.006350
#   Errors > 0.004: 50 / 17161 (0.29%)
# Epoch 9500: Loss = 0.001502, Max Error = 0.007447
#   Errors > 0.004: 66 / 17161 (0.38%)
# Epoch 9600: Loss = 0.001890, Max Error = 0.007377
#   Errors > 0.004: 65 / 17161 (0.38%)
# Epoch 9700: Loss = 0.001365, Max Error = 0.006476
#   Errors > 0.004: 41 / 17161 (0.24%)
# Epoch 9800: Loss = 0.001321, Max Error = 0.006514
#   Errors > 0.004: 25 / 17161 (0.15%)
# Epoch 9900: Loss = 0.001455, Max Error = 0.006322
#   Errors > 0.004: 47 / 17161 (0.27%)
# Epoch 10000: Loss = 0.001313, Max Error = 0.006740
#   Errors > 0.004: 27 / 17161 (0.16%)
# Epoch 10100: Loss = 0.001523, Max Error = 0.006692
#   Errors > 0.004: 54 / 17161 (0.31%)
# Epoch 10200: Loss = 0.001573, Max Error = 0.007010
#   Errors > 0.004: 47 / 17161 (0.27%)
# Epoch 10300: Loss = 0.001425, Max Error = 0.006710
#   Errors > 0.004: 25 / 17161 (0.15%)
# Epoch 10400: Loss = 0.001618, Max Error = 0.006544
#   Errors > 0.004: 27 / 17161 (0.16%)
# Epoch 10500: Loss = 0.001374, Max Error = 0.007281
#   Errors > 0.004: 47 / 17161 (0.27%)
# Epoch 10600: Loss = 0.001363, Max Error = 0.006992
#   Errors > 0.004: 37 / 17161 (0.22%)
# Epoch 10700: Loss = 0.001394, Max Error = 0.006092
#   Errors > 0.004: 19 / 17161 (0.11%)
# Epoch 10800: Loss = 0.001458, Max Error = 0.006751
#   Errors > 0.004: 43 / 17161 (0.25%)
# Epoch 10900: Loss = 0.001321, Max Error = 0.006454
#   Errors > 0.004: 18 / 17161 (0.10%)
# Epoch 11000: Loss = 0.001182, Max Error = 0.007324
#   Errors > 0.004: 30 / 17161 (0.17%)
# Epoch 11100: Loss = 0.001256, Max Error = 0.007224
#   Errors > 0.004: 22 / 17161 (0.13%)
# Epoch 11200: Loss = 0.001299, Max Error = 0.007525
#   Errors > 0.004: 23 / 17161 (0.13%)
# Epoch 11300: Loss = 0.001426, Max Error = 0.007230
#   Errors > 0.004: 60 / 17161 (0.35%)
# Epoch 11400: Loss = 0.001345, Max Error = 0.006831
#   Errors > 0.004: 17 / 17161 (0.10%)
# Epoch 11500: Loss = 0.001259, Max Error = 0.006631
#   Errors > 0.004: 16 / 17161 (0.09%)
# Epoch 11600: Loss = 0.001460, Max Error = 0.006138
#   Errors > 0.004: 18 / 17161 (0.10%)
# Epoch 11700: Loss = 0.001240, Max Error = 0.006837
#   Errors > 0.004: 19 / 17161 (0.11%)
# Epoch 11800: Loss = 0.001298, Max Error = 0.006147
#   Errors > 0.004: 25 / 17161 (0.15%)
# Epoch 11900: Loss = 0.001216, Max Error = 0.006005
#   Errors > 0.004: 15 / 17161 (0.09%)
# Epoch 12000: Loss = 0.001475, Max Error = 0.006936
#   Errors > 0.004: 14 / 17161 (0.08%)
# Epoch 12100: Loss = 0.001365, Max Error = 0.006661
#   Errors > 0.004: 20 / 17161 (0.12%)
# Epoch 12200: Loss = 0.001220, Max Error = 0.006782
#   Errors > 0.004: 25 / 17161 (0.15%)
# Epoch 12300: Loss = 0.001314, Max Error = 0.007156
#   Errors > 0.004: 36 / 17161 (0.21%)
# Epoch 12400: Loss = 0.001163, Max Error = 0.006836
#   Errors > 0.004: 11 / 17161 (0.06%)
# Epoch 12500: Loss = 0.001232, Max Error = 0.007288
#   Errors > 0.004: 18 / 17161 (0.10%)
# Epoch 12600: Loss = 0.001233, Max Error = 0.006728
#   Errors > 0.004: 25 / 17161 (0.15%)
# Epoch 12700: Loss = 0.001226, Max Error = 0.007461
#   Errors > 0.004: 23 / 17161 (0.13%)
# Epoch 12800: Loss = 0.001135, Max Error = 0.006997
#   Errors > 0.004: 13 / 17161 (0.08%)
# Epoch 12900: Loss = 0.001173, Max Error = 0.007012
#   Errors > 0.004: 12 / 17161 (0.07%)
# Epoch 13000: Loss = 0.001298, Max Error = 0.007033
#   Errors > 0.004: 13 / 17161 (0.08%)
# Epoch 13100: Loss = 0.001339, Max Error = 0.006958
#   Errors > 0.004: 13 / 17161 (0.08%)
# Epoch 13200: Loss = 0.001094, Max Error = 0.006810
#   Errors > 0.004: 11 / 17161 (0.06%)
# Epoch 13300: Loss = 0.001384, Max Error = 0.006769
#   Errors > 0.004: 17 / 17161 (0.10%)
# Epoch 13400: Loss = 0.001124, Max Error = 0.006535
#   Errors > 0.004: 19 / 17161 (0.11%)
# Epoch 13500: Loss = 0.001414, Max Error = 0.007184
#   Errors > 0.004: 13 / 17161 (0.08%)
# Epoch 13600: Loss = 0.001235, Max Error = 0.006659
#   Errors > 0.004: 18 / 17161 (0.10%)
# Epoch 13700: Loss = 0.001388, Max Error = 0.007114
#   Errors > 0.004: 12 / 17161 (0.07%)
# Epoch 13800: Loss = 0.001374, Max Error = 0.006983
#   Errors > 0.004: 11 / 17161 (0.06%)
# Epoch 13900: Loss = 0.001206, Max Error = 0.006921
#   Errors > 0.004: 10 / 17161 (0.06%)
# Epoch 14000: Loss = 0.001250, Max Error = 0.006641
#   Errors > 0.004: 11 / 17161 (0.06%)
# Epoch 14100: Loss = 0.001146, Max Error = 0.007291
#   Errors > 0.004: 13 / 17161 (0.08%)
# Epoch 14200: Loss = 0.001086, Max Error = 0.007101
#   Errors > 0.004: 10 / 17161 (0.06%)
# Epoch 14300: Loss = 0.001049, Max Error = 0.006321
#   Errors > 0.004: 16 / 17161 (0.09%)
# Epoch 14400: Loss = 0.001446, Max Error = 0.006806
#   Errors > 0.004: 14 / 17161 (0.08%)
# Epoch 14500: Loss = 0.001426, Max Error = 0.007028
#   Errors > 0.004: 9 / 17161 (0.05%)
# Epoch 14600: Loss = 0.001046, Max Error = 0.006519
#   Errors > 0.004: 9 / 17161 (0.05%)
# Epoch 14700: Loss = 0.001149, Max Error = 0.007370
#   Errors > 0.004: 15 / 17161 (0.09%)
# Epoch 14800: Loss = 0.001048, Max Error = 0.006938
#   Errors > 0.004: 13 / 17161 (0.08%)
# Epoch 14900: Loss = 0.001117, Max Error = 0.006533
#   Errors > 0.004: 9 / 17161 (0.05%)
# Epoch 15000: Loss = 0.001318, Max Error = 0.006402
#   Errors > 0.004: 12 / 17161 (0.07%)
# Epoch 15100: Loss = 0.001176, Max Error = 0.006869
#   Errors > 0.004: 9 / 17161 (0.05%)
# Epoch 15200: Loss = 0.001085, Max Error = 0.006717
#   Errors > 0.004: 9 / 17161 (0.05%)
# Epoch 15300: Loss = 0.001083, Max Error = 0.007187
#   Errors > 0.004: 9 / 17161 (0.05%)
# Epoch 15400: Loss = 0.001287, Max Error = 0.006404
#   Errors > 0.004: 9 / 17161 (0.05%)
# Epoch 15500: Loss = 0.001218, Max Error = 0.007207
#   Errors > 0.004: 9 / 17161 (0.05%)
# Epoch 15600: Loss = 0.001144, Max Error = 0.006917
#   Errors > 0.004: 9 / 17161 (0.05%)
# Epoch 15700: Loss = 0.000978, Max Error = 0.006934
#   Errors > 0.004: 9 / 17161 (0.05%)
# Epoch 15800: Loss = 0.001280, Max Error = 0.006947
#   Errors > 0.004: 9 / 17161 (0.05%)
# Epoch 15900: Loss = 0.001017, Max Error = 0.007196
#   Errors > 0.004: 9 / 17161 (0.05%)
# Epoch 16000: Loss = 0.001041, Max Error = 0.006967
#   Errors > 0.004: 9 / 17161 (0.05%)
# Epoch 16100: Loss = 0.001170, Max Error = 0.006713
#   Errors > 0.004: 10 / 17161 (0.06%)
# Epoch 16200: Loss = 0.001147, Max Error = 0.006906
#   Errors > 0.004: 8 / 17161 (0.05%)
# Epoch 16300: Loss = 0.000997, Max Error = 0.006878
#   Errors > 0.004: 8 / 17161 (0.05%)
# Epoch 16400: Loss = 0.001068, Max Error = 0.006933
#   Errors > 0.004: 9 / 17161 (0.05%)
# Epoch 16500: Loss = 0.001307, Max Error = 0.006903
#   Errors > 0.004: 10 / 17161 (0.06%)
# Epoch 16600: Loss = 0.001013, Max Error = 0.006858
#   Errors > 0.004: 8 / 17161 (0.05%)
# Epoch 16700: Loss = 0.001116, Max Error = 0.006519
#   Errors > 0.004: 9 / 17161 (0.05%)
# Epoch 16800: Loss = 0.000991, Max Error = 0.006708
#   Errors > 0.004: 8 / 17161 (0.05%)
# Epoch 16900: Loss = 0.001165, Max Error = 0.006053
#   Errors > 0.004: 9 / 17161 (0.05%)
# Epoch 17000: Loss = 0.001154, Max Error = 0.006705
#   Errors > 0.004: 8 / 17161 (0.05%)
# Epoch 17100: Loss = 0.001028, Max Error = 0.006636
#   Errors > 0.004: 8 / 17161 (0.05%)
# Epoch 17200: Loss = 0.001322, Max Error = 0.006828
#   Errors > 0.004: 8 / 17161 (0.05%)
# Epoch 17300: Loss = 0.001233, Max Error = 0.006526
#   Errors > 0.004: 9 / 17161 (0.05%)
# Epoch 17400: Loss = 0.000916, Max Error = 0.006531
#   Errors > 0.004: 9 / 17161 (0.05%)
# Epoch 17500: Loss = 0.000918, Max Error = 0.006671
#   Errors > 0.004: 8 / 17161 (0.05%)
# Epoch 17600: Loss = 0.001272, Max Error = 0.006234
#   Errors > 0.004: 8 / 17161 (0.05%)
# Epoch 17700: Loss = 0.001267, Max Error = 0.006128
#   Errors > 0.004: 8 / 17161 (0.05%)
# Epoch 17800: Loss = 0.001115, Max Error = 0.006451
#   Errors > 0.004: 10 / 17161 (0.06%)
# Epoch 17900: Loss = 0.000961, Max Error = 0.006631
#   Errors > 0.004: 9 / 17161 (0.05%)
# Epoch 18000: Loss = 0.001129, Max Error = 0.006497
#   Errors > 0.004: 9 / 17161 (0.05%)
# Epoch 18100: Loss = 0.001170, Max Error = 0.006663
#   Errors > 0.004: 9 / 17161 (0.05%)
# Epoch 18200: Loss = 0.000873, Max Error = 0.006404
#   Errors > 0.004: 9 / 17161 (0.05%)
# Epoch 18300: Loss = 0.000955, Max Error = 0.006166
#   Errors > 0.004: 8 / 17161 (0.05%)
# Epoch 18400: Loss = 0.000969, Max Error = 0.006393
#   Errors > 0.004: 8 / 17161 (0.05%)
# Epoch 18500: Loss = 0.001121, Max Error = 0.006653
#   Errors > 0.004: 8 / 17161 (0.05%)
# Epoch 18600: Loss = 0.001034, Max Error = 0.006471
#   Errors > 0.004: 8 / 17161 (0.05%)
# Epoch 18700: Loss = 0.001125, Max Error = 0.006609
#   Errors > 0.004: 8 / 17161 (0.05%)
# Epoch 18800: Loss = 0.000938, Max Error = 0.006518
#   Errors > 0.004: 8 / 17161 (0.05%)
# Epoch 18900: Loss = 0.000949, Max Error = 0.006277
#   Errors > 0.004: 9 / 17161 (0.05%)
# Epoch 19000: Loss = 0.000911, Max Error = 0.006558
#   Errors > 0.004: 7 / 17161 (0.04%)
# Epoch 19100: Loss = 0.001248, Max Error = 0.006100
#   Errors > 0.004: 8 / 17161 (0.05%)
# Epoch 19200: Loss = 0.001163, Max Error = 0.006600
#   Errors > 0.004: 7 / 17161 (0.04%)
# Epoch 19300: Loss = 0.000944, Max Error = 0.006057
#   Errors > 0.004: 8 / 17161 (0.05%)
# Epoch 19400: Loss = 0.001043, Max Error = 0.006074
#   Errors > 0.004: 6 / 17161 (0.03%)
# Epoch 19500: Loss = 0.000955, Max Error = 0.006606
#   Errors > 0.004: 8 / 17161 (0.05%)
# Epoch 19600: Loss = 0.001039, Max Error = 0.005951
#   Errors > 0.004: 7 / 17161 (0.04%)
# Epoch 19700: Loss = 0.000999, Max Error = 0.005980
#   Errors > 0.004: 7 / 17161 (0.04%)
# Epoch 19800: Loss = 0.000981, Max Error = 0.006346
#   Errors > 0.004: 8 / 17161 (0.05%)
# Epoch 19900: Loss = 0.000939, Max Error = 0.005820
#   Errors > 0.004: 8 / 17161 (0.05%)
# Epoch 20000: Loss = 0.000937, Max Error = 0.005910
#   Errors > 0.004: 8 / 17161 (0.05%)
# Epoch 20100: Loss = 0.000886, Max Error = 0.005292
#   Errors > 0.004: 8 / 17161 (0.05%)
# Epoch 20200: Loss = 0.001176, Max Error = 0.006203
#   Errors > 0.004: 6 / 17161 (0.03%)
# Epoch 20300: Loss = 0.000876, Max Error = 0.006220
#   Errors > 0.004: 8 / 17161 (0.05%)
# Epoch 20400: Loss = 0.001052, Max Error = 0.005784
#   Errors > 0.004: 8 / 17161 (0.05%)
# Epoch 20500: Loss = 0.001092, Max Error = 0.005950
#   Errors > 0.004: 8 / 17161 (0.05%)
# Epoch 20600: Loss = 0.000880, Max Error = 0.005930
#   Errors > 0.004: 8 / 17161 (0.05%)
# Epoch 20700: Loss = 0.000845, Max Error = 0.005910
#   Errors > 0.004: 8 / 17161 (0.05%)
# Epoch 20800: Loss = 0.000950, Max Error = 0.005621
#   Errors > 0.004: 7 / 17161 (0.04%)
# Epoch 20900: Loss = 0.000903, Max Error = 0.005720
#   Errors > 0.004: 7 / 17161 (0.04%)
# Epoch 21000: Loss = 0.000815, Max Error = 0.005887
#   Errors > 0.004: 7 / 17161 (0.04%)
# Epoch 21100: Loss = 0.001039, Max Error = 0.005694
#   Errors > 0.004: 6 / 17161 (0.03%)
# Epoch 21200: Loss = 0.001097, Max Error = 0.005981
#   Errors > 0.004: 6 / 17161 (0.03%)
# Epoch 21300: Loss = 0.001026, Max Error = 0.005751
#   Errors > 0.004: 8 / 17161 (0.05%)
# Epoch 21400: Loss = 0.000867, Max Error = 0.005796
#   Errors > 0.004: 7 / 17161 (0.04%)
# Epoch 21500: Loss = 0.000954, Max Error = 0.005887
#   Errors > 0.004: 6 / 17161 (0.03%)
# Epoch 21600: Loss = 0.000800, Max Error = 0.005544
#   Errors > 0.004: 7 / 17161 (0.04%)
# Epoch 21700: Loss = 0.000844, Max Error = 0.005561
#   Errors > 0.004: 7 / 17161 (0.04%)
# Epoch 21800: Loss = 0.000932, Max Error = 0.005208
#   Errors > 0.004: 6 / 17161 (0.03%)
# Epoch 21900: Loss = 0.000845, Max Error = 0.005465
#   Errors > 0.004: 8 / 17161 (0.05%)
# Epoch 22000: Loss = 0.000834, Max Error = 0.005744
#   Errors > 0.004: 8 / 17161 (0.05%)
# Epoch 22100: Loss = 0.000874, Max Error = 0.005844
#   Errors > 0.004: 7 / 17161 (0.04%)
# Epoch 22200: Loss = 0.000989, Max Error = 0.005685
#   Errors > 0.004: 6 / 17161 (0.03%)
# Epoch 22300: Loss = 0.000802, Max Error = 0.005789
#   Errors > 0.004: 6 / 17161 (0.03%)
# Epoch 22400: Loss = 0.001077, Max Error = 0.005100
#   Errors > 0.004: 5 / 17161 (0.03%)
# Epoch 22500: Loss = 0.000840, Max Error = 0.004966
#   Errors > 0.004: 6 / 17161 (0.03%)
# Epoch 22600: Loss = 0.000843, Max Error = 0.005508
#   Errors > 0.004: 8 / 17161 (0.05%)
# Epoch 22700: Loss = 0.000931, Max Error = 0.005648
#   Errors > 0.004: 6 / 17161 (0.03%)
# Epoch 22800: Loss = 0.000822, Max Error = 0.005550
#   Errors > 0.004: 6 / 17161 (0.03%)
# Epoch 22900: Loss = 0.000877, Max Error = 0.005483
#   Errors > 0.004: 5 / 17161 (0.03%)
# Epoch 23000: Loss = 0.000858, Max Error = 0.005636
#   Errors > 0.004: 6 / 17161 (0.03%)
# Epoch 23100: Loss = 0.000913, Max Error = 0.005093
#   Errors > 0.004: 5 / 17161 (0.03%)
# Epoch 23200: Loss = 0.000908, Max Error = 0.005473
#   Errors > 0.004: 6 / 17161 (0.03%)
# Epoch 23300: Loss = 0.000925, Max Error = 0.005174
#   Errors > 0.004: 5 / 17161 (0.03%)
# Epoch 23400: Loss = 0.000822, Max Error = 0.005493
#   Errors > 0.004: 6 / 17161 (0.03%)
# Epoch 23500: Loss = 0.000829, Max Error = 0.005245
#   Errors > 0.004: 5 / 17161 (0.03%)
# Epoch 23600: Loss = 0.001035, Max Error = 0.005414
#   Errors > 0.004: 7 / 17161 (0.04%)
# Epoch 23700: Loss = 0.000859, Max Error = 0.005196
#   Errors > 0.004: 5 / 17161 (0.03%)
# Epoch 23800: Loss = 0.000777, Max Error = 0.005890
#   Errors > 0.004: 6 / 17161 (0.03%)
# Epoch 23900: Loss = 0.000968, Max Error = 0.005444
#   Errors > 0.004: 6 / 17161 (0.03%)
# Epoch 24000: Loss = 0.000943, Max Error = 0.005571
#   Errors > 0.004: 5 / 17161 (0.03%)
# Epoch 24100: Loss = 0.000823, Max Error = 0.005567
#   Errors > 0.004: 7 / 17161 (0.04%)
# Epoch 24200: Loss = 0.000803, Max Error = 0.005334
#   Errors > 0.004: 5 / 17161 (0.03%)
# Epoch 24300: Loss = 0.000877, Max Error = 0.005538
#   Errors > 0.004: 6 / 17161 (0.03%)
# Epoch 24400: Loss = 0.000745, Max Error = 0.005012
#   Errors > 0.004: 4 / 17161 (0.02%)
# Epoch 24500: Loss = 0.000876, Max Error = 0.005072
#   Errors > 0.004: 3 / 17161 (0.02%)
# Epoch 24600: Loss = 0.000890, Max Error = 0.005185
#   Errors > 0.004: 4 / 17161 (0.02%)
# Epoch 24700: Loss = 0.001038, Max Error = 0.005634
#   Errors > 0.004: 7 / 17161 (0.04%)
# Epoch 24800: Loss = 0.000884, Max Error = 0.005326
#   Errors > 0.004: 5 / 17161 (0.03%)
# Epoch 24900: Loss = 0.000952, Max Error = 0.005133
#   Errors > 0.004: 3 / 17161 (0.02%)
# Epoch 25000: Loss = 0.000776, Max Error = 0.005394
#   Errors > 0.004: 5 / 17161 (0.03%)
# Epoch 25100: Loss = 0.000928, Max Error = 0.005319
#   Errors > 0.004: 4 / 17161 (0.02%)
# Epoch 25200: Loss = 0.000889, Max Error = 0.005230
#   Errors > 0.004: 5 / 17161 (0.03%)
# Epoch 25300: Loss = 0.000786, Max Error = 0.005301
#   Errors > 0.004: 4 / 17161 (0.02%)
# Epoch 25400: Loss = 0.000854, Max Error = 0.005045
#   Errors > 0.004: 3 / 17161 (0.02%)
# Epoch 25500: Loss = 0.000751, Max Error = 0.005343
#   Errors > 0.004: 4 / 17161 (0.02%)
# Epoch 25600: Loss = 0.000840, Max Error = 0.004420
#   Errors > 0.004: 1 / 17161 (0.01%)
# Epoch 25700: Loss = 0.000847, Max Error = 0.005189
#   Errors > 0.004: 4 / 17161 (0.02%)
# Epoch 25800: Loss = 0.000796, Max Error = 0.005399
#   Errors > 0.004: 5 / 17161 (0.03%)
# Epoch 25900: Loss = 0.000831, Max Error = 0.004905
#   Errors > 0.004: 3 / 17161 (0.02%)
# Epoch 26000: Loss = 0.000912, Max Error = 0.005349
#   Errors > 0.004: 4 / 17161 (0.02%)
# Epoch 26100: Loss = 0.000853, Max Error = 0.005053
#   Errors > 0.004: 3 / 17161 (0.02%)
# Epoch 26200: Loss = 0.000733, Max Error = 0.004901
#   Errors > 0.004: 3 / 17161 (0.02%)
# Epoch 26300: Loss = 0.000857, Max Error = 0.005082
#   Errors > 0.004: 3 / 17161 (0.02%)
# Epoch 26400: Loss = 0.000884, Max Error = 0.005275
#   Errors > 0.004: 4 / 17161 (0.02%)
# Epoch 26500: Loss = 0.000841, Max Error = 0.004959
#   Errors > 0.004: 3 / 17161 (0.02%)
# Epoch 26600: Loss = 0.000794, Max Error = 0.005005
#   Errors > 0.004: 3 / 17161 (0.02%)
# Epoch 26700: Loss = 0.000838, Max Error = 0.005091
#   Errors > 0.004: 3 / 17161 (0.02%)
# Epoch 26800: Loss = 0.000911, Max Error = 0.005146
#   Errors > 0.004: 4 / 17161 (0.02%)
# Epoch 26900: Loss = 0.000800, Max Error = 0.005156
#   Errors > 0.004: 3 / 17161 (0.02%)
# Early stopping at epoch 26995: loss and max error stopped improving.
#     Best loss: 0.0006236187764443457, Current loss: 0.0008933536591939628
#     Best max error: 0.004386045970022678, Current max error: 0.005089547950774431
# モデルは収束しました。訓練は 26995 エポックで停止しました。
# トレーニングデータの再構成誤差（平均）：0.0006807127535085343
# トレーニングデータの再構成誤差（最大値）：0.005089522277284484
# モデルの更新: シード値=50
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=40, units_2=10, 試行回数=2, seed値 = 51
# Epoch 100: Loss = 0.021146, Max Error = 0.114059
#   Errors > 0.004: 17156 / 17161 (99.97%)
# Epoch 200: Loss = 0.016832, Max Error = 0.060533
#   Errors > 0.004: 17143 / 17161 (99.90%)
# Epoch 300: Loss = 0.009939, Max Error = 0.036317
#   Errors > 0.004: 16263 / 17161 (94.77%)
# Epoch 400: Loss = 0.009501, Max Error = 0.035472
#   Errors > 0.004: 15445 / 17161 (90.00%)
# Epoch 500: Loss = 0.009298, Max Error = 0.034558
#   Errors > 0.004: 15705 / 17161 (91.52%)
# Epoch 600: Loss = 0.008920, Max Error = 0.035408
#   Errors > 0.004: 15143 / 17161 (88.24%)
# Epoch 700: Loss = 0.006557, Max Error = 0.025552
#   Errors > 0.004: 12226 / 17161 (71.24%)
# Epoch 800: Loss = 0.006272, Max Error = 0.026767
#   Errors > 0.004: 11748 / 17161 (68.46%)
# Epoch 900: Loss = 0.006175, Max Error = 0.027301
#   Errors > 0.004: 11445 / 17161 (66.69%)
# Epoch 1000: Loss = 0.006116, Max Error = 0.027527
#   Errors > 0.004: 11574 / 17161 (67.44%)
# Epoch 1100: Loss = 0.006070, Max Error = 0.027590
#   Errors > 0.004: 11534 / 17161 (67.21%)
# Epoch 1200: Loss = 0.006032, Max Error = 0.027570
#   Errors > 0.004: 11730 / 17161 (68.35%)
# Epoch 1300: Loss = 0.005998, Max Error = 0.027507
#   Errors > 0.004: 11929 / 17161 (69.51%)
# Epoch 1400: Loss = 0.005965, Max Error = 0.027414
#   Errors > 0.004: 12128 / 17161 (70.67%)
# Epoch 1500: Loss = 0.005934, Max Error = 0.027299
#   Errors > 0.004: 12362 / 17161 (72.04%)
# Epoch 1600: Loss = 0.005905, Max Error = 0.027162
#   Errors > 0.004: 12649 / 17161 (73.71%)
# Epoch 1700: Loss = 0.005878, Max Error = 0.027001
#   Errors > 0.004: 13189 / 17161 (76.85%)
# Epoch 1800: Loss = 0.005841, Max Error = 0.026794
#   Errors > 0.004: 14482 / 17161 (84.39%)
# Epoch 1900: Loss = 0.005815, Max Error = 0.026573
#   Errors > 0.004: 14696 / 17161 (85.64%)
# Epoch 2000: Loss = 0.005786, Max Error = 0.026315
#   Errors > 0.004: 14551 / 17161 (84.79%)
# Epoch 2100: Loss = 0.005748, Max Error = 0.025963
#   Errors > 0.004: 14584 / 17161 (84.98%)
# Epoch 2200: Loss = 0.005682, Max Error = 0.025314
#   Errors > 0.004: 15371 / 17161 (89.57%)
# Epoch 2300: Loss = 0.005523, Max Error = 0.023836
#   Errors > 0.004: 15226 / 17161 (88.72%)
# Epoch 2400: Loss = 0.004997, Max Error = 0.018199
#   Errors > 0.004: 10636 / 17161 (61.98%)
# Epoch 2500: Loss = 0.004318, Max Error = 0.018122
#   Errors > 0.004: 7324 / 17161 (42.68%)
# Epoch 2600: Loss = 0.003983, Max Error = 0.016812
#   Errors > 0.004: 12161 / 17161 (70.86%)
# Epoch 2700: Loss = 0.003700, Max Error = 0.015183
#   Errors > 0.004: 5660 / 17161 (32.98%)
# Epoch 2800: Loss = 0.003205, Max Error = 0.012248
#   Errors > 0.004: 3246 / 17161 (18.91%)
# Epoch 2900: Loss = 0.002618, Max Error = 0.010256
#   Errors > 0.004: 1969 / 17161 (11.47%)
# Epoch 3000: Loss = 0.002454, Max Error = 0.010127
#   Errors > 0.004: 430 / 17161 (2.51%)
# Epoch 3100: Loss = 0.002597, Max Error = 0.010403
#   Errors > 0.004: 715 / 17161 (4.17%)
# Epoch 3200: Loss = 0.002076, Max Error = 0.009286
#   Errors > 0.004: 291 / 17161 (1.70%)
# Epoch 3300: Loss = 0.002766, Max Error = 0.009287
#   Errors > 0.004: 675 / 17161 (3.93%)
# Epoch 3400: Loss = 0.002201, Max Error = 0.008539
#   Errors > 0.004: 160 / 17161 (0.93%)
# Epoch 3500: Loss = 0.001972, Max Error = 0.010050
#   Errors > 0.004: 2401 / 17161 (13.99%)
# Epoch 3600: Loss = 0.002714, Max Error = 0.008900
#   Errors > 0.004: 893 / 17161 (5.20%)
# Epoch 3700: Loss = 0.002889, Max Error = 0.007941
#   Errors > 0.004: 338 / 17161 (1.97%)
# Epoch 3800: Loss = 0.002429, Max Error = 0.008047
#   Errors > 0.004: 312 / 17161 (1.82%)
# Epoch 3900: Loss = 0.002566, Max Error = 0.008843
#   Errors > 0.004: 314 / 17161 (1.83%)
# Epoch 4000: Loss = 0.002210, Max Error = 0.008558
#   Errors > 0.004: 150 / 17161 (0.87%)
# Epoch 4100: Loss = 0.002254, Max Error = 0.008436
#   Errors > 0.004: 184 / 17161 (1.07%)
# Epoch 4200: Loss = 0.001909, Max Error = 0.009060
#   Errors > 0.004: 269 / 17161 (1.57%)
# Epoch 4300: Loss = 0.002433, Max Error = 0.007966
#   Errors > 0.004: 135 / 17161 (0.79%)
# Epoch 4400: Loss = 0.001873, Max Error = 0.008064
#   Errors > 0.004: 193 / 17161 (1.12%)
# Epoch 4500: Loss = 0.001789, Max Error = 0.008311
#   Errors > 0.004: 125 / 17161 (0.73%)
# Epoch 4600: Loss = 0.001714, Max Error = 0.007177
#   Errors > 0.004: 140 / 17161 (0.82%)
# Epoch 4700: Loss = 0.002371, Max Error = 0.008236
#   Errors > 0.004: 253 / 17161 (1.47%)
# Epoch 4800: Loss = 0.001761, Max Error = 0.008711
#   Errors > 0.004: 141 / 17161 (0.82%)
# Epoch 4900: Loss = 0.001678, Max Error = 0.008442
#   Errors > 0.004: 169 / 17161 (0.98%)
# Epoch 5000: Loss = 0.002243, Max Error = 0.007435
#   Errors > 0.004: 120 / 17161 (0.70%)
# Epoch 5100: Loss = 0.001710, Max Error = 0.009100
#   Errors > 0.004: 293 / 17161 (1.71%)
# Epoch 5200: Loss = 0.001754, Max Error = 0.007442
#   Errors > 0.004: 111 / 17161 (0.65%)
# Epoch 5300: Loss = 0.001700, Max Error = 0.007946
#   Errors > 0.004: 112 / 17161 (0.65%)
# Epoch 5400: Loss = 0.002434, Max Error = 0.008093
#   Errors > 0.004: 192 / 17161 (1.12%)
# Epoch 5500: Loss = 0.001663, Max Error = 0.007328
#   Errors > 0.004: 148 / 17161 (0.86%)
# Epoch 5600: Loss = 0.001581, Max Error = 0.007651
#   Errors > 0.004: 119 / 17161 (0.69%)
# Epoch 5700: Loss = 0.001731, Max Error = 0.007949
#   Errors > 0.004: 132 / 17161 (0.77%)
# Epoch 5800: Loss = 0.002057, Max Error = 0.007894
#   Errors > 0.004: 157 / 17161 (0.91%)
# Epoch 5900: Loss = 0.001829, Max Error = 0.007350
#   Errors > 0.004: 124 / 17161 (0.72%)
# Epoch 6000: Loss = 0.001587, Max Error = 0.007794
#   Errors > 0.004: 132 / 17161 (0.77%)
# Epoch 6100: Loss = 0.002288, Max Error = 0.007695
#   Errors > 0.004: 162 / 17161 (0.94%)
# Epoch 6200: Loss = 0.001967, Max Error = 0.007836
#   Errors > 0.004: 115 / 17161 (0.67%)
# Epoch 6300: Loss = 0.001922, Max Error = 0.006896
#   Errors > 0.004: 100 / 17161 (0.58%)
# Epoch 6400: Loss = 0.001883, Max Error = 0.007376
#   Errors > 0.004: 129 / 17161 (0.75%)
# Epoch 6500: Loss = 0.001946, Max Error = 0.007358
#   Errors > 0.004: 118 / 17161 (0.69%)
# Epoch 6600: Loss = 0.002126, Max Error = 0.007655
#   Errors > 0.004: 103 / 17161 (0.60%)
# Epoch 6700: Loss = 0.001769, Max Error = 0.007570
#   Errors > 0.004: 103 / 17161 (0.60%)
# Epoch 6800: Loss = 0.002012, Max Error = 0.007170
#   Errors > 0.004: 135 / 17161 (0.79%)
# Epoch 6900: Loss = 0.002284, Max Error = 0.007239
#   Errors > 0.004: 134 / 17161 (0.78%)
# Epoch 7000: Loss = 0.001547, Max Error = 0.006726
#   Errors > 0.004: 83 / 17161 (0.48%)
# Epoch 7100: Loss = 0.001823, Max Error = 0.007214
#   Errors > 0.004: 93 / 17161 (0.54%)
# Epoch 7200: Loss = 0.001807, Max Error = 0.007842
#   Errors > 0.004: 128 / 17161 (0.75%)
# Epoch 7300: Loss = 0.001722, Max Error = 0.007424
#   Errors > 0.004: 117 / 17161 (0.68%)
# Epoch 7400: Loss = 0.001710, Max Error = 0.007126
#   Errors > 0.004: 87 / 17161 (0.51%)
# Epoch 7500: Loss = 0.001770, Max Error = 0.006496
#   Errors > 0.004: 102 / 17161 (0.59%)
# Epoch 7600: Loss = 0.002230, Max Error = 0.007367
#   Errors > 0.004: 138 / 17161 (0.80%)
# Epoch 7700: Loss = 0.001771, Max Error = 0.007336
#   Errors > 0.004: 324 / 17161 (1.89%)
# Epoch 7800: Loss = 0.001788, Max Error = 0.007395
#   Errors > 0.004: 91 / 17161 (0.53%)
# Epoch 7900: Loss = 0.001974, Max Error = 0.006668
#   Errors > 0.004: 74 / 17161 (0.43%)
# Epoch 8000: Loss = 0.001616, Max Error = 0.007185
#   Errors > 0.004: 108 / 17161 (0.63%)
# Epoch 8100: Loss = 0.001576, Max Error = 0.006962
#   Errors > 0.004: 66 / 17161 (0.38%)
# Epoch 8200: Loss = 0.001839, Max Error = 0.006611
#   Errors > 0.004: 117 / 17161 (0.68%)
# Epoch 8300: Loss = 0.001622, Max Error = 0.006560
#   Errors > 0.004: 61 / 17161 (0.36%)
# Epoch 8400: Loss = 0.001699, Max Error = 0.007197
#   Errors > 0.004: 61 / 17161 (0.36%)
# Epoch 8500: Loss = 0.001639, Max Error = 0.006743
#   Errors > 0.004: 64 / 17161 (0.37%)
# Epoch 8600: Loss = 0.001643, Max Error = 0.007064
#   Errors > 0.004: 63 / 17161 (0.37%)
# Epoch 8700: Loss = 0.001372, Max Error = 0.006537
#   Errors > 0.004: 60 / 17161 (0.35%)
# Epoch 8800: Loss = 0.001530, Max Error = 0.006963
#   Errors > 0.004: 59 / 17161 (0.34%)
# Epoch 8900: Loss = 0.001710, Max Error = 0.006103
#   Errors > 0.004: 51 / 17161 (0.30%)
# Epoch 9000: Loss = 0.001788, Max Error = 0.006072
#   Errors > 0.004: 67 / 17161 (0.39%)
# Epoch 9100: Loss = 0.001792, Max Error = 0.006726
#   Errors > 0.004: 67 / 17161 (0.39%)
# Epoch 9200: Loss = 0.001699, Max Error = 0.006110
#   Errors > 0.004: 64 / 17161 (0.37%)
# Epoch 9300: Loss = 0.001607, Max Error = 0.007243
#   Errors > 0.004: 79 / 17161 (0.46%)
# Epoch 9400: Loss = 0.001494, Max Error = 0.006035
#   Errors > 0.004: 54 / 17161 (0.31%)
# Epoch 9500: Loss = 0.001557, Max Error = 0.006345
#   Errors > 0.004: 62 / 17161 (0.36%)
# Epoch 9600: Loss = 0.001794, Max Error = 0.006423
#   Errors > 0.004: 56 / 17161 (0.33%)
# Epoch 9700: Loss = 0.001436, Max Error = 0.006298
#   Errors > 0.004: 49 / 17161 (0.29%)
# Epoch 9800: Loss = 0.001440, Max Error = 0.006521
#   Errors > 0.004: 50 / 17161 (0.29%)
# Epoch 9900: Loss = 0.001708, Max Error = 0.005997
#   Errors > 0.004: 46 / 17161 (0.27%)
# Epoch 10000: Loss = 0.001720, Max Error = 0.006900
#   Errors > 0.004: 55 / 17161 (0.32%)
# Epoch 10100: Loss = 0.001292, Max Error = 0.006546
#   Errors > 0.004: 54 / 17161 (0.31%)
# Epoch 10200: Loss = 0.001591, Max Error = 0.005990
#   Errors > 0.004: 41 / 17161 (0.24%)
# Epoch 10300: Loss = 0.001727, Max Error = 0.005882
#   Errors > 0.004: 49 / 17161 (0.29%)
# Epoch 10400: Loss = 0.001615, Max Error = 0.005883
#   Errors > 0.004: 57 / 17161 (0.33%)
# Epoch 10500: Loss = 0.001529, Max Error = 0.006987
#   Errors > 0.004: 51 / 17161 (0.30%)
# Epoch 10600: Loss = 0.001666, Max Error = 0.005801
#   Errors > 0.004: 52 / 17161 (0.30%)
# Epoch 10700: Loss = 0.001244, Max Error = 0.005517
#   Errors > 0.004: 41 / 17161 (0.24%)
# Epoch 10800: Loss = 0.001641, Max Error = 0.005783
#   Errors > 0.004: 64 / 17161 (0.37%)
# Epoch 10900: Loss = 0.001528, Max Error = 0.005853
#   Errors > 0.004: 36 / 17161 (0.21%)
# Epoch 11000: Loss = 0.001783, Max Error = 0.006104
#   Errors > 0.004: 59 / 17161 (0.34%)
# Epoch 11100: Loss = 0.001376, Max Error = 0.006128
#   Errors > 0.004: 62 / 17161 (0.36%)
# Epoch 11200: Loss = 0.001289, Max Error = 0.005813
#   Errors > 0.004: 51 / 17161 (0.30%)
# Epoch 11300: Loss = 0.001309, Max Error = 0.006171
#   Errors > 0.004: 39 / 17161 (0.23%)
# Epoch 11400: Loss = 0.001206, Max Error = 0.005619
#   Errors > 0.004: 30 / 17161 (0.17%)
# Epoch 11500: Loss = 0.001356, Max Error = 0.005923
#   Errors > 0.004: 44 / 17161 (0.26%)
# Epoch 11600: Loss = 0.001685, Max Error = 0.005984
#   Errors > 0.004: 55 / 17161 (0.32%)
# Epoch 11700: Loss = 0.001326, Max Error = 0.005909
#   Errors > 0.004: 28 / 17161 (0.16%)
# Epoch 11800: Loss = 0.001410, Max Error = 0.005580
#   Errors > 0.004: 39 / 17161 (0.23%)
# Epoch 11900: Loss = 0.001618, Max Error = 0.006516
#   Errors > 0.004: 23 / 17161 (0.13%)
# Epoch 12000: Loss = 0.001709, Max Error = 0.005604
#   Errors > 0.004: 49 / 17161 (0.29%)
# Epoch 12100: Loss = 0.001218, Max Error = 0.005630
#   Errors > 0.004: 15 / 17161 (0.09%)
# Epoch 12200: Loss = 0.001327, Max Error = 0.005384
#   Errors > 0.004: 41 / 17161 (0.24%)
# Epoch 12300: Loss = 0.001297, Max Error = 0.005793
#   Errors > 0.004: 44 / 17161 (0.26%)
# Epoch 12400: Loss = 0.001366, Max Error = 0.005893
#   Errors > 0.004: 29 / 17161 (0.17%)
# Epoch 12500: Loss = 0.001368, Max Error = 0.005816
#   Errors > 0.004: 14 / 17161 (0.08%)
# Epoch 12600: Loss = 0.001123, Max Error = 0.005772
#   Errors > 0.004: 28 / 17161 (0.16%)
# Epoch 12700: Loss = 0.001498, Max Error = 0.005686
#   Errors > 0.004: 45 / 17161 (0.26%)
# Epoch 12800: Loss = 0.001231, Max Error = 0.005952
#   Errors > 0.004: 18 / 17161 (0.10%)
# Epoch 12900: Loss = 0.001259, Max Error = 0.005314
#   Errors > 0.004: 10 / 17161 (0.06%)
# Epoch 13000: Loss = 0.001108, Max Error = 0.005995
#   Errors > 0.004: 10 / 17161 (0.06%)
# Epoch 13100: Loss = 0.001493, Max Error = 0.005718
#   Errors > 0.004: 32 / 17161 (0.19%)
# Epoch 13200: Loss = 0.001188, Max Error = 0.005616
#   Errors > 0.004: 12 / 17161 (0.07%)
# Epoch 13300: Loss = 0.001178, Max Error = 0.005772
#   Errors > 0.004: 15 / 17161 (0.09%)
# Epoch 13400: Loss = 0.001614, Max Error = 0.005724
#   Errors > 0.004: 36 / 17161 (0.21%)
# Epoch 13500: Loss = 0.001357, Max Error = 0.006589
#   Errors > 0.004: 13 / 17161 (0.08%)
# Epoch 13600: Loss = 0.001305, Max Error = 0.006763
#   Errors > 0.004: 18 / 17161 (0.10%)
# Epoch 13700: Loss = 0.001164, Max Error = 0.006302
#   Errors > 0.004: 14 / 17161 (0.08%)
# Epoch 13800: Loss = 0.001236, Max Error = 0.005528
#   Errors > 0.004: 26 / 17161 (0.15%)
# Epoch 13900: Loss = 0.001239, Max Error = 0.005499
#   Errors > 0.004: 11 / 17161 (0.06%)
# Epoch 14000: Loss = 0.001152, Max Error = 0.005887
#   Errors > 0.004: 10 / 17161 (0.06%)
# Epoch 14100: Loss = 0.001134, Max Error = 0.006298
#   Errors > 0.004: 12 / 17161 (0.07%)
# Epoch 14200: Loss = 0.001225, Max Error = 0.006307
#   Errors > 0.004: 8 / 17161 (0.05%)
# Epoch 14300: Loss = 0.001319, Max Error = 0.005984
#   Errors > 0.004: 13 / 17161 (0.08%)
# Epoch 14400: Loss = 0.001091, Max Error = 0.006056
#   Errors > 0.004: 10 / 17161 (0.06%)
# Epoch 14500: Loss = 0.001433, Max Error = 0.006819
#   Errors > 0.004: 8 / 17161 (0.05%)
# Epoch 14600: Loss = 0.001264, Max Error = 0.006560
#   Errors > 0.004: 8 / 17161 (0.05%)
# Epoch 14700: Loss = 0.001190, Max Error = 0.006605
#   Errors > 0.004: 4 / 17161 (0.02%)
# Epoch 14800: Loss = 0.001171, Max Error = 0.006367
#   Errors > 0.004: 7 / 17161 (0.04%)
# Epoch 14900: Loss = 0.001323, Max Error = 0.005932
#   Errors > 0.004: 24 / 17161 (0.14%)
# Epoch 15000: Loss = 0.001245, Max Error = 0.006880
#   Errors > 0.004: 7 / 17161 (0.04%)
# Epoch 15100: Loss = 0.001085, Max Error = 0.006204
#   Errors > 0.004: 6 / 17161 (0.03%)
# Epoch 15200: Loss = 0.001078, Max Error = 0.006166
#   Errors > 0.004: 15 / 17161 (0.09%)
# Epoch 15300: Loss = 0.001085, Max Error = 0.006469
#   Errors > 0.004: 7 / 17161 (0.04%)
# Epoch 15400: Loss = 0.001123, Max Error = 0.006855
#   Errors > 0.004: 2 / 17161 (0.01%)
# Epoch 15500: Loss = 0.001388, Max Error = 0.005860
#   Errors > 0.004: 15 / 17161 (0.09%)
# Epoch 15600: Loss = 0.001070, Max Error = 0.006090
#   Errors > 0.004: 9 / 17161 (0.05%)
# Epoch 15700: Loss = 0.001161, Max Error = 0.006322
#   Errors > 0.004: 8 / 17161 (0.05%)
# Epoch 15800: Loss = 0.001053, Max Error = 0.006259
#   Errors > 0.004: 5 / 17161 (0.03%)
# Epoch 15900: Loss = 0.001177, Max Error = 0.006485
#   Errors > 0.004: 9 / 17161 (0.05%)
# Epoch 16000: Loss = 0.001211, Max Error = 0.006710
#   Errors > 0.004: 7 / 17161 (0.04%)
# Epoch 16100: Loss = 0.001008, Max Error = 0.005947
#   Errors > 0.004: 5 / 17161 (0.03%)
# Epoch 16200: Loss = 0.001016, Max Error = 0.006229
#   Errors > 0.004: 6 / 17161 (0.03%)
# Epoch 16300: Loss = 0.000979, Max Error = 0.006606
#   Errors > 0.004: 2 / 17161 (0.01%)
# Epoch 16400: Loss = 0.001094, Max Error = 0.006236
#   Errors > 0.004: 7 / 17161 (0.04%)
# Epoch 16500: Loss = 0.001123, Max Error = 0.006305
#   Errors > 0.004: 5 / 17161 (0.03%)
# Epoch 16600: Loss = 0.001250, Max Error = 0.007134
#   Errors > 0.004: 6 / 17161 (0.03%)
# Epoch 16700: Loss = 0.001005, Max Error = 0.006059
#   Errors > 0.004: 5 / 17161 (0.03%)
# Epoch 16800: Loss = 0.001114, Max Error = 0.006781
#   Errors > 0.004: 8 / 17161 (0.05%)
# Epoch 16900: Loss = 0.001074, Max Error = 0.005798
#   Errors > 0.004: 4 / 17161 (0.02%)
# Epoch 17000: Loss = 0.000942, Max Error = 0.006163
#   Errors > 0.004: 7 / 17161 (0.04%)
# Epoch 17100: Loss = 0.001057, Max Error = 0.006381
#   Errors > 0.004: 5 / 17161 (0.03%)
# Epoch 17200: Loss = 0.001164, Max Error = 0.006008
#   Errors > 0.004: 4 / 17161 (0.02%)
# Epoch 17300: Loss = 0.001111, Max Error = 0.005771
#   Errors > 0.004: 6 / 17161 (0.03%)
# Epoch 17400: Loss = 0.001054, Max Error = 0.006379
#   Errors > 0.004: 4 / 17161 (0.02%)
# Epoch 17500: Loss = 0.000956, Max Error = 0.006432
#   Errors > 0.004: 4 / 17161 (0.02%)
# Epoch 17600: Loss = 0.001042, Max Error = 0.006611
#   Errors > 0.004: 5 / 17161 (0.03%)
# Epoch 17700: Loss = 0.001035, Max Error = 0.006268
#   Errors > 0.004: 4 / 17161 (0.02%)
# Epoch 17800: Loss = 0.001165, Max Error = 0.006388
#   Errors > 0.004: 7 / 17161 (0.04%)
# Epoch 17900: Loss = 0.000986, Max Error = 0.006821
#   Errors > 0.004: 9 / 17161 (0.05%)
# Epoch 18000: Loss = 0.000945, Max Error = 0.005817
#   Errors > 0.004: 4 / 17161 (0.02%)
# Early stopping at epoch 18003: loss and max error stopped improving.
#     Best loss: 0.0008392758900299668, Current loss: 0.0011679533636197448
#     Best max error: 0.004991497844457626, Current max error: 0.00544677022844553
# モデルは収束しました。訓練は 18003 エポックで停止しました。
# トレーニングデータの再構成誤差（平均）：0.001477573212221595
# トレーニングデータの再構成誤差（最大値）：0.005446786268556027
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=40, units_2=10, 試行回数=3, seed値 = 52
# Epoch 100: Loss = 0.021462, Max Error = 0.115069
#   Errors > 0.004: 17158 / 17161 (99.98%)
# Epoch 200: Loss = 0.015189, Max Error = 0.091143
#   Errors > 0.004: 17069 / 17161 (99.46%)
# Epoch 300: Loss = 0.009715, Max Error = 0.039210
#   Errors > 0.004: 16080 / 17161 (93.70%)
# Epoch 400: Loss = 0.008074, Max Error = 0.027776
#   Errors > 0.004: 15604 / 17161 (90.93%)
# Epoch 500: Loss = 0.006439, Max Error = 0.025748
#   Errors > 0.004: 13242 / 17161 (77.16%)
# Epoch 600: Loss = 0.006319, Max Error = 0.025856
#   Errors > 0.004: 11755 / 17161 (68.50%)
# Epoch 700: Loss = 0.006253, Max Error = 0.025887
#   Errors > 0.004: 11366 / 17161 (66.23%)
# Epoch 800: Loss = 0.006203, Max Error = 0.025884
#   Errors > 0.004: 11312 / 17161 (65.92%)
# Epoch 900: Loss = 0.006159, Max Error = 0.025877
#   Errors > 0.004: 11193 / 17161 (65.22%)
# Epoch 1000: Loss = 0.006116, Max Error = 0.025887
#   Errors > 0.004: 11030 / 17161 (64.27%)
# Epoch 1100: Loss = 0.006078, Max Error = 0.025887
#   Errors > 0.004: 10988 / 17161 (64.03%)
# Epoch 1200: Loss = 0.006043, Max Error = 0.025865
#   Errors > 0.004: 11121 / 17161 (64.80%)
# Epoch 1300: Loss = 0.006007, Max Error = 0.025804
#   Errors > 0.004: 11466 / 17161 (66.81%)
# Epoch 1400: Loss = 0.005966, Max Error = 0.025791
#   Errors > 0.004: 11458 / 17161 (66.77%)
# Epoch 1500: Loss = 0.005936, Max Error = 0.025733
#   Errors > 0.004: 11012 / 17161 (64.17%)
# Epoch 1600: Loss = 0.005907, Max Error = 0.025687
#   Errors > 0.004: 10822 / 17161 (63.06%)
# Epoch 1700: Loss = 0.005879, Max Error = 0.025644
#   Errors > 0.004: 10680 / 17161 (62.23%)
# Epoch 1800: Loss = 0.005853, Max Error = 0.025602
#   Errors > 0.004: 10463 / 17161 (60.97%)
# Epoch 1900: Loss = 0.005827, Max Error = 0.025558
#   Errors > 0.004: 10341 / 17161 (60.26%)
# Epoch 2000: Loss = 0.005804, Max Error = 0.025363
#   Errors > 0.004: 11002 / 17161 (64.11%)
# Epoch 2100: Loss = 0.005782, Max Error = 0.025301
#   Errors > 0.004: 10527 / 17161 (61.34%)
# Epoch 2200: Loss = 0.005747, Max Error = 0.025335
#   Errors > 0.004: 10307 / 17161 (60.06%)
# Epoch 2300: Loss = 0.005738, Max Error = 0.025233
#   Errors > 0.004: 10721 / 17161 (62.47%)
# Epoch 2400: Loss = 0.005713, Max Error = 0.025283
#   Errors > 0.004: 10820 / 17161 (63.05%)
# Epoch 2500: Loss = 0.005691, Max Error = 0.025195
#   Errors > 0.004: 10494 / 17161 (61.15%)
# Epoch 2600: Loss = 0.005669, Max Error = 0.025078
#   Errors > 0.004: 10296 / 17161 (60.00%)
# Epoch 2700: Loss = 0.005646, Max Error = 0.024932
#   Errors > 0.004: 10273 / 17161 (59.86%)
# Epoch 2800: Loss = 0.005613, Max Error = 0.024736
#   Errors > 0.004: 9940 / 17161 (57.92%)
# Epoch 2900: Loss = 0.005576, Max Error = 0.024440
#   Errors > 0.004: 9457 / 17161 (55.11%)
# Epoch 3000: Loss = 0.005491, Max Error = 0.023534
#   Errors > 0.004: 9319 / 17161 (54.30%)
# Epoch 3100: Loss = 0.005208, Max Error = 0.020209
#   Errors > 0.004: 8614 / 17161 (50.20%)
# Epoch 3200: Loss = 0.004368, Max Error = 0.017544
#   Errors > 0.004: 5500 / 17161 (32.05%)
# Epoch 3300: Loss = 0.004086, Max Error = 0.017023
#   Errors > 0.004: 5119 / 17161 (29.83%)
# Epoch 3400: Loss = 0.004014, Max Error = 0.015947
#   Errors > 0.004: 5020 / 17161 (29.25%)
# Epoch 3500: Loss = 0.003935, Max Error = 0.014988
#   Errors > 0.004: 4987 / 17161 (29.06%)
# Epoch 3600: Loss = 0.003899, Max Error = 0.014355
#   Errors > 0.004: 4952 / 17161 (28.86%)
# Epoch 3700: Loss = 0.003904, Max Error = 0.014133
#   Errors > 0.004: 5076 / 17161 (29.58%)
# Epoch 3800: Loss = 0.003812, Max Error = 0.013975
#   Errors > 0.004: 4904 / 17161 (28.58%)
# Epoch 3900: Loss = 0.003798, Max Error = 0.013714
#   Errors > 0.004: 4641 / 17161 (27.04%)
# Epoch 4000: Loss = 0.003778, Max Error = 0.013484
#   Errors > 0.004: 4456 / 17161 (25.97%)
# Epoch 4100: Loss = 0.003763, Max Error = 0.013367
#   Errors > 0.004: 4446 / 17161 (25.91%)
# Epoch 4200: Loss = 0.003731, Max Error = 0.013290
#   Errors > 0.004: 4235 / 17161 (24.68%)
# Epoch 4300: Loss = 0.003712, Max Error = 0.013303
#   Errors > 0.004: 4105 / 17161 (23.92%)
# Epoch 4400: Loss = 0.003707, Max Error = 0.013351
#   Errors > 0.004: 4067 / 17161 (23.70%)
# Epoch 4500: Loss = 0.003683, Max Error = 0.013466
#   Errors > 0.004: 4051 / 17161 (23.61%)
# Epoch 4600: Loss = 0.003651, Max Error = 0.013503
#   Errors > 0.004: 3978 / 17161 (23.18%)
# Epoch 4700: Loss = 0.003605, Max Error = 0.013443
#   Errors > 0.004: 3918 / 17161 (22.83%)
# Epoch 4800: Loss = 0.003563, Max Error = 0.013582
#   Errors > 0.004: 3973 / 17161 (23.15%)
# Epoch 4900: Loss = 0.003494, Max Error = 0.013480
#   Errors > 0.004: 3766 / 17161 (21.95%)
# Epoch 5000: Loss = 0.003371, Max Error = 0.012855
#   Errors > 0.004: 3537 / 17161 (20.61%)
# Epoch 5100: Loss = 0.003175, Max Error = 0.011338
#   Errors > 0.004: 2960 / 17161 (17.25%)
# Epoch 5200: Loss = 0.002837, Max Error = 0.009949
#   Errors > 0.004: 2090 / 17161 (12.18%)
# Epoch 5300: Loss = 0.002474, Max Error = 0.009538
#   Errors > 0.004: 1304 / 17161 (7.60%)
# Epoch 5400: Loss = 0.002165, Max Error = 0.009366
#   Errors > 0.004: 671 / 17161 (3.91%)
# Epoch 5500: Loss = 0.002193, Max Error = 0.009161
#   Errors > 0.004: 495 / 17161 (2.88%)
# Epoch 5600: Loss = 0.002004, Max Error = 0.008667
#   Errors > 0.004: 396 / 17161 (2.31%)
# Epoch 5700: Loss = 0.001993, Max Error = 0.008369
#   Errors > 0.004: 415 / 17161 (2.42%)
# Epoch 5800: Loss = 0.001897, Max Error = 0.007687
#   Errors > 0.004: 193 / 17161 (1.12%)
# Epoch 5900: Loss = 0.002201, Max Error = 0.008167
#   Errors > 0.004: 416 / 17161 (2.42%)
# Epoch 6000: Loss = 0.001785, Max Error = 0.007576
#   Errors > 0.004: 163 / 17161 (0.95%)
# Epoch 6100: Loss = 0.001720, Max Error = 0.007435
#   Errors > 0.004: 105 / 17161 (0.61%)
# Epoch 6200: Loss = 0.002561, Max Error = 0.008449
#   Errors > 0.004: 283 / 17161 (1.65%)
# Epoch 6300: Loss = 0.001628, Max Error = 0.007335
#   Errors > 0.004: 92 / 17161 (0.54%)
# Epoch 6400: Loss = 0.002400, Max Error = 0.008034
#   Errors > 0.004: 157 / 17161 (0.91%)
# Epoch 6500: Loss = 0.002021, Max Error = 0.007399
#   Errors > 0.004: 104 / 17161 (0.61%)
# Epoch 6600: Loss = 0.001502, Max Error = 0.007633
#   Errors > 0.004: 175 / 17161 (1.02%)
# Epoch 6700: Loss = 0.001451, Max Error = 0.007631
#   Errors > 0.004: 97 / 17161 (0.57%)
# Epoch 6800: Loss = 0.002247, Max Error = 0.007119
#   Errors > 0.004: 63 / 17161 (0.37%)
# Epoch 6900: Loss = 0.002398, Max Error = 0.007600
#   Errors > 0.004: 167 / 17161 (0.97%)
# Epoch 7000: Loss = 0.001491, Max Error = 0.007546
#   Errors > 0.004: 88 / 17161 (0.51%)
# Epoch 7100: Loss = 0.002150, Max Error = 0.006990
#   Errors > 0.004: 68 / 17161 (0.40%)
# Epoch 7200: Loss = 0.001462, Max Error = 0.007648
#   Errors > 0.004: 84 / 17161 (0.49%)
# Epoch 7300: Loss = 0.001686, Max Error = 0.007097
#   Errors > 0.004: 72 / 17161 (0.42%)
# Epoch 7400: Loss = 0.001447, Max Error = 0.007167
#   Errors > 0.004: 47 / 17161 (0.27%)
# Epoch 7500: Loss = 0.001561, Max Error = 0.007240
#   Errors > 0.004: 49 / 17161 (0.29%)
# Epoch 7600: Loss = 0.001503, Max Error = 0.006887
#   Errors > 0.004: 66 / 17161 (0.38%)
# Epoch 7700: Loss = 0.001955, Max Error = 0.007204
#   Errors > 0.004: 63 / 17161 (0.37%)
# Epoch 7800: Loss = 0.001617, Max Error = 0.007045
#   Errors > 0.004: 50 / 17161 (0.29%)
# Epoch 7900: Loss = 0.001659, Max Error = 0.006562
#   Errors > 0.004: 31 / 17161 (0.18%)
# Epoch 8000: Loss = 0.001535, Max Error = 0.007101
# ...
#   Errors > 0.004: 27 / 17161 (0.16%)
# Epoch 7500: Loss = 0.001576, Max Error = 0.007135
#   Errors > 0.004: 58 / 17161 (0.34%)
# Epoch 7600: Loss = 0.001819, Max Error = 0.007266
#   Errors > 0.004: 60 / 17161 (0.35%)
# Epoch 7700: Loss = 0.001231, Max Error = 0.007995
#   Errors > 0.004: 26 / 17161 (0.15%)
# Epoch 7800: Loss = 0.001736, Max Error = 0.008073
#   Errors > 0.004: 52 / 17161 (0.30%)
# Epoch 7900: Loss = 0.001559, Max Error = 0.007923
#   Errors > 0.004: 41 / 17161 (0.24%)
# Epoch 8000: Loss = 0.001635, Max Error = 0.008781
#   Errors > 0.004: 35 / 17161 (0.20%)
# Epoch 8100: Loss = 0.001222, Max Error = 0.008218
#   Errors > 0.004: 20 / 17161 (0.12%)
# Epoch 8200: Loss = 0.001325, Max Error = 0.007764
#   Errors > 0.004: 30 / 17161 (0.17%)
# Epoch 8300: Loss = 0.001506, Max Error = 0.007928
#   Errors > 0.004: 18 / 17161 (0.10%)
# Epoch 8400: Loss = 0.001682, Max Error = 0.008227
#   Errors > 0.004: 25 / 17161 (0.15%)
# Epoch 8500: Loss = 0.001655, Max Error = 0.007383
#   Errors > 0.004: 65 / 17161 (0.38%)
# Epoch 8600: Loss = 0.001605, Max Error = 0.008624
#   Errors > 0.004: 27 / 17161 (0.16%)
# Epoch 8700: Loss = 0.001197, Max Error = 0.007854
#   Errors > 0.004: 19 / 17161 (0.11%)
# Epoch 8800: Loss = 0.001501, Max Error = 0.008074
#   Errors > 0.004: 23 / 17161 (0.13%)
# Epoch 8900: Loss = 0.001348, Max Error = 0.008311
#   Errors > 0.004: 22 / 17161 (0.13%)
# Epoch 9000: Loss = 0.001252, Max Error = 0.007865
#   Errors > 0.004: 18 / 17161 (0.10%)
# Epoch 9100: Loss = 0.001385, Max Error = 0.008476
#   Errors > 0.004: 21 / 17161 (0.12%)
# Epoch 9200: Loss = 0.001242, Max Error = 0.008583
#   Errors > 0.004: 16 / 17161 (0.09%)
# Epoch 9300: Loss = 0.001211, Max Error = 0.007930
#   Errors > 0.004: 20 / 17161 (0.12%)
# Epoch 9400: Loss = 0.001259, Max Error = 0.008457
#   Errors > 0.004: 13 / 17161 (0.08%)
# Epoch 9500: Loss = 0.001467, Max Error = 0.007420
#   Errors > 0.004: 35 / 17161 (0.20%)
# Epoch 9600: Loss = 0.001244, Max Error = 0.008170
#   Errors > 0.004: 21 / 17161 (0.12%)
# Epoch 9700: Loss = 0.001436, Max Error = 0.007686
#   Errors > 0.004: 21 / 17161 (0.12%)
# Epoch 9800: Loss = 0.001306, Max Error = 0.008089
#   Errors > 0.004: 14 / 17161 (0.08%)
# Epoch 9900: Loss = 0.001259, Max Error = 0.008103
#   Errors > 0.004: 15 / 17161 (0.09%)
# Epoch 10000: Loss = 0.001317, Max Error = 0.008315
#   Errors > 0.004: 17 / 17161 (0.10%)
# Epoch 10100: Loss = 0.001574, Max Error = 0.008322
#   Errors > 0.004: 12 / 17161 (0.07%)
# Epoch 10200: Loss = 0.001150, Max Error = 0.007788
#   Errors > 0.004: 16 / 17161 (0.09%)
# Epoch 10300: Loss = 0.001381, Max Error = 0.008240
#   Errors > 0.004: 13 / 17161 (0.08%)
# Epoch 10400: Loss = 0.001602, Max Error = 0.008449
#   Errors > 0.004: 18 / 17161 (0.10%)
# Epoch 10500: Loss = 0.001636, Max Error = 0.007585
#   Errors > 0.004: 42 / 17161 (0.24%)
# Epoch 10600: Loss = 0.001327, Max Error = 0.008390
#   Errors > 0.004: 21 / 17161 (0.12%)
# Epoch 10700: Loss = 0.001327, Max Error = 0.008093
#   Errors > 0.004: 22 / 17161 (0.13%)
# Epoch 10800: Loss = 0.001109, Max Error = 0.007752
#   Errors > 0.004: 22 / 17161 (0.13%)
# Epoch 10900: Loss = 0.001550, Max Error = 0.008606
#   Errors > 0.004: 13 / 17161 (0.08%)
# Epoch 11000: Loss = 0.001626, Max Error = 0.007579
#   Errors > 0.004: 29 / 17161 (0.17%)
# Epoch 11100: Loss = 0.001108, Max Error = 0.008158
#   Errors > 0.004: 13 / 17161 (0.08%)
# Epoch 11200: Loss = 0.001295, Max Error = 0.007763
#   Errors > 0.004: 10 / 17161 (0.06%)
# Epoch 11300: Loss = 0.001595, Max Error = 0.008560
#   Errors > 0.004: 13 / 17161 (0.08%)
# Epoch 11400: Loss = 0.001496, Max Error = 0.007951
#   Errors > 0.004: 17 / 17161 (0.10%)
# Epoch 11500: Loss = 0.001095, Max Error = 0.007918
#   Errors > 0.004: 9 / 17161 (0.05%)
# Epoch 11600: Loss = 0.001216, Max Error = 0.007389
#   Errors > 0.004: 12 / 17161 (0.07%)
# Epoch 11700: Loss = 0.001669, Max Error = 0.008282
#   Errors > 0.004: 11 / 17161 (0.06%)
# Epoch 11800: Loss = 0.001515, Max Error = 0.007717
#   Errors > 0.004: 23 / 17161 (0.13%)
# Epoch 11900: Loss = 0.001179, Max Error = 0.008734
#   Errors > 0.004: 15 / 17161 (0.09%)
# Epoch 12000: Loss = 0.001476, Max Error = 0.008362
#   Errors > 0.004: 16 / 17161 (0.09%)
# Epoch 12100: Loss = 0.001135, Max Error = 0.007819
#   Errors > 0.004: 12 / 17161 (0.07%)
# Epoch 12200: Loss = 0.001183, Max Error = 0.008227
#   Errors > 0.004: 12 / 17161 (0.07%)
# Epoch 12300: Loss = 0.001121, Max Error = 0.007635
#   Errors > 0.004: 19 / 17161 (0.11%)
# Epoch 12400: Loss = 0.001146, Max Error = 0.007744
#   Errors > 0.004: 11 / 17161 (0.06%)
# Epoch 12500: Loss = 0.001130, Max Error = 0.008011
#   Errors > 0.004: 10 / 17161 (0.06%)
# Epoch 12600: Loss = 0.001128, Max Error = 0.008174
#   Errors > 0.004: 9 / 17161 (0.05%)
# Epoch 12700: Loss = 0.001143, Max Error = 0.007409
#   Errors > 0.004: 15 / 17161 (0.09%)
# Epoch 12800: Loss = 0.001559, Max Error = 0.007833
#   Errors > 0.004: 12 / 17161 (0.07%)
# Epoch 12900: Loss = 0.001041, Max Error = 0.007583
#   Errors > 0.004: 9 / 17161 (0.05%)
# Epoch 13000: Loss = 0.001466, Max Error = 0.008373
#   Errors > 0.004: 11 / 17161 (0.06%)
# Epoch 13100: Loss = 0.001057, Max Error = 0.008140
#   Errors > 0.004: 12 / 17161 (0.07%)
# Epoch 13200: Loss = 0.001387, Max Error = 0.007950
#   Errors > 0.004: 14 / 17161 (0.08%)
# Epoch 13300: Loss = 0.001055, Max Error = 0.007540
#   Errors > 0.004: 10 / 17161 (0.06%)
# Epoch 13400: Loss = 0.001430, Max Error = 0.007699
#   Errors > 0.004: 16 / 17161 (0.09%)
# Epoch 13500: Loss = 0.001108, Max Error = 0.007724
#   Errors > 0.004: 10 / 17161 (0.06%)
# Epoch 13600: Loss = 0.001316, Max Error = 0.008005
#   Errors > 0.004: 12 / 17161 (0.07%)
# Epoch 13700: Loss = 0.001213, Max Error = 0.007767
#   Errors > 0.004: 9 / 17161 (0.05%)
# Epoch 13800: Loss = 0.001271, Max Error = 0.007539
#   Errors > 0.004: 10 / 17161 (0.06%)
# Epoch 13900: Loss = 0.001223, Max Error = 0.008053
#   Errors > 0.004: 11 / 17161 (0.06%)
# Epoch 14000: Loss = 0.001062, Max Error = 0.007664
#   Errors > 0.004: 9 / 17161 (0.05%)
# Epoch 14100: Loss = 0.000976, Max Error = 0.007832
#   Errors > 0.004: 11 / 17161 (0.06%)
# Epoch 14200: Loss = 0.001035, Max Error = 0.007381
#   Errors > 0.004: 9 / 17161 (0.05%)
# Epoch 14300: Loss = 0.001170, Max Error = 0.007653
#   Errors > 0.004: 9 / 17161 (0.05%)
# Epoch 14400: Loss = 0.000990, Max Error = 0.007695
#   Errors > 0.004: 9 / 17161 (0.05%)
# Early stopping at epoch 14486: loss and max error stopped improving.
#     Best loss: 0.0009122746414504945, Current loss: 0.0011118934489786625
#     Best max error: 0.006395153235644102, Current max error: 0.007928968407213688
# モデルは収束しました。訓練は 14486 エポックで停止しました。
# トレーニングデータの再構成誤差（平均）：0.001077219996785946
# トレーニングデータの再構成誤差（最大値）：0.007929055861720201
# 結果: units_1_3=40, units_2=10,この時の再構成誤差：0.0006807127535085343
# 1回目の期間のモデル作成終了
# 537/537 ━━━━━━━━━━━━━━━━━━━━ 0s 468us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 最も再構成誤差が大きかったインデックス番号：7624
# 学習データの中に外れ値が発見されたので以降ではモデルの学習を行いません
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 1期間での結果の概要
# トレーニングデータに対する再構成誤差の最大値かつ閾値
# 0.005089522277284484
# トレーニングデータに対する再構成誤差:0.0006807127535085343
# トレーニングデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.000268
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.000359
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.000637
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.000610
# processor_unit_units_status_cpu_board_cpu_core_temp    0.000397
# processor_unit_units_status_cpu_board_gpu_core_temp    0.000435
# processor_unit_units_status_cpu_board_cpu_core_vol     0.000497
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.000274
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.000309
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.000494
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.001361
# dtype: float64
# テストデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.000766
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.000413
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.001459
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.000880
# processor_unit_units_status_cpu_board_cpu_core_temp    0.000728
# processor_unit_units_status_cpu_board_gpu_core_temp    0.000593
# processor_unit_units_status_cpu_board_cpu_core_vol     0.000681
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.000501
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.000508
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.004742
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.001781
# dtype: float64
# 閾値データの各特徴量ごとの再構成誤差
# processor_unit_units_status_cpu_board_cpu_fan          0.000644
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.001662
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.001778
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.001460
# processor_unit_units_status_cpu_board_cpu_core_temp    0.000372
# processor_unit_units_status_cpu_board_gpu_core_temp    0.001401
# processor_unit_units_status_cpu_board_cpu_core_vol     0.001447
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.000092
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.016430
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.000873
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.001248
# Name: 7624, dtype: float64
# trainの日付の最大値:2018/6/01 00:00:00
# testの日付の最大値:2018/7/01 00:00:00
# 異常値と閾値の保存
# =====================================================================================
# 2回目の期間のモデル
# 該当期間の確認
# はじまり(train)2016/7/01 00:00:00
# 終わり(train)2018/7/01 00:00:00
# はじまり(test)2018/7/01 00:00:00
# 終わり(test)2018/8/01 00:00:00
# 2回目の期間のモデル作成開始
# 2回目の期間のトレーニングデータ数:17141
# 2回目の期間においてはすでにあるモデルを使用します
# 196/536 ━━━━━━━━━━━━━━━━━━━━ 0s 513us/step
# c:\Users\keisu\Desktop\研究元ファイル\abnormal\research_abnormal\src\model\model_single_node_fixed_maxaverage_learning_max_stop.py:167: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   abnormal_scores = pd.concat([abnormal_scores,abnormal_score_df])
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 0s 458us/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 最も再構成誤差が大きかったインデックス番号：16874
# 次の期間でも学習を続けます
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2期間での結果の概要
# トレーニングデータに対する再構成誤差の最大値かつ閾値
# 0.005089522277284484
# トレーニングデータに対する再構成誤差:0.0006807127535085343
# トレーニングデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.000268
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.000359
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.000637
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.000610
# processor_unit_units_status_cpu_board_cpu_core_temp    0.000397
# processor_unit_units_status_cpu_board_gpu_core_temp    0.000435
# processor_unit_units_status_cpu_board_cpu_core_vol     0.000497
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.000274
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.000309
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.000494
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.001361
# dtype: float64
# テストデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.001278
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.000486
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.002184
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.001345
# processor_unit_units_status_cpu_board_cpu_core_temp    0.001407
# processor_unit_units_status_cpu_board_gpu_core_temp    0.000663
# processor_unit_units_status_cpu_board_cpu_core_vol     0.000684
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.000744
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.000654
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.008621
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.002370
# dtype: float64
# 閾値データの各特徴量ごとの再構成誤差
# processor_unit_units_status_cpu_board_cpu_fan          0.000644
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.001662
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.001778
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.001460
# processor_unit_units_status_cpu_board_cpu_core_temp    0.000372
# processor_unit_units_status_cpu_board_gpu_core_temp    0.001401
# processor_unit_units_status_cpu_board_cpu_core_vol     0.001447
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.000092
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.016430
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.000873
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.001248
# Name: 7624, dtype: float64
# trainの日付の最大値:2018/7/01 00:00:00
# testの日付の最大値:2018/8/01 00:00:00
# 異常値と閾値の保存
# =====================================================================================
# 3回目の期間のモデル
# 該当期間の確認
# はじまり(train)2016/8/01 00:00:00
# 終わり(train)2018/8/01 00:00:00
# はじまり(test)2018/8/01 00:00:00
# 終わり(test)2018/9/01 00:00:00
# 3回目の期間のモデル作成開始
# 3回目の期間のトレーニングデータ数:17129
# 3回目の期間においてはすでにあるモデルを使用します
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 0s 421us/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step
# 最も再構成誤差が大きかったインデックス番号：17111
# 次の期間でも学習を続けます
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 3期間での結果の概要
# トレーニングデータに対する再構成誤差の最大値かつ閾値
# 0.005089522277284484
# トレーニングデータに対する再構成誤差:0.0006807127535085343
# トレーニングデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.000268
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.000359
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.000637
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.000610
# processor_unit_units_status_cpu_board_cpu_core_temp    0.000397
# processor_unit_units_status_cpu_board_gpu_core_temp    0.000435
# processor_unit_units_status_cpu_board_cpu_core_vol     0.000497
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.000274
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.000309
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.000494
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.001361
# dtype: float64
# テストデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.022767
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.001910
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.081604
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.015531
# processor_unit_units_status_cpu_board_cpu_core_temp    0.013321
# processor_unit_units_status_cpu_board_gpu_core_temp    0.002251
# processor_unit_units_status_cpu_board_cpu_core_vol     0.002730
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.005035
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.016524
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.257407
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.050915
# dtype: float64
# 閾値データの各特徴量ごとの再構成誤差
# processor_unit_units_status_cpu_board_cpu_fan          0.000644
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.001662
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.001778
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.001460
# processor_unit_units_status_cpu_board_cpu_core_temp    0.000372
# processor_unit_units_status_cpu_board_gpu_core_temp    0.001401
# processor_unit_units_status_cpu_board_cpu_core_vol     0.001447
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.000092
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.016430
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.000873
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.001248
# Name: 7624, dtype: float64
# trainの日付の最大値:2018/8/01 00:00:00
# testの日付の最大値:2018/9/01 00:00:00
# 異常値と閾値の保存
# data_exの日付の最大値:2019-02-04 23:00:02
# data_exのデータ数:26425
# data_exの最終月に含まれるデータ数:96
# 実行時間: 20767.354727 秒
