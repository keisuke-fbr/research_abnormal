# %% [markdown]
# ライブラリの呼び出し

# %%
import sys
import os

# 現在の作業ディレクトリを基にプロジェクトのルートディレクトリを設定
project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..','..','..'))
sys.path.append(project_root)
print(project_root)
# Out:
# c:\Users\keisu\Desktop\研究元ファイル\abnormal\research_abnormal

# %%
#必要ライブラリのインストール
from src import data
from src.model import model_single_node_fixed_maxaverage_learning_max_stop
import config

# %%
#モジュールの再リロード
import importlib
import custom_class.custom_learning_average_stopping_maxdata_max_stop
import src
import src.data
import src.model
import src.model.model_single_node_fixed_maxaverage_learning_max_stop
import src.model_basic_single_node_fixed_maxaverage_learning_max_stop
import custom_class.custom_learning_average_stopping_maxdata_max_stop

importlib.reload(src.data)
importlib.reload(custom_class.custom_learning_average_stopping_maxdata_max_stop)
importlib.reload(src.model.model_single_node_fixed_maxaverage_learning_max_stop)
importlib.reload(src.model_basic_single_node_fixed_maxaverage_learning_max_stop)
# Out:
# <module 'src.model_basic_single_node_fixed_maxaverage_learning_max_stop' from 'c:\\Users\\keisu\\Desktop\\研究元ファイル\\abnormal\\research_abnormal\\src\\model_basic_single_node_fixed_maxaverage_learning_max_stop.py'>

# %% [markdown]
# データの読み込み

# %%
#データの読み込み及び加工、コラムリストの取得
data_ex, data_original = data.data_complete()
# Out:
# キャッシュファイルからデータを読み込みます

# %% [markdown]
# ハイパーパラメータの設定

# %%
#ハイパーパラメータの設定

#最大エポック数
max_epochs = 100000

#ノード数
units = 11

#モデル決定の閾値（再構成誤差のパラメータ）
#この閾値を下回ることで十分な性能を持つモデルとする
#今回は使用しない
error_threshold = 1

# シード値の準備
seeds = [50,51,52,53]

# ユニット数の準備
unit13_1 = 40
unit2_1 = 10
unit13_2 = 30
unit2_2 = 5
unit13_3 = 20
unit2_3 = 2

units = [[unit13_1, unit2_1],[unit13_2, unit2_2],[unit13_3, unit2_3]]

# 学習バッチサイズ
batch_size=64

# 監視するエポック数
patience = 1

# 学習変化の閾値
min_delta = 1

# 最大データの監視するエポック
patience_max = 1

# 最大データの閾値
min_delta_max = 1

# 何期間連続して予測を行うか
num = 3

#　初期化回数
num_retry = 4

#　詳細な出力
detail_log = True

#　どこまでの値より大きいデータ点をログの中で数えるか
confirm_datapoint = 0.004

#学習率
learning_rate = 1e-3

#トレーニング開始日
train_start = "2016/6/01 00:00:00"

#テスト開始日
test_start = "2018/6/01 00:00:00"



params = {"max_epochs":max_epochs, "units":units,
	"error_threshold":error_threshold, "seeds":seeds, "units":units, 
	"batch_size":batch_size, "patience":patience, "min_delta": min_delta, "patience_max":patience_max, "min_delta_max" : min_delta_max, "num":num, "train_start" : train_start, "test_start" : test_start,
    "num_retry": num_retry, "detail_log":detail_log, "confirm_datapoint":confirm_datapoint, "learning_rate":learning_rate}

# %%
#実験の実行及び結果の格納
abnormal_scores, thresholds = model_single_node_fixed_maxaverage_learning_max_stop.result(data_ex , params)
# Out:
# =====================================================================================
# 1回目の期間のモデル
# 該当期間の確認
# はじまり(train)2016/6/01 00:00:00
# 終わり(train)2018/6/01 00:00:00
# はじまり(test)2018/6/01 00:00:00
# 終わり(test)2018/7/01 00:00:00
# 1回目の期間のモデル作成開始
# 1回目の期間のトレーニングデータ数:17161
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=40, units_2=10, 試行回数=1, seed値 = 50
# Early stopping at epoch 2: loss and max error stopped improving.
#     Best loss: 0.2266014963388443, Current loss: 0.14176960289478302
#     Best max error: 0.4058353900909424, Current max error: 0.3702999949455261
# モデルは収束しました。訓練は 2 エポックで停止しました。
# トレーニングデータの再構成誤差（平均）：0.15044891199115387
# トレーニングデータの再構成誤差（最大値）：0.37029998269786335
# モデルの更新: シード値=50
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=40, units_2=10, 試行回数=2, seed値 = 51
# Early stopping at epoch 2: loss and max error stopped improving.
#     Best loss: 0.24965885281562805, Current loss: 0.141127809882164
#     Best max error: 0.43352577090263367, Current max error: 0.3680386245250702
# モデルは収束しました。訓練は 2 エポックで停止しました。
# トレーニングデータの再構成誤差（平均）：0.14950615571635884
# トレーニングデータの再構成誤差（最大値）：0.36803861079746264
# モデルの更新: シード値=51
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=40, units_2=10, 試行回数=3, seed値 = 52
# Early stopping at epoch 2: loss and max error stopped improving.
#     Best loss: 0.24840369820594788, Current loss: 0.14153949916362762
#     Best max error: 0.42432376742362976, Current max error: 0.36398833990097046
# モデルは収束しました。訓練は 2 エポックで停止しました。
# トレーニングデータの再構成誤差（平均）：0.14988834807747584
# トレーニングデータの再構成誤差（最大値）：0.36398837175955284
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=40, units_2=10, 試行回数=4, seed値 = 53
# Early stopping at epoch 2: loss and max error stopped improving.
#     Best loss: 0.1755630224943161, Current loss: 0.1418844610452652
#     Best max error: 0.37929800152778625, Current max error: 0.361427366733551
# モデルは収束しました。訓練は 2 エポックで停止しました。
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 2
#       1 #実験の実行及び結果の格納
# ----> 2 abnormal_scores, thresholds = model_single_node_fixed_maxaverage_learning_max_stop.result(data_ex , params)
#
# File c:\Users\keisu\Desktop\研究元ファイル\abnormal\research_abnormal\src\model\model_single_node_fixed_maxaverage_learning_max_stop.py:111, in result(data_ex, params)
#     106 #モデルの作成およびモデル学習
#     107
#     108 # 再学習の必要がある場合のみ学習を行う
#     109 if flag_skip == 0:
#     110     #各実験ごとの学習済みモデルと各特徴量ごとの学習過程配列が返される
# --> 111     model = model_basic_single_node_fixed_maxaverage_learning_max_stop.single_model(params,train_data,period)
#     113     print(str(period+1) + "回目の期間のモデル作成終了")
#     115 else:
#
# File c:\Users\keisu\Desktop\研究元ファイル\abnormal\research_abnormal\src\model_basic_single_node_fixed_maxaverage_learning_max_stop.py:242, in single_model(params, train_data, period)
#     240 model = learn_model(params, model , train_data)
#     241 #トレーニングデータの再構成誤差の計算
# --> 242 train_predict = model.predict(train_data, verbose = 0)
#     243 train_errors = root_mean_squared_error(train_data, train_predict)
#     244 train_errors_max = root_mean_squared_error_per_data(train_data, train_predict).numpy().max()
#
# File c:\Users\keisu\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\keisu\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:510, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     508 callbacks.on_predict_batch_begin(step)
#     509 data = get_data(iterator)
# --> 510 batch_outputs = self.predict_function(data)
#     511 outputs = append_to_outputs(batch_outputs, outputs)
#     512 callbacks.on_predict_batch_end(step, {"outputs": batch_outputs})
#
# File c:\Users\keisu\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\keisu\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\keisu\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File c:\Users\keisu\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\keisu\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\keisu\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\keisu\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\keisu\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\context.py:1552, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1550 cancellation_context = cancellation.context()
#    1551 if cancellation_context is None:
# -> 1552   outputs = execute.execute(
#    1553       name.decode("utf-8"),
#    1554       num_outputs=num_outputs,
#    1555       inputs=tensor_inputs,
#    1556       attrs=attrs,
#    1557       ctx=self,
#    1558   )
#    1559 else:
#    1560   outputs = execute.execute_with_cancellation(
#    1561       name.decode("utf-8"),
#    1562       num_outputs=num_outputs,
#    (...)
#    1566       cancellation_manager=cancellation_context,
#    1567   )
#
# File c:\Users\keisu\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:
