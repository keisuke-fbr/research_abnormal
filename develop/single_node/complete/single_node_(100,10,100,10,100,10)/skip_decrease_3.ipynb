# %% [markdown]
# ライブラリの呼び出し

# %%
import sys
import os

# 現在の作業ディレクトリを基にプロジェクトのルートディレクトリを設定
project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..','..','..'))
sys.path.append(project_root)
print(project_root)
# Out:
# c:\Users\keisu\Desktop\研究元ファイル\abnormal\research_abnormal

# %%
#必要ライブラリのインストール
from src import data
from src import model_basic_single_node
from src.model import model_search_single_node
import config

# %%
#モジュールの再リロード
import importlib
import src
import src.data
import src.model_basic_single_node

importlib.reload(src.data)
importlib.reload(src.model_basic_single_node)
# Out:
# <module 'src.model_basic_single_node' from 'c:\\Users\\keisu\\Desktop\\研究元ファイル\\abnormal\\research_abnormal\\src\\model_basic_single_node.py'>

# %% [markdown]
# データの読み込み

# %%
#データの読み込み及び加工、コラムリストの取得
data_ex, data_original = data.data_complete()
# Out:
# キャッシュファイルからデータを読み込みます

# %% [markdown]
# ハイパーパラメータの設定

# %%
#ハイパーパラメータの設定

#最大エポック数
max_epochs = 100000

#ノード数
units = 11

#モデル決定の閾値（再構成誤差のパラメータ）
#この閾値を下回ることで十分な性能を持つモデルとする
#今回は使用しない
error_threshold = 0.001

# シード値の準備
seeds = [50,51,52,53]

# ユニット数の準備
unit13 = 100
unit2 = 10

# 学習バッチサイズ
batch_size=64

# 監視するエポック数
patience = 1000

# 学習変化の閾値
min_delta = 1e-10

# 何期間連続して予測を行うか
num = 1

#　初期化回数
num_retry = 4

#　詳細な出力
detail_log = 0

#学習率
learning_rate = 1e-3

#トレーニング開始日
train_start = "2016/8/01 00:00:00"

params = {"max_epochs":max_epochs, "units":units,
	"error_threshold":error_threshold, "seeds":seeds, "unit13": unit13, "unit2" : unit2, 
	"batch_size":batch_size, "patience":patience, "min_delta": min_delta, "num":num, "train_start" : train_start,
    "num_retry": num_retry, "detail_log":detail_log, "learning_rate":learning_rate}

# %%
#実験の実行及び結果の格納
abnormal_scores, thresholds,  reconstraction_train_per_features, reconstraction_test_per_features, thresholds_per_features = model_search_single_node.result(data_ex , params)
# Out:
# =====================================================================================
# 1回目の期間のモデル
# 該当期間の確認
# はじまり(train)2016/8/01 00:00:00
# 終わり(train)2018/8/01 00:00:00
# はじまり(test)2018/8/01 00:00:00
# 終わり(test)2018/9/01 00:00:00
# 1回目の期間のモデル作成開始
# 1回目の期間のトレーニングデータ数:17129
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=100, units_2=10, 試行回数=1, seed値 = 50
# c:\Users\keisu\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# モデルは収束しました。訓練は 25103 エポックで停止しました。
# トレーニングデータの再構成誤差：0.0005279085466384601
# モデルの更新: シード値=50
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=100, units_2=10, 試行回数=2, seed値 = 51
# モデルは収束しました。訓練は 13844 エポックで停止しました。
# トレーニングデータの再構成誤差：0.0007692149247035342
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=100, units_2=10, 試行回数=3, seed値 = 52
# モデルは収束しました。訓練は 13837 エポックで停止しました。
# トレーニングデータの再構成誤差：0.0006621380990095717
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=100, units_2=10, 試行回数=4, seed値 = 53
# モデルは収束しました。訓練は 21507 エポックで停止しました。
# トレーニングデータの再構成誤差：0.0006566805085069216
# 結果: units_1_3=100, units_2=10,この時の再構成誤差：0.0005279085466384601
# 1回目の期間のモデル作成終了
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step
# 最も再構成誤差が大きかったインデックス番号：11979
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 1期間での結果の概要
# 閾値：0.00399305564344709
# トレーニングデータに対する再構成誤差:0.0005279085466384601
# トレーニングデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.000404
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.000309
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.000388
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.000553
# processor_unit_units_status_cpu_board_cpu_core_temp    0.000222
# processor_unit_units_status_cpu_board_gpu_core_temp    0.000705
# processor_unit_units_status_cpu_board_cpu_core_vol     0.000403
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.000284
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.000334
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.000246
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.000598
# dtype: float64
# テストデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.000969
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.000447
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.005044
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.001340
# processor_unit_units_status_cpu_board_cpu_core_temp    0.001612
# processor_unit_units_status_cpu_board_gpu_core_temp    0.000697
# processor_unit_units_status_cpu_board_cpu_core_vol     0.000851
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.001219
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.000677
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.001186
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.002248
# dtype: float64
# 閾値データの各特徴量ごとの再構成誤差
# processor_unit_units_status_cpu_board_cpu_fan          0.001553
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.002840
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.006688
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.006096
# processor_unit_units_status_cpu_board_cpu_core_temp    0.007185
# processor_unit_units_status_cpu_board_gpu_core_temp    0.003006
# processor_unit_units_status_cpu_board_cpu_core_vol     0.002878
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.001912
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.000494
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.000108
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.003188
# Name: 11979, dtype: float64
# trainの日付の最大値:2018/8/01 00:00:00
# testの日付の最大値:2018/9/01 00:00:00
# data_exの日付の最大値:2019-02-04 23:00:02
# data_exのデータ数:26425
# data_exの最終月に含まれるデータ数:96
# 異常値と閾値の保存
# c:\Users\keisu\Desktop\研究元ファイル\abnormal\research_abnormal\src\model\model_search_single_node.py:136: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   abnormal_scores = pd.concat([abnormal_scores,abnormal_score_df])
