# %% [markdown]
# ライブラリの呼び出し

# %%
import sys
import os

# 現在の作業ディレクトリを基にプロジェクトのルートディレクトリを設定
project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..','..','..'))
sys.path.append(project_root)
print(project_root)
# Out:
# c:\Users\keisu\Desktop\研究元ファイル\abnormal\research_abnormal

# %%
#必要ライブラリのインストール
from src import data
from src.model import model_search_single_node_fixed_learning_data
import config

# %%
#モジュールの再リロード
import importlib
import src
import src.data
import src.model
import src.model.model_search_single_node_fixed_learning_data
import src.model_basic_single_node_fixed_learning_data

importlib.reload(src.data)
importlib.reload(src.model.model_search_single_node_fixed_learning_data)
importlib.reload(src.model_basic_single_node_fixed_learning_data)
# Out:
# <module 'src.model_basic_single_node_fixed_learning_data' from 'c:\\Users\\keisu\\Desktop\\研究元ファイル\\abnormal\\research_abnormal\\src\\model_basic_single_node_fixed_learning_data.py'>

# %% [markdown]
# データの読み込み

# %%
#データの読み込み及び加工、コラムリストの取得
data_ex, data_original = data.data_complete()
# Out:
# キャッシュファイルからデータを読み込みます

# %% [markdown]
# ハイパーパラメータの設定

# %%
#ハイパーパラメータの設定

#最大エポック数
max_epochs = 100000

#ノード数
units = 11

#モデル決定の閾値（再構成誤差のパラメータ）
#この閾値を下回ることで十分な性能を持つモデルとする
#今回は使用しない
error_threshold = 1

# シード値の準備
seeds = [50,51,52,53]

# ユニット数の準備
unit13_1 = 41
unit2_1 = 10
unit13_2 = 32
unit2_2 = 10
unit13_3 = 44
unit2_3 = 10

units = [[unit13_1, unit2_1],[unit13_2, unit2_2],[unit13_3, unit2_3]]

# 学習バッチサイズ
batch_size=64

# 監視するエポック数
patience = 1000

# 学習変化の閾値
min_delta = 1e-10

# 何期間連続して予測を行うか
num = 3

#　初期化回数
num_retry = 4

#　詳細な出力
detail_log = 0

#学習率
learning_rate = 1e-3

#トレーニング開始日
train_start = "2016/6/01 00:00:00"

#テスト開始日
test_start = "2018/6/01 00:00:00"

params = {"max_epochs":max_epochs, "units":units,
	"error_threshold":error_threshold, "seeds":seeds, "units":units, 
	"batch_size":batch_size, "patience":patience, "min_delta": min_delta, "num":num, "train_start" : train_start, "test_start" : test_start,
    "num_retry": num_retry, "detail_log":detail_log, "learning_rate":learning_rate}

# %%
#実験の実行及び結果の格納
abnormal_scores, thresholds = model_search_single_node_fixed_learning_data.result(data_ex , params)
# Out:
# =====================================================================================
# 1回目の期間のモデル
# 該当期間の確認
# はじまり(train)2016/6/01 00:00:00
# 終わり(train)2018/6/01 00:00:00
# はじまり(test)2018/6/01 00:00:00
# 終わり(test)2018/7/01 00:00:00
# 1回目の期間のモデル作成開始
# 1回目の期間のトレーニングデータ数:17161
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=41, units_2=10, 試行回数=1, seed値 = 50
# c:\Users\keisu\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# モデルは収束しました。訓練は 18879 エポックで停止しました。
# トレーニングデータの再構成誤差（平均）：0.0007201042755408912
# トレーニングデータの再構成誤差（最大値）：0.005422438982291691
# モデルの更新: シード値=50
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=41, units_2=10, 試行回数=2, seed値 = 51
# モデルは収束しました。訓練は 13360 エポックで停止しました。
# トレーニングデータの再構成誤差（平均）：0.0032655924398401
# トレーニングデータの再構成誤差（最大値）：0.013522587945313247
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=41, units_2=10, 試行回数=3, seed値 = 52
# モデルは収束しました。訓練は 15390 エポックで停止しました。
# トレーニングデータの再構成誤差（平均）：0.0015030996089675066
# トレーニングデータの再構成誤差（最大値）：0.005156858577303679
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=41, units_2=10, 試行回数=4, seed値 = 53
# モデルは収束しました。訓練は 9258 エポックで停止しました。
# トレーニングデータの再構成誤差（平均）：0.0011158617062351612
# トレーニングデータの再構成誤差（最大値）：0.013582500017122856
# 結果: units_1_3=41, units_2=10,この時の再構成誤差：0.0007201042755408912
# 1回目の期間のモデル作成終了
# 537/537 ━━━━━━━━━━━━━━━━━━━━ 0s 470us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 500us/step
# 最も再構成誤差が大きかったインデックス番号：6319
# 学習データの中に外れ値が発見されたので以降ではモデルの学習を行いません
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 1期間での結果の概要
# トレーニングデータに対する再構成誤差の最大値かつ閾値
# 0.005422438982291691
# トレーニングデータに対する再構成誤差:0.0007201042755408912
# トレーニングデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.000345
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.000729
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.000577
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.000293
# processor_unit_units_status_cpu_board_cpu_core_temp    0.001318
# processor_unit_units_status_cpu_board_gpu_core_temp    0.000353
# processor_unit_units_status_cpu_board_cpu_core_vol     0.000339
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.000607
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.000347
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.000425
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.000673
# dtype: float64
# テストデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.001077
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.000793
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.005188
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.000943
# processor_unit_units_status_cpu_board_cpu_core_temp    0.001630
# processor_unit_units_status_cpu_board_gpu_core_temp    0.000598
# processor_unit_units_status_cpu_board_cpu_core_vol     0.000408
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.000634
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.000763
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.013543
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.002304
# dtype: float64
# 閾値データの各特徴量ごとの再構成誤差
# processor_unit_units_status_cpu_board_cpu_fan          0.005640
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.015246
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.000209
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.005193
# processor_unit_units_status_cpu_board_cpu_core_temp    0.001962
# processor_unit_units_status_cpu_board_gpu_core_temp    0.004535
# processor_unit_units_status_cpu_board_cpu_core_vol     0.000332
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.002033
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.001738
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.000282
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.000643
# Name: 6319, dtype: float64
# trainの日付の最大値:2018/6/01 00:00:00
# testの日付の最大値:2018/7/01 00:00:00
# 異常値と閾値の保存
# =====================================================================================
# 2回目の期間のモデル
# 該当期間の確認
# はじまり(train)2016/7/01 00:00:00
# 終わり(train)2018/7/01 00:00:00
# はじまり(test)2018/7/01 00:00:00
# 終わり(test)2018/8/01 00:00:00
# 2回目の期間のモデル作成開始
# 2回目の期間のトレーニングデータ数:17141
# 2回目の期間においてはすでにあるモデルを使用します
# 224/536 ━━━━━━━━━━━━━━━━━━━━ 0s 453us/step
# c:\Users\keisu\Desktop\研究元ファイル\abnormal\research_abnormal\src\model\model_search_single_node_fixed_learning_data.py:163: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   abnormal_scores = pd.concat([abnormal_scores,abnormal_score_df])
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 0s 442us/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step
# 最も再構成誤差が大きかったインデックス番号：16870
# 次の期間でも学習を続けます
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2期間での結果の概要
# トレーニングデータに対する再構成誤差の最大値かつ閾値
# 0.005422438982291691
# トレーニングデータに対する再構成誤差:0.0007201042755408912
# トレーニングデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.000345
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.000729
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.000577
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.000293
# processor_unit_units_status_cpu_board_cpu_core_temp    0.001318
# processor_unit_units_status_cpu_board_gpu_core_temp    0.000353
# processor_unit_units_status_cpu_board_cpu_core_vol     0.000339
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.000607
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.000347
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.000425
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.000673
# dtype: float64
# テストデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.001244
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.001059
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.006727
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.001317
# processor_unit_units_status_cpu_board_cpu_core_temp    0.001618
# processor_unit_units_status_cpu_board_gpu_core_temp    0.000600
# processor_unit_units_status_cpu_board_cpu_core_vol     0.000523
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.000836
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.000646
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.019032
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.002952
# dtype: float64
# 閾値データの各特徴量ごとの再構成誤差
# processor_unit_units_status_cpu_board_cpu_fan          0.005640
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.015246
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.000209
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.005193
# processor_unit_units_status_cpu_board_cpu_core_temp    0.001962
# processor_unit_units_status_cpu_board_gpu_core_temp    0.004535
# processor_unit_units_status_cpu_board_cpu_core_vol     0.000332
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.002033
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.001738
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.000282
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.000643
# Name: 6319, dtype: float64
# trainの日付の最大値:2018/7/01 00:00:00
# testの日付の最大値:2018/8/01 00:00:00
# 異常値と閾値の保存
# =====================================================================================
# 3回目の期間のモデル
# 該当期間の確認
# はじまり(train)2016/8/01 00:00:00
# 終わり(train)2018/8/01 00:00:00
# はじまり(test)2018/8/01 00:00:00
# 終わり(test)2018/9/01 00:00:00
# 3回目の期間のモデル作成開始
# 3回目の期間のトレーニングデータ数:17129
# 3回目の期間においてはすでにあるモデルを使用します
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 0s 468us/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step
# 最も再構成誤差が大きかったインデックス番号：17111
# 次の期間でも学習を続けます
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 3期間での結果の概要
# トレーニングデータに対する再構成誤差の最大値かつ閾値
# 0.005422438982291691
# トレーニングデータに対する再構成誤差:0.0007201042755408912
# トレーニングデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.000345
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.000729
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.000577
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.000293
# processor_unit_units_status_cpu_board_cpu_core_temp    0.001318
# processor_unit_units_status_cpu_board_gpu_core_temp    0.000353
# processor_unit_units_status_cpu_board_cpu_core_vol     0.000339
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.000607
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.000347
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.000425
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.000673
# dtype: float64
# テストデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.018967
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.004930
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.111806
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.017128
# processor_unit_units_status_cpu_board_cpu_core_temp    0.014470
# processor_unit_units_status_cpu_board_gpu_core_temp    0.001812
# processor_unit_units_status_cpu_board_cpu_core_vol     0.003049
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.005748
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.002316
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.317823
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.039132
# dtype: float64
# 閾値データの各特徴量ごとの再構成誤差
# processor_unit_units_status_cpu_board_cpu_fan          0.005640
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.015246
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.000209
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.005193
# processor_unit_units_status_cpu_board_cpu_core_temp    0.001962
# processor_unit_units_status_cpu_board_gpu_core_temp    0.004535
# processor_unit_units_status_cpu_board_cpu_core_vol     0.000332
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.002033
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.001738
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.000282
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.000643
# Name: 6319, dtype: float64
# trainの日付の最大値:2018/8/01 00:00:00
# testの日付の最大値:2018/9/01 00:00:00
# 異常値と閾値の保存
# data_exの日付の最大値:2019-02-04 23:00:02
# data_exのデータ数:26425
# data_exの最終月に含まれるデータ数:96
