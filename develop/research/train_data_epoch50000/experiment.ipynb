# %% [markdown]
# ライブラリの呼び出し

# %%
import sys
import os

# 現在の作業ディレクトリを基にプロジェクトのルートディレクトリを設定
project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..','..'))
sys.path.append(project_root)
print(project_root)
# Out:
# c:\Users\keisu\Desktop\研究元ファイル\abnormal\research_abnormal

# %%
#必要ライブラリのインストール
from src import data
from src.model import model_single_node_fixed_research_train_data
import config

# %%
#モジュールの再リロード
import importlib
import custom_class.custom_learning_average_stopping_maxdata_max_stop
import src
import src.data
import src.model
import src.model.model_single_node_fixed_research_train_data
import src.model_basic_single_node_research_train_data

importlib.reload(src.data)
importlib.reload(custom_class.custom_learning_average_stopping_maxdata_max_stop)
importlib.reload(src.model.model_single_node_fixed_research_train_data)
importlib.reload(src.model_basic_single_node_research_train_data)
# Out:
# <module 'src.model_basic_single_node_research_train_data' from 'c:\\Users\\keisu\\Desktop\\研究元ファイル\\abnormal\\research_abnormal\\src\\model_basic_single_node_research_train_data.py'>

# %% [markdown]
# データの読み込み

# %%
#データの読み込み及び加工、コラムリストの取得
data_ex, data_original = data.data_complete()
# Out:
# キャッシュファイルからデータを読み込みます

# %% [markdown]
# ハイパーパラメータの設定

# %%
#ハイパーパラメータの設定

#最大エポック数
max_epochs = 100000

#ノード数
units = 11

#モデル決定の閾値（再構成誤差のパラメータ）
#この閾値を下回ることで十分な性能を持つモデルとする
#今回は使用しない
error_threshold = 1

# シード値の準備
seeds = [50]

# ユニット数の準備
unit13_1 = 40
unit2_1 = 10
unit13_2 = 30
unit2_2 = 5
unit13_3 = 20
unit2_3 = 2

units = [[unit13_1, unit2_1],[unit13_2, unit2_2],[unit13_3, unit2_3]]

# 学習バッチサイズ
batch_size=64

# 監視するエポック数
patience = 50000

# 学習変化の閾値
min_delta = 1

# 最大データの監視するエポック
patience_max = 1

# 最大データの閾値
min_delta_max = 1

# 何期間連続して予測を行うか
num = 3

#　初期化回数
num_retry = 1

#　詳細な出力
detail_log = True

#　どこまでの値より大きいデータ点をログの中で数えるか
confirm_datapoint = 0.004

#学習率
learning_rate = 1e-3

#トレーニング開始日
train_start = "2016/6/01 00:00:00"

#テスト開始日
test_start = "2018/6/01 00:00:00"



params = {"max_epochs":max_epochs, "units":units,
	"error_threshold":error_threshold, "seeds":seeds, "units":units, 
	"batch_size":batch_size, "patience":patience, "min_delta": min_delta, "patience_max":patience_max, "min_delta_max" : min_delta_max, "num":num, "train_start" : train_start, "test_start" : test_start,
    "num_retry": num_retry, "detail_log":detail_log, "confirm_datapoint":confirm_datapoint, "learning_rate":learning_rate}

# %%
#実験の実行及び結果の格納
abnormal_scores, thresholds = model_single_node_fixed_research_train_data.result(data_ex , params)
# Out:
# =====================================================================================
# 1回目の期間のモデル
# 該当期間の確認
# はじまり(train)2016/6/01 00:00:00
# 終わり(train)2018/6/01 00:00:00
# はじまり(test)2018/6/01 00:00:00
# 終わり(test)2018/7/01 00:00:00
# 1回目の期間のモデル作成開始
# 1回目の期間のトレーニングデータ数:17161
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=40, units_2=10, 試行回数=1, seed値 = 50
# Epoch 100: Loss = 0.019532, Max Error = 0.117365
#   Errors > 0.004: 17148 / 17161 (99.92%)
#
# Epoch 200: Loss = 0.013920, Max Error = 0.093430
#   Errors > 0.004: 17121 / 17161 (99.77%)
#
# Epoch 300: Loss = 0.008722, Max Error = 0.034152
#   Errors > 0.004: 15935 / 17161 (92.86%)
#
# Epoch 400: Loss = 0.007504, Max Error = 0.026769
#   Errors > 0.004: 15756 / 17161 (91.81%)
#
# Epoch 500: Loss = 0.005997, Max Error = 0.027396
#   Errors > 0.004: 12702 / 17161 (74.02%)
#
# Epoch 600: Loss = 0.005870, Max Error = 0.027467
#   Errors > 0.004: 12212 / 17161 (71.16%)
#
# Epoch 700: Loss = 0.005809, Max Error = 0.027437
#   Errors > 0.004: 12009 / 17161 (69.98%)
#
# Epoch 800: Loss = 0.005745, Max Error = 0.027365
#   Errors > 0.004: 11787 / 17161 (68.68%)
#
# Epoch 900: Loss = 0.005668, Max Error = 0.027298
#   Errors > 0.004: 11484 / 17161 (66.92%)
#
# Epoch 1000: Loss = 0.005625, Max Error = 0.027230
#   Errors > 0.004: 11336 / 17161 (66.06%)
#
# Epoch 1100: Loss = 0.005595, Max Error = 0.027156
#   Errors > 0.004: 11212 / 17161 (65.33%)
#
# Epoch 1200: Loss = 0.005566, Max Error = 0.027074
#   Errors > 0.004: 11099 / 17161 (64.68%)
#
# Epoch 1300: Loss = 0.005528, Max Error = 0.026982
#   Errors > 0.004: 10955 / 17161 (63.84%)
#
# Epoch 1400: Loss = 0.005454, Max Error = 0.026883
#   Errors > 0.004: 10678 / 17161 (62.22%)
#
# Epoch 1500: Loss = 0.005421, Max Error = 0.026788
#   Errors > 0.004: 10557 / 17161 (61.52%)
#
# Epoch 1600: Loss = 0.005350, Max Error = 0.026712
#   Errors > 0.004: 10283 / 17161 (59.92%)
#
# Epoch 1700: Loss = 0.005270, Max Error = 0.026666
#   Errors > 0.004: 10017 / 17161 (58.37%)
#
# Epoch 1800: Loss = 0.005243, Max Error = 0.026587
#   Errors > 0.004: 9922 / 17161 (57.82%)
#
# Epoch 1900: Loss = 0.005225, Max Error = 0.026515
#   Errors > 0.004: 9863 / 17161 (57.47%)
#
# Epoch 2000: Loss = 0.005206, Max Error = 0.026448
#   Errors > 0.004: 9789 / 17161 (57.04%)
#
# Epoch 2100: Loss = 0.005082, Max Error = 0.026379
#   Errors > 0.004: 9425 / 17161 (54.92%)
#
# Epoch 2200: Loss = 0.005136, Max Error = 0.026319
#   Errors > 0.004: 9594 / 17161 (55.91%)
#
# Epoch 2300: Loss = 0.005059, Max Error = 0.026292
#   Errors > 0.004: 9375 / 17161 (54.63%)
#
# Epoch 2400: Loss = 0.005024, Max Error = 0.026272
#   Errors > 0.004: 9277 / 17161 (54.06%)
#
# Epoch 2500: Loss = 0.004976, Max Error = 0.026255
#   Errors > 0.004: 9149 / 17161 (53.31%)
#
# Epoch 2600: Loss = 0.004946, Max Error = 0.026243
#   Errors > 0.004: 9050 / 17161 (52.74%)
#
# Epoch 2700: Loss = 0.004892, Max Error = 0.026255
#   Errors > 0.004: 8909 / 17161 (51.91%)
#
# Epoch 2800: Loss = 0.004857, Max Error = 0.026261
#   Errors > 0.004: 8820 / 17161 (51.40%)
#
# Epoch 2900: Loss = 0.004821, Max Error = 0.026262
#   Errors > 0.004: 8738 / 17161 (50.92%)
#
# Epoch 3000: Loss = 0.004787, Max Error = 0.026251
#   Errors > 0.004: 8657 / 17161 (50.45%)
#
# Epoch 3100: Loss = 0.004756, Max Error = 0.026215
#   Errors > 0.004: 8607 / 17161 (50.15%)
#
# Epoch 3200: Loss = 0.004729, Max Error = 0.026136
#   Errors > 0.004: 8549 / 17161 (49.82%)
#
# Epoch 3300: Loss = 0.004703, Max Error = 0.025987
#   Errors > 0.004: 8520 / 17161 (49.65%)
#
# Epoch 3400: Loss = 0.004674, Max Error = 0.025691
#   Errors > 0.004: 8536 / 17161 (49.74%)
#
# Epoch 3500: Loss = 0.004618, Max Error = 0.025007
#   Errors > 0.004: 8560 / 17161 (49.88%)
#
# Epoch 3600: Loss = 0.004804, Max Error = 0.022986
#   Errors > 0.004: 9321 / 17161 (54.32%)
#
# Epoch 3700: Loss = 0.004262, Max Error = 0.016302
#   Errors > 0.004: 7924 / 17161 (46.17%)
#
# Epoch 3800: Loss = 0.003387, Max Error = 0.015795
#   Errors > 0.004: 4966 / 17161 (28.94%)
#
# Epoch 3900: Loss = 0.003806, Max Error = 0.014660
#   Errors > 0.004: 5243 / 17161 (30.55%)
#
# Epoch 4000: Loss = 0.003610, Max Error = 0.014024
#   Errors > 0.004: 4983 / 17161 (29.04%)
#
# Epoch 4100: Loss = 0.003558, Max Error = 0.013878
#   Errors > 0.004: 4894 / 17161 (28.52%)
#
# Epoch 4200: Loss = 0.003529, Max Error = 0.013736
#   Errors > 0.004: 4849 / 17161 (28.26%)
#
# Epoch 4300: Loss = 0.003293, Max Error = 0.013591
#   Errors > 0.004: 4641 / 17161 (27.04%)
#
# Epoch 4400: Loss = 0.003515, Max Error = 0.013466
#   Errors > 0.004: 4723 / 17161 (27.52%)
#
# Epoch 4500: Loss = 0.003475, Max Error = 0.013330
#   Errors > 0.004: 4673 / 17161 (27.23%)
#
# Epoch 4600: Loss = 0.003321, Max Error = 0.013216
#   Errors > 0.004: 4634 / 17161 (27.00%)
#
# Epoch 4700: Loss = 0.003371, Max Error = 0.013153
#   Errors > 0.004: 4647 / 17161 (27.08%)
#
# Epoch 4800: Loss = 0.003361, Max Error = 0.013165
#   Errors > 0.004: 4627 / 17161 (26.96%)
#
# Epoch 4900: Loss = 0.003319, Max Error = 0.013261
#   Errors > 0.004: 4579 / 17161 (26.68%)
#
# Epoch 5000: Loss = 0.003162, Max Error = 0.013368
#   Errors > 0.004: 4504 / 17161 (26.25%)
#
# Epoch 5100: Loss = 0.003408, Max Error = 0.013456
#   Errors > 0.004: 4521 / 17161 (26.34%)
#
# Epoch 5200: Loss = 0.003128, Max Error = 0.013461
#   Errors > 0.004: 4329 / 17161 (25.23%)
#
# Epoch 5300: Loss = 0.002909, Max Error = 0.013259
#   Errors > 0.004: 4010 / 17161 (23.37%)
#
# Epoch 5400: Loss = 0.002827, Max Error = 0.012152
#   Errors > 0.004: 3446 / 17161 (20.08%)
#
# Epoch 5500: Loss = 0.002682, Max Error = 0.009610
#   Errors > 0.004: 1382 / 17161 (8.05%)
#
# Epoch 5600: Loss = 0.002185, Max Error = 0.009220
#   Errors > 0.004: 292 / 17161 (1.70%)
#
# Epoch 5700: Loss = 0.001755, Max Error = 0.009198
#   Errors > 0.004: 143 / 17161 (0.83%)
#
# Epoch 5800: Loss = 0.001980, Max Error = 0.008923
#   Errors > 0.004: 165 / 17161 (0.96%)
#
# Epoch 5900: Loss = 0.002230, Max Error = 0.009170
#   Errors > 0.004: 166 / 17161 (0.97%)
#
# Epoch 6000: Loss = 0.001725, Max Error = 0.008634
#   Errors > 0.004: 118 / 17161 (0.69%)
#
# Epoch 6100: Loss = 0.002043, Max Error = 0.009186
#   Errors > 0.004: 145 / 17161 (0.84%)
#
# Epoch 6200: Loss = 0.002755, Max Error = 0.009067
#   Errors > 0.004: 283 / 17161 (1.65%)
#
# Epoch 6300: Loss = 0.002324, Max Error = 0.008444
#   Errors > 0.004: 191 / 17161 (1.11%)
#
# Epoch 6400: Loss = 0.002050, Max Error = 0.008624
#   Errors > 0.004: 141 / 17161 (0.82%)
#
# Epoch 6500: Loss = 0.001863, Max Error = 0.008041
#   Errors > 0.004: 136 / 17161 (0.79%)
#
# Epoch 6600: Loss = 0.001943, Max Error = 0.008027
#   Errors > 0.004: 92 / 17161 (0.54%)
#
# Epoch 6700: Loss = 0.002222, Max Error = 0.008047
#   Errors > 0.004: 116 / 17161 (0.68%)
#
# Epoch 6800: Loss = 0.002806, Max Error = 0.008445
#   Errors > 0.004: 289 / 17161 (1.68%)
#
# Epoch 6900: Loss = 0.001461, Max Error = 0.007126
#   Errors > 0.004: 68 / 17161 (0.40%)
#
# Epoch 7000: Loss = 0.002019, Max Error = 0.007940
#   Errors > 0.004: 116 / 17161 (0.68%)
#
# Epoch 7100: Loss = 0.001592, Max Error = 0.007282
#   Errors > 0.004: 72 / 17161 (0.42%)
#
# Epoch 7200: Loss = 0.002886, Max Error = 0.008246
#   Errors > 0.004: 337 / 17161 (1.96%)
#
# Epoch 7300: Loss = 0.001602, Max Error = 0.006861
#   Errors > 0.004: 72 / 17161 (0.42%)
#
# Epoch 7400: Loss = 0.002100, Max Error = 0.007051
#   Errors > 0.004: 89 / 17161 (0.52%)
#
# Epoch 7500: Loss = 0.001553, Max Error = 0.006928
#   Errors > 0.004: 87 / 17161 (0.51%)
#
# Epoch 7600: Loss = 0.001661, Max Error = 0.006890
#   Errors > 0.004: 74 / 17161 (0.43%)
#
# Epoch 7700: Loss = 0.002269, Max Error = 0.007521
#   Errors > 0.004: 127 / 17161 (0.74%)
#
# Epoch 7800: Loss = 0.001727, Max Error = 0.007145
#   Errors > 0.004: 78 / 17161 (0.45%)
#
# Epoch 7900: Loss = 0.002226, Max Error = 0.008056
#   Errors > 0.004: 101 / 17161 (0.59%)
#
# Epoch 8000: Loss = 0.001304, Max Error = 0.006329
#   Errors > 0.004: 53 / 17161 (0.31%)
#
# Epoch 8100: Loss = 0.002061, Max Error = 0.006601
#   Errors > 0.004: 78 / 17161 (0.45%)
#
# Epoch 8200: Loss = 0.001606, Max Error = 0.006854
#   Errors > 0.004: 60 / 17161 (0.35%)
#
# Epoch 8300: Loss = 0.001559, Max Error = 0.006072
#   Errors > 0.004: 55 / 17161 (0.32%)
#
# Epoch 8400: Loss = 0.002063, Max Error = 0.006490
#   Errors > 0.004: 74 / 17161 (0.43%)
#
# Epoch 8500: Loss = 0.002068, Max Error = 0.006364
#   Errors > 0.004: 69 / 17161 (0.40%)
#
# Epoch 8600: Loss = 0.001343, Max Error = 0.006416
#   Errors > 0.004: 38 / 17161 (0.22%)
#
# Epoch 8700: Loss = 0.001322, Max Error = 0.006556
#   Errors > 0.004: 42 / 17161 (0.24%)
#
# Epoch 8800: Loss = 0.001316, Max Error = 0.006239
#   Errors > 0.004: 44 / 17161 (0.26%)
#
# Epoch 8900: Loss = 0.001530, Max Error = 0.006818
#   Errors > 0.004: 53 / 17161 (0.31%)
#
# Epoch 9000: Loss = 0.001855, Max Error = 0.006463
#   Errors > 0.004: 62 / 17161 (0.36%)
#
# Epoch 9100: Loss = 0.002093, Max Error = 0.006809
#   Errors > 0.004: 51 / 17161 (0.30%)
#
# Epoch 9200: Loss = 0.001659, Max Error = 0.007112
#   Errors > 0.004: 43 / 17161 (0.25%)
#
# Epoch 9300: Loss = 0.001133, Max Error = 0.006483
#   Errors > 0.004: 43 / 17161 (0.25%)
#
# Epoch 9400: Loss = 0.001589, Max Error = 0.006350
#   Errors > 0.004: 50 / 17161 (0.29%)
#
# Epoch 9500: Loss = 0.002027, Max Error = 0.007447
#   Errors > 0.004: 66 / 17161 (0.38%)
#
# Epoch 9600: Loss = 0.002090, Max Error = 0.007377
#   Errors > 0.004: 65 / 17161 (0.38%)
#
# Epoch 9700: Loss = 0.001535, Max Error = 0.006476
#   Errors > 0.004: 41 / 17161 (0.24%)
#
# Epoch 9800: Loss = 0.001196, Max Error = 0.006514
#   Errors > 0.004: 25 / 17161 (0.15%)
#
# Epoch 9900: Loss = 0.001562, Max Error = 0.006322
#   Errors > 0.004: 47 / 17161 (0.27%)
#
# Epoch 10000: Loss = 0.001298, Max Error = 0.006740
#   Errors > 0.004: 27 / 17161 (0.16%)
#
# Epoch 10100: Loss = 0.001632, Max Error = 0.006692
#   Errors > 0.004: 54 / 17161 (0.31%)
#
# Epoch 10200: Loss = 0.001579, Max Error = 0.007010
#   Errors > 0.004: 47 / 17161 (0.27%)
#
# Epoch 10300: Loss = 0.001305, Max Error = 0.006710
#   Errors > 0.004: 25 / 17161 (0.15%)
#
# Epoch 10400: Loss = 0.001633, Max Error = 0.006544
#   Errors > 0.004: 27 / 17161 (0.16%)
#
# Epoch 10500: Loss = 0.001453, Max Error = 0.007281
#   Errors > 0.004: 47 / 17161 (0.27%)
#
# Epoch 10600: Loss = 0.001527, Max Error = 0.006992
#   Errors > 0.004: 37 / 17161 (0.22%)
#
# Epoch 10700: Loss = 0.001152, Max Error = 0.006092
#   Errors > 0.004: 19 / 17161 (0.11%)
#
# Epoch 10800: Loss = 0.001588, Max Error = 0.006751
#   Errors > 0.004: 43 / 17161 (0.25%)
#
# Epoch 10900: Loss = 0.001524, Max Error = 0.006454
#   Errors > 0.004: 18 / 17161 (0.10%)
#
# Epoch 11000: Loss = 0.001709, Max Error = 0.007324
#   Errors > 0.004: 30 / 17161 (0.17%)
#
# Epoch 11100: Loss = 0.001266, Max Error = 0.007224
#   Errors > 0.004: 22 / 17161 (0.13%)
#
# Epoch 11200: Loss = 0.001174, Max Error = 0.007525
#   Errors > 0.004: 23 / 17161 (0.13%)
#
# Epoch 11300: Loss = 0.001978, Max Error = 0.007230
#   Errors > 0.004: 60 / 17161 (0.35%)
#
# Epoch 11400: Loss = 0.000885, Max Error = 0.006831
#   Errors > 0.004: 17 / 17161 (0.10%)
#
# Epoch 11500: Loss = 0.001137, Max Error = 0.006631
#   Errors > 0.004: 16 / 17161 (0.09%)
#
# Epoch 11600: Loss = 0.001337, Max Error = 0.006138
#   Errors > 0.004: 18 / 17161 (0.10%)
#
# Epoch 11700: Loss = 0.001646, Max Error = 0.006837
#   Errors > 0.004: 19 / 17161 (0.11%)
#
# Epoch 11800: Loss = 0.001822, Max Error = 0.006147
#   Errors > 0.004: 25 / 17161 (0.15%)
#
# Epoch 11900: Loss = 0.001410, Max Error = 0.006005
#   Errors > 0.004: 15 / 17161 (0.09%)
#
# Epoch 12000: Loss = 0.001207, Max Error = 0.006936
#   Errors > 0.004: 14 / 17161 (0.08%)
#
# Epoch 12100: Loss = 0.001235, Max Error = 0.006661
#   Errors > 0.004: 20 / 17161 (0.12%)
#
# Epoch 12200: Loss = 0.001669, Max Error = 0.006782
#   Errors > 0.004: 25 / 17161 (0.15%)
#
# Epoch 12300: Loss = 0.002067, Max Error = 0.007156
#   Errors > 0.004: 36 / 17161 (0.21%)
#
# Epoch 12400: Loss = 0.000850, Max Error = 0.006836
#   Errors > 0.004: 11 / 17161 (0.06%)
#
# Epoch 12500: Loss = 0.001453, Max Error = 0.007288
#   Errors > 0.004: 18 / 17161 (0.10%)
#
# Epoch 12600: Loss = 0.001481, Max Error = 0.006728
#   Errors > 0.004: 25 / 17161 (0.15%)
#
# Epoch 12700: Loss = 0.001869, Max Error = 0.007461
#   Errors > 0.004: 23 / 17161 (0.13%)
#
# Epoch 12800: Loss = 0.000772, Max Error = 0.006997
#   Errors > 0.004: 13 / 17161 (0.08%)
#
# Epoch 12900: Loss = 0.001212, Max Error = 0.007012
#   Errors > 0.004: 12 / 17161 (0.07%)
#
# Epoch 13000: Loss = 0.000795, Max Error = 0.007033
#   Errors > 0.004: 13 / 17161 (0.08%)
#
# Epoch 13100: Loss = 0.001575, Max Error = 0.006958
#   Errors > 0.004: 13 / 17161 (0.08%)
#
# Epoch 13200: Loss = 0.001269, Max Error = 0.006810
#   Errors > 0.004: 11 / 17161 (0.06%)
#
# Epoch 13300: Loss = 0.001346, Max Error = 0.006769
#   Errors > 0.004: 17 / 17161 (0.10%)
#
# Epoch 13400: Loss = 0.001591, Max Error = 0.006535
#   Errors > 0.004: 19 / 17161 (0.11%)
#
# Epoch 13500: Loss = 0.001419, Max Error = 0.007184
#   Errors > 0.004: 13 / 17161 (0.08%)
#
# Epoch 13600: Loss = 0.001764, Max Error = 0.006659
#   Errors > 0.004: 18 / 17161 (0.10%)
#
# Epoch 13700: Loss = 0.000824, Max Error = 0.007114
#   Errors > 0.004: 12 / 17161 (0.07%)
#
# Epoch 13800: Loss = 0.001026, Max Error = 0.006983
#   Errors > 0.004: 11 / 17161 (0.06%)
#
# Epoch 13900: Loss = 0.000998, Max Error = 0.006921
#   Errors > 0.004: 10 / 17161 (0.06%)
#
# Epoch 14000: Loss = 0.001043, Max Error = 0.006641
#   Errors > 0.004: 11 / 17161 (0.06%)
#
# Epoch 14100: Loss = 0.001427, Max Error = 0.007291
#   Errors > 0.004: 13 / 17161 (0.08%)
#
# Epoch 14200: Loss = 0.001353, Max Error = 0.007101
#   Errors > 0.004: 10 / 17161 (0.06%)
#
# Epoch 14300: Loss = 0.001809, Max Error = 0.006321
#   Errors > 0.004: 16 / 17161 (0.09%)
#
# Epoch 14400: Loss = 0.001197, Max Error = 0.006806
#   Errors > 0.004: 14 / 17161 (0.08%)
#
# Epoch 14500: Loss = 0.001199, Max Error = 0.007028
#   Errors > 0.004: 9 / 17161 (0.05%)
#
# Epoch 14600: Loss = 0.001587, Max Error = 0.006519
#   Errors > 0.004: 9 / 17161 (0.05%)
#
# Epoch 14700: Loss = 0.001412, Max Error = 0.007370
#   Errors > 0.004: 15 / 17161 (0.09%)
#
# Epoch 14800: Loss = 0.001467, Max Error = 0.006938
#   Errors > 0.004: 13 / 17161 (0.08%)
#
# Epoch 14900: Loss = 0.001084, Max Error = 0.006533
#   Errors > 0.004: 9 / 17161 (0.05%)
#
# Epoch 15000: Loss = 0.001464, Max Error = 0.006402
#   Errors > 0.004: 12 / 17161 (0.07%)
#
# Epoch 15100: Loss = 0.001078, Max Error = 0.006869
#   Errors > 0.004: 9 / 17161 (0.05%)
#
# Epoch 15200: Loss = 0.001187, Max Error = 0.006717
#   Errors > 0.004: 9 / 17161 (0.05%)
#
# Epoch 15300: Loss = 0.001052, Max Error = 0.007187
#   Errors > 0.004: 9 / 17161 (0.05%)
#
# Epoch 15400: Loss = 0.001397, Max Error = 0.006404
#   Errors > 0.004: 9 / 17161 (0.05%)
#
# Epoch 15500: Loss = 0.001461, Max Error = 0.007207
#   Errors > 0.004: 9 / 17161 (0.05%)
#
# Epoch 15600: Loss = 0.001176, Max Error = 0.006917
#   Errors > 0.004: 9 / 17161 (0.05%)
#
# Epoch 15700: Loss = 0.001017, Max Error = 0.006934
#   Errors > 0.004: 9 / 17161 (0.05%)
#
# Epoch 15800: Loss = 0.000688, Max Error = 0.006947
#   Errors > 0.004: 9 / 17161 (0.05%)
#
# Epoch 15900: Loss = 0.000996, Max Error = 0.007196
#   Errors > 0.004: 9 / 17161 (0.05%)
#
# Epoch 16000: Loss = 0.000915, Max Error = 0.006967
#   Errors > 0.004: 9 / 17161 (0.05%)
#
# Epoch 16100: Loss = 0.001378, Max Error = 0.006713
#   Errors > 0.004: 10 / 17161 (0.06%)
#
# Epoch 16200: Loss = 0.001141, Max Error = 0.006906
#   Errors > 0.004: 8 / 17161 (0.05%)
#
# Epoch 16300: Loss = 0.001204, Max Error = 0.006878
#   Errors > 0.004: 8 / 17161 (0.05%)
#
# Epoch 16400: Loss = 0.000828, Max Error = 0.006933
#   Errors > 0.004: 9 / 17161 (0.05%)
#
# Epoch 16500: Loss = 0.001427, Max Error = 0.006903
#   Errors > 0.004: 10 / 17161 (0.06%)
#
# Epoch 16600: Loss = 0.000985, Max Error = 0.006858
#   Errors > 0.004: 8 / 17161 (0.05%)
#
# Epoch 16700: Loss = 0.001279, Max Error = 0.006519
#   Errors > 0.004: 9 / 17161 (0.05%)
#
# Epoch 16800: Loss = 0.001059, Max Error = 0.006708
#   Errors > 0.004: 8 / 17161 (0.05%)
#
# Epoch 16900: Loss = 0.001504, Max Error = 0.006053
#   Errors > 0.004: 9 / 17161 (0.05%)
#
# Epoch 17000: Loss = 0.000900, Max Error = 0.006705
#   Errors > 0.004: 8 / 17161 (0.05%)
#
# Epoch 17100: Loss = 0.001124, Max Error = 0.006636
#   Errors > 0.004: 8 / 17161 (0.05%)
#
# Epoch 17200: Loss = 0.001079, Max Error = 0.006828
#   Errors > 0.004: 8 / 17161 (0.05%)
#
# Epoch 17300: Loss = 0.001016, Max Error = 0.006526
#   Errors > 0.004: 9 / 17161 (0.05%)
#
# Epoch 17400: Loss = 0.001085, Max Error = 0.006531
#   Errors > 0.004: 9 / 17161 (0.05%)
#
# Epoch 17500: Loss = 0.000826, Max Error = 0.006671
#   Errors > 0.004: 8 / 17161 (0.05%)
#
# Epoch 17600: Loss = 0.001027, Max Error = 0.006234
#   Errors > 0.004: 8 / 17161 (0.05%)
#
# Epoch 17700: Loss = 0.001164, Max Error = 0.006128
#   Errors > 0.004: 8 / 17161 (0.05%)
#
# Epoch 17800: Loss = 0.001350, Max Error = 0.006451
#   Errors > 0.004: 10 / 17161 (0.06%)
#
# Epoch 17900: Loss = 0.001318, Max Error = 0.006631
#   Errors > 0.004: 9 / 17161 (0.05%)
#
# Epoch 18000: Loss = 0.001226, Max Error = 0.006497
#   Errors > 0.004: 9 / 17161 (0.05%)
#
# Epoch 18100: Loss = 0.001635, Max Error = 0.006663
#   Errors > 0.004: 9 / 17161 (0.05%)
#
# Epoch 18200: Loss = 0.000899, Max Error = 0.006404
#   Errors > 0.004: 9 / 17161 (0.05%)
#
# Epoch 18300: Loss = 0.000980, Max Error = 0.006166
#   Errors > 0.004: 8 / 17161 (0.05%)
#
# Epoch 18400: Loss = 0.001137, Max Error = 0.006393
#   Errors > 0.004: 8 / 17161 (0.05%)
#
# Epoch 18500: Loss = 0.001209, Max Error = 0.006653
#   Errors > 0.004: 8 / 17161 (0.05%)
#
# Epoch 18600: Loss = 0.001133, Max Error = 0.006471
#   Errors > 0.004: 8 / 17161 (0.05%)
#
# Epoch 18700: Loss = 0.001163, Max Error = 0.006609
#   Errors > 0.004: 8 / 17161 (0.05%)
#
# Epoch 18800: Loss = 0.000942, Max Error = 0.006518
#   Errors > 0.004: 8 / 17161 (0.05%)
#
# Epoch 18900: Loss = 0.001246, Max Error = 0.006277
#   Errors > 0.004: 9 / 17161 (0.05%)
#
# Epoch 19000: Loss = 0.001392, Max Error = 0.006558
#   Errors > 0.004: 7 / 17161 (0.04%)
#
# Epoch 19100: Loss = 0.001339, Max Error = 0.006100
#   Errors > 0.004: 8 / 17161 (0.05%)
#
# Epoch 19200: Loss = 0.000870, Max Error = 0.006600
#   Errors > 0.004: 7 / 17161 (0.04%)
#
# Epoch 19300: Loss = 0.000977, Max Error = 0.006057
#   Errors > 0.004: 8 / 17161 (0.05%)
#
# Epoch 19400: Loss = 0.001293, Max Error = 0.006074
#   Errors > 0.004: 6 / 17161 (0.03%)
#
# Epoch 19500: Loss = 0.000890, Max Error = 0.006606
#   Errors > 0.004: 8 / 17161 (0.05%)
#
# Epoch 19600: Loss = 0.000875, Max Error = 0.005951
#   Errors > 0.004: 7 / 17161 (0.04%)
#
# Epoch 19700: Loss = 0.000653, Max Error = 0.005980
#   Errors > 0.004: 7 / 17161 (0.04%)
#
# Epoch 19800: Loss = 0.001250, Max Error = 0.006346
#   Errors > 0.004: 8 / 17161 (0.05%)
#
# Epoch 19900: Loss = 0.000777, Max Error = 0.005820
#   Errors > 0.004: 8 / 17161 (0.05%)
#
# Epoch 20000: Loss = 0.001063, Max Error = 0.005910
#   Errors > 0.004: 8 / 17161 (0.05%)
#
# Epoch 20100: Loss = 0.001150, Max Error = 0.005292
#   Errors > 0.004: 8 / 17161 (0.05%)
#
# Epoch 20200: Loss = 0.001177, Max Error = 0.006203
#   Errors > 0.004: 6 / 17161 (0.03%)
#
# Epoch 20300: Loss = 0.000943, Max Error = 0.006220
#   Errors > 0.004: 8 / 17161 (0.05%)
#
# Epoch 20400: Loss = 0.001268, Max Error = 0.005784
#   Errors > 0.004: 8 / 17161 (0.05%)
#
# Epoch 20500: Loss = 0.001207, Max Error = 0.005950
#   Errors > 0.004: 8 / 17161 (0.05%)
#
# Epoch 20600: Loss = 0.001324, Max Error = 0.005930
#   Errors > 0.004: 8 / 17161 (0.05%)
#
# Epoch 20700: Loss = 0.001054, Max Error = 0.005910
#   Errors > 0.004: 8 / 17161 (0.05%)
#
# Epoch 20800: Loss = 0.001223, Max Error = 0.005621
#   Errors > 0.004: 7 / 17161 (0.04%)
#
# Epoch 20900: Loss = 0.000802, Max Error = 0.005720
#   Errors > 0.004: 7 / 17161 (0.04%)
#
# Epoch 21000: Loss = 0.000892, Max Error = 0.005887
#   Errors > 0.004: 7 / 17161 (0.04%)
#
# Epoch 21100: Loss = 0.001088, Max Error = 0.005694
#   Errors > 0.004: 6 / 17161 (0.03%)
#
# Epoch 21200: Loss = 0.001154, Max Error = 0.005981
#   Errors > 0.004: 6 / 17161 (0.03%)
#
# Epoch 21300: Loss = 0.000957, Max Error = 0.005751
#   Errors > 0.004: 8 / 17161 (0.05%)
#
# Epoch 21400: Loss = 0.000857, Max Error = 0.005796
#   Errors > 0.004: 7 / 17161 (0.04%)
#
# Epoch 21500: Loss = 0.000838, Max Error = 0.005887
#   Errors > 0.004: 6 / 17161 (0.03%)
#
# Epoch 21600: Loss = 0.000928, Max Error = 0.005544
#   Errors > 0.004: 7 / 17161 (0.04%)
#
# Epoch 21700: Loss = 0.000952, Max Error = 0.005561
#   Errors > 0.004: 7 / 17161 (0.04%)
#
# Epoch 21800: Loss = 0.000934, Max Error = 0.005208
#   Errors > 0.004: 6 / 17161 (0.03%)
#
# Epoch 21900: Loss = 0.001128, Max Error = 0.005465
#   Errors > 0.004: 8 / 17161 (0.05%)
#
# Epoch 22000: Loss = 0.001081, Max Error = 0.005744
#   Errors > 0.004: 8 / 17161 (0.05%)
#
# Epoch 22100: Loss = 0.001045, Max Error = 0.005844
#   Errors > 0.004: 7 / 17161 (0.04%)
#
# Epoch 22200: Loss = 0.000884, Max Error = 0.005685
#   Errors > 0.004: 6 / 17161 (0.03%)
#
# Epoch 22300: Loss = 0.000793, Max Error = 0.005789
#   Errors > 0.004: 6 / 17161 (0.03%)
#
# Epoch 22400: Loss = 0.001005, Max Error = 0.005100
#   Errors > 0.004: 5 / 17161 (0.03%)
#
# Epoch 22500: Loss = 0.000914, Max Error = 0.004966
#   Errors > 0.004: 6 / 17161 (0.03%)
#
# Epoch 22600: Loss = 0.001186, Max Error = 0.005508
#   Errors > 0.004: 8 / 17161 (0.05%)
#
# Epoch 22700: Loss = 0.000973, Max Error = 0.005648
#   Errors > 0.004: 6 / 17161 (0.03%)
#
# Epoch 22800: Loss = 0.000645, Max Error = 0.005550
#   Errors > 0.004: 6 / 17161 (0.03%)
#
# Epoch 22900: Loss = 0.000697, Max Error = 0.005483
#   Errors > 0.004: 5 / 17161 (0.03%)
#
# Epoch 23000: Loss = 0.000789, Max Error = 0.005636
#   Errors > 0.004: 6 / 17161 (0.03%)
#
# Epoch 23100: Loss = 0.001004, Max Error = 0.005093
#   Errors > 0.004: 5 / 17161 (0.03%)
#
# Epoch 23200: Loss = 0.001138, Max Error = 0.005473
#   Errors > 0.004: 6 / 17161 (0.03%)
#
# Epoch 23300: Loss = 0.001196, Max Error = 0.005174
#   Errors > 0.004: 5 / 17161 (0.03%)
#
# Epoch 23400: Loss = 0.000609, Max Error = 0.005493
#   Errors > 0.004: 6 / 17161 (0.03%)
#
# Epoch 23500: Loss = 0.001023, Max Error = 0.005245
#   Errors > 0.004: 5 / 17161 (0.03%)
#
# Epoch 23600: Loss = 0.000867, Max Error = 0.005414
#   Errors > 0.004: 7 / 17161 (0.04%)
#
# Epoch 23700: Loss = 0.000890, Max Error = 0.005196
#   Errors > 0.004: 5 / 17161 (0.03%)
#
# Epoch 23800: Loss = 0.000984, Max Error = 0.005890
#   Errors > 0.004: 6 / 17161 (0.03%)
#
# Epoch 23900: Loss = 0.000673, Max Error = 0.005444
#   Errors > 0.004: 6 / 17161 (0.03%)
#
# Epoch 24000: Loss = 0.000799, Max Error = 0.005571
#   Errors > 0.004: 5 / 17161 (0.03%)
#
# Epoch 24100: Loss = 0.000781, Max Error = 0.005567
#   Errors > 0.004: 7 / 17161 (0.04%)
#
# Epoch 24200: Loss = 0.000708, Max Error = 0.005334
#   Errors > 0.004: 5 / 17161 (0.03%)
#
# Epoch 24300: Loss = 0.001111, Max Error = 0.005538
#   Errors > 0.004: 6 / 17161 (0.03%)
#
# Epoch 24400: Loss = 0.000954, Max Error = 0.005012
#   Errors > 0.004: 4 / 17161 (0.02%)
#
# Epoch 24500: Loss = 0.000673, Max Error = 0.005072
#   Errors > 0.004: 3 / 17161 (0.02%)
#
# Epoch 24600: Loss = 0.000629, Max Error = 0.005185
#   Errors > 0.004: 4 / 17161 (0.02%)
#
# Epoch 24700: Loss = 0.000973, Max Error = 0.005634
#   Errors > 0.004: 7 / 17161 (0.04%)
#
# Epoch 24800: Loss = 0.001192, Max Error = 0.005326
#   Errors > 0.004: 5 / 17161 (0.03%)
#
# Epoch 24900: Loss = 0.001048, Max Error = 0.005133
#   Errors > 0.004: 3 / 17161 (0.02%)
#
# Epoch 25000: Loss = 0.000734, Max Error = 0.005394
#   Errors > 0.004: 5 / 17161 (0.03%)
#
# Epoch 25100: Loss = 0.000788, Max Error = 0.005319
#   Errors > 0.004: 4 / 17161 (0.02%)
#
# Epoch 25200: Loss = 0.001029, Max Error = 0.005230
#   Errors > 0.004: 5 / 17161 (0.03%)
#
# Epoch 25300: Loss = 0.000818, Max Error = 0.005301
#   Errors > 0.004: 4 / 17161 (0.02%)
#
# Epoch 25400: Loss = 0.000719, Max Error = 0.005045
#   Errors > 0.004: 3 / 17161 (0.02%)
#
# Epoch 25500: Loss = 0.000558, Max Error = 0.005343
#   Errors > 0.004: 4 / 17161 (0.02%)
#
# Epoch 25600: Loss = 0.000903, Max Error = 0.004420
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 25700: Loss = 0.000944, Max Error = 0.005189
#   Errors > 0.004: 4 / 17161 (0.02%)
#
# Epoch 25800: Loss = 0.000758, Max Error = 0.005399
#   Errors > 0.004: 5 / 17161 (0.03%)
#
# Epoch 25900: Loss = 0.000999, Max Error = 0.004905
#   Errors > 0.004: 3 / 17161 (0.02%)
#
# Epoch 26000: Loss = 0.000756, Max Error = 0.005349
#   Errors > 0.004: 4 / 17161 (0.02%)
#
# Epoch 26100: Loss = 0.000603, Max Error = 0.005053
#   Errors > 0.004: 3 / 17161 (0.02%)
#
# Epoch 26200: Loss = 0.001051, Max Error = 0.004901
#   Errors > 0.004: 3 / 17161 (0.02%)
#
# Epoch 26300: Loss = 0.000972, Max Error = 0.005082
#   Errors > 0.004: 3 / 17161 (0.02%)
#
# Epoch 26400: Loss = 0.000892, Max Error = 0.005275
#   Errors > 0.004: 4 / 17161 (0.02%)
#
# Epoch 26500: Loss = 0.000705, Max Error = 0.004959
#   Errors > 0.004: 3 / 17161 (0.02%)
#
# Epoch 26600: Loss = 0.000814, Max Error = 0.005005
#   Errors > 0.004: 3 / 17161 (0.02%)
#
# Epoch 26700: Loss = 0.000909, Max Error = 0.005091
#   Errors > 0.004: 3 / 17161 (0.02%)
#
# Epoch 26800: Loss = 0.000749, Max Error = 0.005146
#   Errors > 0.004: 4 / 17161 (0.02%)
#
# Epoch 26900: Loss = 0.000845, Max Error = 0.005156
#   Errors > 0.004: 3 / 17161 (0.02%)
#
# Epoch 27000: Loss = 0.000910, Max Error = 0.004986
#   Errors > 0.004: 3 / 17161 (0.02%)
#
# Epoch 27100: Loss = 0.000727, Max Error = 0.004919
#   Errors > 0.004: 3 / 17161 (0.02%)
#
# Epoch 27200: Loss = 0.000793, Max Error = 0.005050
#   Errors > 0.004: 3 / 17161 (0.02%)
#
# Epoch 27300: Loss = 0.000708, Max Error = 0.005112
#   Errors > 0.004: 3 / 17161 (0.02%)
#
# Epoch 27400: Loss = 0.000731, Max Error = 0.004865
#   Errors > 0.004: 2 / 17161 (0.01%)
#
# Epoch 27500: Loss = 0.000976, Max Error = 0.004781
#   Errors > 0.004: 2 / 17161 (0.01%)
#
# Epoch 27600: Loss = 0.001046, Max Error = 0.005019
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 27700: Loss = 0.000949, Max Error = 0.005235
#   Errors > 0.004: 3 / 17161 (0.02%)
#
# Epoch 27800: Loss = 0.000551, Max Error = 0.004946
#   Errors > 0.004: 2 / 17161 (0.01%)
#
# Epoch 27900: Loss = 0.000811, Max Error = 0.005184
#   Errors > 0.004: 3 / 17161 (0.02%)
#
# Epoch 28000: Loss = 0.000739, Max Error = 0.004735
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 28100: Loss = 0.000684, Max Error = 0.005040
#   Errors > 0.004: 2 / 17161 (0.01%)
#
# Epoch 28200: Loss = 0.000884, Max Error = 0.005428
#   Errors > 0.004: 3 / 17161 (0.02%)
#
# Epoch 28300: Loss = 0.000690, Max Error = 0.004911
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 28400: Loss = 0.000534, Max Error = 0.004924
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 28500: Loss = 0.000763, Max Error = 0.004815
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 28600: Loss = 0.000748, Max Error = 0.004817
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 28700: Loss = 0.001016, Max Error = 0.005228
#   Errors > 0.004: 3 / 17161 (0.02%)
#
# Epoch 28800: Loss = 0.000869, Max Error = 0.005178
#   Errors > 0.004: 3 / 17161 (0.02%)
#
# Epoch 28900: Loss = 0.000840, Max Error = 0.004887
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 29000: Loss = 0.001142, Max Error = 0.004703
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 29100: Loss = 0.000926, Max Error = 0.004924
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 29200: Loss = 0.000852, Max Error = 0.004749
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 29300: Loss = 0.000870, Max Error = 0.005108
#   Errors > 0.004: 2 / 17161 (0.01%)
#
# Epoch 29400: Loss = 0.000856, Max Error = 0.004777
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 29500: Loss = 0.000660, Max Error = 0.004891
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 29600: Loss = 0.000671, Max Error = 0.005082
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 29700: Loss = 0.000652, Max Error = 0.004770
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 29800: Loss = 0.000809, Max Error = 0.004806
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 29900: Loss = 0.000699, Max Error = 0.004766
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 30000: Loss = 0.000520, Max Error = 0.004742
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 30100: Loss = 0.000801, Max Error = 0.004585
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 30200: Loss = 0.000827, Max Error = 0.004600
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 30300: Loss = 0.001078, Max Error = 0.004522
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 30400: Loss = 0.000564, Max Error = 0.004642
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 30500: Loss = 0.000931, Max Error = 0.004362
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 30600: Loss = 0.000805, Max Error = 0.004418
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 30700: Loss = 0.001117, Max Error = 0.004594
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 30800: Loss = 0.000951, Max Error = 0.004996
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 30900: Loss = 0.001017, Max Error = 0.004338
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 31000: Loss = 0.000654, Max Error = 0.004295
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 31100: Loss = 0.000657, Max Error = 0.004736
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 31200: Loss = 0.000746, Max Error = 0.004769
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 31300: Loss = 0.000809, Max Error = 0.004864
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 31400: Loss = 0.001031, Max Error = 0.004345
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 31500: Loss = 0.000849, Max Error = 0.004710
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 31600: Loss = 0.000848, Max Error = 0.003973
#   Errors > 0.004: 0 / 17161 (0.00%)
#
# Epoch 31700: Loss = 0.000865, Max Error = 0.004575
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 31800: Loss = 0.000857, Max Error = 0.004721
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 31900: Loss = 0.000638, Max Error = 0.004562
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 32000: Loss = 0.000793, Max Error = 0.004023
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 32100: Loss = 0.000925, Max Error = 0.004528
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 32200: Loss = 0.000909, Max Error = 0.004093
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 32300: Loss = 0.000711, Max Error = 0.004691
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 32400: Loss = 0.000658, Max Error = 0.004688
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 32500: Loss = 0.000575, Max Error = 0.004712
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 32600: Loss = 0.000708, Max Error = 0.004689
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 32700: Loss = 0.000815, Max Error = 0.004078
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 32800: Loss = 0.001007, Max Error = 0.004288
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 32900: Loss = 0.000815, Max Error = 0.004836
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 33000: Loss = 0.000730, Max Error = 0.004711
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 33100: Loss = 0.000955, Max Error = 0.004531
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 33200: Loss = 0.000785, Max Error = 0.004449
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 33300: Loss = 0.000742, Max Error = 0.004159
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 33400: Loss = 0.000902, Max Error = 0.004296
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 33500: Loss = 0.000631, Max Error = 0.004674
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 33600: Loss = 0.000806, Max Error = 0.004600
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 33700: Loss = 0.000861, Max Error = 0.004414
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 33800: Loss = 0.000554, Max Error = 0.004561
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 33900: Loss = 0.000613, Max Error = 0.004088
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 34000: Loss = 0.000700, Max Error = 0.004373
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 34100: Loss = 0.000827, Max Error = 0.004355
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 34200: Loss = 0.000730, Max Error = 0.004734
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 34300: Loss = 0.000679, Max Error = 0.004367
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 34400: Loss = 0.000786, Max Error = 0.004139
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 34500: Loss = 0.000779, Max Error = 0.004139
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 34600: Loss = 0.000886, Max Error = 0.004673
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 34700: Loss = 0.000653, Max Error = 0.004246
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 34800: Loss = 0.000787, Max Error = 0.004208
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 34900: Loss = 0.000992, Max Error = 0.004046
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 35000: Loss = 0.000758, Max Error = 0.004219
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 35100: Loss = 0.000693, Max Error = 0.004374
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 35200: Loss = 0.000806, Max Error = 0.004262
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 35300: Loss = 0.000706, Max Error = 0.004538
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 35400: Loss = 0.000772, Max Error = 0.004492
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 35500: Loss = 0.000776, Max Error = 0.004195
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 35600: Loss = 0.000689, Max Error = 0.004130
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 35700: Loss = 0.000863, Max Error = 0.004009
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 35800: Loss = 0.000765, Max Error = 0.004376
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 35900: Loss = 0.000846, Max Error = 0.004553
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 36000: Loss = 0.000678, Max Error = 0.004165
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 36100: Loss = 0.001043, Max Error = 0.004261
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 36200: Loss = 0.000601, Max Error = 0.004368
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 36300: Loss = 0.000719, Max Error = 0.004697
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 36400: Loss = 0.000669, Max Error = 0.004081
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 36500: Loss = 0.000611, Max Error = 0.004516
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 36600: Loss = 0.000610, Max Error = 0.004344
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 36700: Loss = 0.000870, Max Error = 0.004344
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 36800: Loss = 0.000677, Max Error = 0.004474
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 36900: Loss = 0.000789, Max Error = 0.004152
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 37000: Loss = 0.000543, Max Error = 0.004426
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 37100: Loss = 0.000660, Max Error = 0.004082
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 37200: Loss = 0.000883, Max Error = 0.004114
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 37300: Loss = 0.000495, Max Error = 0.004313
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 37400: Loss = 0.000858, Max Error = 0.004176
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 37500: Loss = 0.000918, Max Error = 0.004203
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 37600: Loss = 0.000666, Max Error = 0.003982
#   Errors > 0.004: 0 / 17161 (0.00%)
#
# Epoch 37700: Loss = 0.000567, Max Error = 0.004500
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 37800: Loss = 0.000576, Max Error = 0.004474
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 37900: Loss = 0.000704, Max Error = 0.004484
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 38000: Loss = 0.000648, Max Error = 0.003962
#   Errors > 0.004: 0 / 17161 (0.00%)
#
# Epoch 38100: Loss = 0.000623, Max Error = 0.004567
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 38200: Loss = 0.000678, Max Error = 0.004474
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 38300: Loss = 0.000639, Max Error = 0.004509
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 38400: Loss = 0.000519, Max Error = 0.004263
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 38500: Loss = 0.000659, Max Error = 0.004194
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 38600: Loss = 0.001065, Max Error = 0.004170
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 38700: Loss = 0.000821, Max Error = 0.004280
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 38800: Loss = 0.000754, Max Error = 0.004294
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 38900: Loss = 0.000873, Max Error = 0.004124
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 39000: Loss = 0.000677, Max Error = 0.004176
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 39100: Loss = 0.000783, Max Error = 0.004188
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 39200: Loss = 0.000559, Max Error = 0.004083
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 39300: Loss = 0.000460, Max Error = 0.004261
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 39400: Loss = 0.000766, Max Error = 0.004305
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 39500: Loss = 0.000620, Max Error = 0.004144
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 39600: Loss = 0.000756, Max Error = 0.004326
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 39700: Loss = 0.000484, Max Error = 0.004182
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 39800: Loss = 0.000638, Max Error = 0.004271
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 39900: Loss = 0.000970, Max Error = 0.004209
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 40000: Loss = 0.000585, Max Error = 0.004097
#   Errors > 0.004: 2 / 17161 (0.01%)
#
# Epoch 40100: Loss = 0.000609, Max Error = 0.004164
#   Errors > 0.004: 2 / 17161 (0.01%)
#
# Epoch 40200: Loss = 0.000718, Max Error = 0.004131
#   Errors > 0.004: 2 / 17161 (0.01%)
#
# Epoch 40300: Loss = 0.000822, Max Error = 0.004337
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 40400: Loss = 0.000976, Max Error = 0.004378
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 40500: Loss = 0.000654, Max Error = 0.004275
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 40600: Loss = 0.000751, Max Error = 0.004495
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 40700: Loss = 0.000797, Max Error = 0.004529
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 40800: Loss = 0.000643, Max Error = 0.004205
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 40900: Loss = 0.000503, Max Error = 0.004104
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 41000: Loss = 0.000549, Max Error = 0.004158
#   Errors > 0.004: 2 / 17161 (0.01%)
#
# Epoch 41100: Loss = 0.000798, Max Error = 0.004251
#   Errors > 0.004: 2 / 17161 (0.01%)
#
# Epoch 41200: Loss = 0.001066, Max Error = 0.004230
#   Errors > 0.004: 2 / 17161 (0.01%)
#
# Epoch 41300: Loss = 0.000736, Max Error = 0.004270
#   Errors > 0.004: 2 / 17161 (0.01%)
#
# Epoch 41400: Loss = 0.000773, Max Error = 0.004365
#   Errors > 0.004: 2 / 17161 (0.01%)
#
# Epoch 41500: Loss = 0.000519, Max Error = 0.004322
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 41600: Loss = 0.000670, Max Error = 0.004359
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 41700: Loss = 0.000741, Max Error = 0.004348
#   Errors > 0.004: 2 / 17161 (0.01%)
#
# Epoch 41800: Loss = 0.000913, Max Error = 0.004645
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 41900: Loss = 0.000428, Max Error = 0.004381
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 42000: Loss = 0.000888, Max Error = 0.004600
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 42100: Loss = 0.000742, Max Error = 0.004843
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 42200: Loss = 0.000534, Max Error = 0.004354
#   Errors > 0.004: 2 / 17161 (0.01%)
#
# Epoch 42300: Loss = 0.000662, Max Error = 0.004524
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 42400: Loss = 0.000669, Max Error = 0.004725
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 42500: Loss = 0.000552, Max Error = 0.004441
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 42600: Loss = 0.000596, Max Error = 0.004324
#   Errors > 0.004: 2 / 17161 (0.01%)
#
# Epoch 42700: Loss = 0.000660, Max Error = 0.004441
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 42800: Loss = 0.000789, Max Error = 0.004642
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 42900: Loss = 0.000591, Max Error = 0.004494
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 43000: Loss = 0.000567, Max Error = 0.004577
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 43100: Loss = 0.000577, Max Error = 0.004908
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 43200: Loss = 0.000782, Max Error = 0.004688
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 43300: Loss = 0.000642, Max Error = 0.004558
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 43400: Loss = 0.000487, Max Error = 0.004906
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 43500: Loss = 0.000504, Max Error = 0.004354
#   Errors > 0.004: 2 / 17161 (0.01%)
#
# Epoch 43600: Loss = 0.000485, Max Error = 0.004730
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 43700: Loss = 0.000762, Max Error = 0.004945
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 43800: Loss = 0.000688, Max Error = 0.004694
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 43900: Loss = 0.000763, Max Error = 0.004596
#   Errors > 0.004: 2 / 17161 (0.01%)
#
# Epoch 44000: Loss = 0.000669, Max Error = 0.004611
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 44100: Loss = 0.000676, Max Error = 0.004780
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 44200: Loss = 0.000709, Max Error = 0.005151
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 44300: Loss = 0.000707, Max Error = 0.005025
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 44400: Loss = 0.000808, Max Error = 0.004647
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 44500: Loss = 0.000606, Max Error = 0.004850
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 44600: Loss = 0.000671, Max Error = 0.005251
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 44700: Loss = 0.000814, Max Error = 0.005096
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 44800: Loss = 0.000823, Max Error = 0.005177
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 44900: Loss = 0.000634, Max Error = 0.004655
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 45000: Loss = 0.000527, Max Error = 0.005198
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 45100: Loss = 0.000547, Max Error = 0.004991
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 45200: Loss = 0.000690, Max Error = 0.005168
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 45300: Loss = 0.000438, Max Error = 0.004867
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 45400: Loss = 0.000668, Max Error = 0.005108
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 45500: Loss = 0.000582, Max Error = 0.005307
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 45600: Loss = 0.000533, Max Error = 0.004855
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 45700: Loss = 0.000524, Max Error = 0.005266
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 45800: Loss = 0.000783, Max Error = 0.005413
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 45900: Loss = 0.000767, Max Error = 0.004968
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 46000: Loss = 0.000614, Max Error = 0.005024
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 46100: Loss = 0.000628, Max Error = 0.005266
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 46200: Loss = 0.000401, Max Error = 0.005097
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 46300: Loss = 0.000619, Max Error = 0.005178
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 46400: Loss = 0.000497, Max Error = 0.005343
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 46500: Loss = 0.000654, Max Error = 0.005078
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 46600: Loss = 0.000741, Max Error = 0.005383
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 46700: Loss = 0.000723, Max Error = 0.005449
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 46800: Loss = 0.000512, Max Error = 0.005198
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 46900: Loss = 0.000404, Max Error = 0.005167
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 47000: Loss = 0.000682, Max Error = 0.005498
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 47100: Loss = 0.000486, Max Error = 0.005338
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 47200: Loss = 0.000493, Max Error = 0.005016
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 47300: Loss = 0.000619, Max Error = 0.005107
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 47400: Loss = 0.000547, Max Error = 0.005575
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 47500: Loss = 0.000491, Max Error = 0.005356
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 47600: Loss = 0.000472, Max Error = 0.005301
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 47700: Loss = 0.000696, Max Error = 0.005371
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 47800: Loss = 0.000581, Max Error = 0.005562
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 47900: Loss = 0.000474, Max Error = 0.005616
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 48000: Loss = 0.000515, Max Error = 0.005625
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 48100: Loss = 0.000490, Max Error = 0.005652
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 48200: Loss = 0.000646, Max Error = 0.005235
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 48300: Loss = 0.000401, Max Error = 0.005618
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 48400: Loss = 0.000406, Max Error = 0.005526
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 48500: Loss = 0.000610, Max Error = 0.005466
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 48600: Loss = 0.000526, Max Error = 0.005762
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 48700: Loss = 0.000410, Max Error = 0.005528
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 48800: Loss = 0.000593, Max Error = 0.005515
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 48900: Loss = 0.000502, Max Error = 0.005751
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 49000: Loss = 0.000601, Max Error = 0.005645
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 49100: Loss = 0.000665, Max Error = 0.005659
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 49200: Loss = 0.000606, Max Error = 0.005888
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 49300: Loss = 0.000486, Max Error = 0.005634
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 49400: Loss = 0.000700, Max Error = 0.005610
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 49500: Loss = 0.000417, Max Error = 0.005827
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 49600: Loss = 0.000547, Max Error = 0.005611
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 49700: Loss = 0.000429, Max Error = 0.005822
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 49800: Loss = 0.000570, Max Error = 0.005725
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 49900: Loss = 0.000591, Max Error = 0.005904
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Epoch 50000: Loss = 0.000732, Max Error = 0.005928
#   Errors > 0.004: 1 / 17161 (0.01%)
#
# Early stopping at epoch 50001: loss and max error stopped improving.
#     Best loss: 0.2266014963388443, Current loss: 0.0004662384162656963
#     Best max error: 0.4058353900909424, Current max error: 0.005650418344885111
# モデルは収束しました。訓練は 50001 エポックで停止しました。
# トレーニングデータの再構成誤差（平均）：0.0004804121175645732
# トレーニングデータの再構成誤差（最大値）：0.0056504330958243336
# モデルの更新: シード値=50
# 結果: units_1_3=40, units_2=10,この時の再構成誤差：0.0004804121175645732
# 1回目の期間のモデル作成終了
# 537/537 ━━━━━━━━━━━━━━━━━━━━ 0s 310us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 最も再構成誤差が大きかったインデックス番号：1245
# 学習データの中に外れ値が発見されたので以降ではモデルの学習を行いません
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 1期間での結果の概要
# トレーニングデータに対する再構成誤差の最大値かつ閾値
# 0.0056504330958243336
# トレーニングデータに対する再構成誤差:0.0004804121175645732
# トレーニングデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.000490
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.000543
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.000254
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.000361
# processor_unit_units_status_cpu_board_cpu_core_temp    0.000264
# processor_unit_units_status_cpu_board_gpu_core_temp    0.000206
# processor_unit_units_status_cpu_board_cpu_core_vol     0.000790
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.000353
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.000420
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.000142
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.000341
# dtype: float64
# テストデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.006058
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.001678
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.014363
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.004127
# processor_unit_units_status_cpu_board_cpu_core_temp    0.002987
# processor_unit_units_status_cpu_board_gpu_core_temp    0.000285
# processor_unit_units_status_cpu_board_cpu_core_vol     0.002288
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.000750
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.002364
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.101070
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.006463
# dtype: float64
# 閾値データの各特徴量ごとの再構成誤差
# processor_unit_units_status_cpu_board_cpu_fan          0.001204
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.000758
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.002363
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.000883
# processor_unit_units_status_cpu_board_cpu_core_temp    0.000625
# processor_unit_units_status_cpu_board_gpu_core_temp    0.000638
# processor_unit_units_status_cpu_board_cpu_core_vol     0.001710
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.000151
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.018410
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.000222
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.000290
# Name: 1245, dtype: float64
# trainの日付の最大値:2018/6/01 00:00:00
# testの日付の最大値:2018/7/01 00:00:00
# 異常値と閾値の保存
# =====================================================================================
# 2回目の期間のモデル
# 該当期間の確認
# はじまり(train)2016/7/01 00:00:00
# 終わり(train)2018/7/01 00:00:00
# はじまり(test)2018/7/01 00:00:00
# 終わり(test)2018/8/01 00:00:00
# 2回目の期間のモデル作成開始
# 2回目の期間のトレーニングデータ数:17141
# 2回目の期間においてはすでにあるモデルを使用します
# 195/536 ━━━━━━━━━━━━━━━━━━━━ 0s 308us/step
# c:\Users\keisu\Desktop\研究元ファイル\abnormal\research_abnormal\src\model\model_single_node_fixed_research_train_data.py:163: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   abnormal_scores = pd.concat([abnormal_scores,abnormal_score_df])
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 0s 293us/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step
# 最も再構成誤差が大きかったインデックス番号：16870
# 次の期間でも学習を続けます
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2期間での結果の概要
# トレーニングデータに対する再構成誤差の最大値かつ閾値
# 0.0056504330958243336
# トレーニングデータに対する再構成誤差:0.0004804121175645732
# トレーニングデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.000490
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.000543
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.000254
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.000361
# processor_unit_units_status_cpu_board_cpu_core_temp    0.000264
# processor_unit_units_status_cpu_board_gpu_core_temp    0.000206
# processor_unit_units_status_cpu_board_cpu_core_vol     0.000790
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.000353
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.000420
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.000142
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.000341
# dtype: float64
# テストデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.010329
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.002732
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.024408
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.007190
# processor_unit_units_status_cpu_board_cpu_core_temp    0.005007
# processor_unit_units_status_cpu_board_gpu_core_temp    0.000494
# processor_unit_units_status_cpu_board_cpu_core_vol     0.003319
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.001276
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.003833
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.175721
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.010920
# dtype: float64
# 閾値データの各特徴量ごとの再構成誤差
# processor_unit_units_status_cpu_board_cpu_fan          0.001204
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.000758
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.002363
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.000883
# processor_unit_units_status_cpu_board_cpu_core_temp    0.000625
# processor_unit_units_status_cpu_board_gpu_core_temp    0.000638
# processor_unit_units_status_cpu_board_cpu_core_vol     0.001710
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.000151
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.018410
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.000222
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.000290
# Name: 1245, dtype: float64
# trainの日付の最大値:2018/7/01 00:00:00
# testの日付の最大値:2018/8/01 00:00:00
# 異常値と閾値の保存
# =====================================================================================
# 3回目の期間のモデル
# 該当期間の確認
# はじまり(train)2016/8/01 00:00:00
# 終わり(train)2018/8/01 00:00:00
# はじまり(test)2018/8/01 00:00:00
# 終わり(test)2018/9/01 00:00:00
# 3回目の期間のモデル作成開始
# 3回目の期間のトレーニングデータ数:17129
# 3回目の期間においてはすでにあるモデルを使用します
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 0s 325us/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step
# 最も再構成誤差が大きかったインデックス番号：16165
# 次の期間でも学習を続けます
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 3期間での結果の概要
# トレーニングデータに対する再構成誤差の最大値かつ閾値
# 0.0056504330958243336
# トレーニングデータに対する再構成誤差:0.0004804121175645732
# トレーニングデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.000490
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.000543
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.000254
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.000361
# processor_unit_units_status_cpu_board_cpu_core_temp    0.000264
# processor_unit_units_status_cpu_board_gpu_core_temp    0.000206
# processor_unit_units_status_cpu_board_cpu_core_vol     0.000790
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.000353
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.000420
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.000142
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.000341
# dtype: float64
# テストデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.027856
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.007572
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.081376
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.018979
# processor_unit_units_status_cpu_board_cpu_core_temp    0.013750
# processor_unit_units_status_cpu_board_gpu_core_temp    0.001376
# processor_unit_units_status_cpu_board_cpu_core_vol     0.011417
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.005065
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.014555
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.588499
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.029854
# dtype: float64
# 閾値データの各特徴量ごとの再構成誤差
# processor_unit_units_status_cpu_board_cpu_fan          0.001204
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.000758
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.002363
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.000883
# processor_unit_units_status_cpu_board_cpu_core_temp    0.000625
# processor_unit_units_status_cpu_board_gpu_core_temp    0.000638
# processor_unit_units_status_cpu_board_cpu_core_vol     0.001710
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.000151
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.018410
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.000222
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.000290
# Name: 1245, dtype: float64
# trainの日付の最大値:2018/8/01 00:00:00
# testの日付の最大値:2018/9/01 00:00:00
# 異常値と閾値の保存
# data_exの日付の最大値:2019-02-04 23:00:02
# data_exのデータ数:26425
# data_exの最終月に含まれるデータ数:96
