# %% [markdown]
# ライブラリの呼び出し

# %%
import sys
import os

# 現在の作業ディレクトリを基にプロジェクトのルートディレクトリを設定
project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..','..'))
sys.path.append(project_root)
print(project_root)
# Out:
# c:\Users\keisu\Desktop\研究元ファイル\abnormal\research_abnormal

# %%
#必要ライブラリのインストール
from src import data
from src.model import model_single_node_fixed_research_train_data
import config

# %%
#モジュールの再リロード
import importlib
import custom_class.custom_learning_average_stopping_maxdata_max_stop
import src
import src.data
import src.model
import src.model.model_single_node_fixed_research_train_data
import src.model_basic_single_node_research_train_data

importlib.reload(src.data)
importlib.reload(custom_class.custom_learning_average_stopping_maxdata_max_stop)
importlib.reload(src.model.model_single_node_fixed_research_train_data)
importlib.reload(src.model_basic_single_node_research_train_data)
# Out:
# <module 'src.model_basic_single_node_research_train_data' from 'c:\\Users\\keisu\\Desktop\\研究元ファイル\\abnormal\\research_abnormal\\src\\model_basic_single_node_research_train_data.py'>

# %% [markdown]
# データの読み込み

# %%
#データの読み込み及び加工、コラムリストの取得
data_ex, data_original = data.data_complete()
# Out:
# キャッシュファイルからデータを読み込みます

# %% [markdown]
# ハイパーパラメータの設定

# %%
#ハイパーパラメータの設定

#最大エポック数
max_epochs = 100000

#ノード数
units = 11

#モデル決定の閾値（再構成誤差のパラメータ）
#この閾値を下回ることで十分な性能を持つモデルとする
#今回は使用しない
error_threshold = 1

# シード値の準備
seeds = [50,51,52,53]

# ユニット数の準備
unit13_1 = 40
unit2_1 = 10
unit13_2 = 30
unit2_2 = 5
unit13_3 = 20
unit2_3 = 2

units = [[unit13_1, unit2_1],[unit13_2, unit2_2],[unit13_3, unit2_3]]

# 学習バッチサイズ
batch_size=64

# 監視するエポック数
patience = 1

# 学習変化の閾値
min_delta = 1

# 最大データの監視するエポック
patience_max = 1

# 最大データの閾値
min_delta_max = 1

# 何期間連続して予測を行うか
num = 3

#　初期化回数
num_retry = 4

#　詳細な出力
detail_log = True

#　どこまでの値より大きいデータ点をログの中で数えるか
confirm_datapoint = 0.004

#学習率
learning_rate = 1e-3

#トレーニング開始日
train_start = "2016/6/01 00:00:00"

#テスト開始日
test_start = "2018/6/01 00:00:00"



params = {"max_epochs":max_epochs, "units":units,
	"error_threshold":error_threshold, "seeds":seeds, "units":units, 
	"batch_size":batch_size, "patience":patience, "min_delta": min_delta, "patience_max":patience_max, "min_delta_max" : min_delta_max, "num":num, "train_start" : train_start, "test_start" : test_start,
    "num_retry": num_retry, "detail_log":detail_log, "confirm_datapoint":confirm_datapoint, "learning_rate":learning_rate}

# %%
#実験の実行及び結果の格納
abnormal_scores, thresholds = model_single_node_fixed_research_train_data.result(data_ex , params)
# Out:
# =====================================================================================
# 1回目の期間のモデル
# 該当期間の確認
# はじまり(train)2016/6/01 00:00:00
# 終わり(train)2018/6/01 00:00:00
# はじまり(test)2018/6/01 00:00:00
# 終わり(test)2018/7/01 00:00:00
# 1回目の期間のモデル作成開始
# 1回目の期間のトレーニングデータ数:17161
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=40, units_2=10, 試行回数=1, seed値 = 50
# Early stopping at epoch 2: loss and max error stopped improving.
#     Best loss: 0.2266014963388443, Current loss: 0.14176960289478302
#     Best max error: 0.4058353900909424, Current max error: 0.3702999949455261
# 各エポックの各データ（日付）誤差を保存しました：reconstruction_errors_per_epoch.csv
# モデルは収束しました。訓練は 2 エポックで停止しました。
# トレーニングデータの再構成誤差（平均）：0.15044891199115387
# トレーニングデータの再構成誤差（最大値）：0.37029998269786335
# モデルの更新: シード値=50
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=40, units_2=10, 試行回数=2, seed値 = 51
# Early stopping at epoch 2: loss and max error stopped improving.
#     Best loss: 0.24965885281562805, Current loss: 0.141127809882164
#     Best max error: 0.43352577090263367, Current max error: 0.3680386245250702
# 各エポックの各データ（日付）誤差を保存しました：reconstruction_errors_per_epoch.csv
# モデルは収束しました。訓練は 2 エポックで停止しました。
# トレーニングデータの再構成誤差（平均）：0.14950615571635884
# トレーニングデータの再構成誤差（最大値）：0.36803861079746264
# モデルの更新: シード値=51
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=40, units_2=10, 試行回数=3, seed値 = 52
# Early stopping at epoch 2: loss and max error stopped improving.
#     Best loss: 0.24840369820594788, Current loss: 0.14153949916362762
#     Best max error: 0.42432376742362976, Current max error: 0.36398833990097046
# 各エポックの各データ（日付）誤差を保存しました：reconstruction_errors_per_epoch.csv
# モデルは収束しました。訓練は 2 エポックで停止しました。
# トレーニングデータの再構成誤差（平均）：0.14988834807747584
# トレーニングデータの再構成誤差（最大値）：0.36398837175955284
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=40, units_2=10, 試行回数=4, seed値 = 53
# Early stopping at epoch 2: loss and max error stopped improving.
#     Best loss: 0.1755630224943161, Current loss: 0.1418844610452652
#     Best max error: 0.37929800152778625, Current max error: 0.361427366733551
# 各エポックの各データ（日付）誤差を保存しました：reconstruction_errors_per_epoch.csv
# モデルは収束しました。訓練は 2 エポックで停止しました。
# トレーニングデータの再構成誤差（平均）：0.1504925472159945
# トレーニングデータの再構成誤差（最大値）：0.3614273575012229
# 結果: units_1_3=40, units_2=10,この時の再構成誤差：0.14950615571635884
# 1回目の期間のモデル作成終了
# 537/537 ━━━━━━━━━━━━━━━━━━━━ 0s 361us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 最も再構成誤差が大きかったインデックス番号：5894
# 次の期間でも学習を続けます
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 1期間での結果の概要
# トレーニングデータに対する再構成誤差の最大値かつ閾値
# 0.36803861079746264
# トレーニングデータに対する再構成誤差:0.14950615571635884
# トレーニングデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.109449
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.131311
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.026253
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.109508
# processor_unit_units_status_cpu_board_cpu_core_temp    0.091351
# processor_unit_units_status_cpu_board_gpu_core_temp    0.110739
# processor_unit_units_status_cpu_board_cpu_core_vol     0.184487
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.075832
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.156482
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.130029
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.072245
# dtype: float64
# テストデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.129661
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.123334
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.080366
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.100173
# processor_unit_units_status_cpu_board_cpu_core_temp    0.090372
# processor_unit_units_status_cpu_board_gpu_core_temp    0.092558
# processor_unit_units_status_cpu_board_cpu_core_vol     0.183505
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.035338
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.241538
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.033029
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.044612
# dtype: float64
# 閾値データの各特徴量ごとの再構成誤差
# processor_unit_units_status_cpu_board_cpu_fan          0.516217
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.372070
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.086231
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.536079
# processor_unit_units_status_cpu_board_cpu_core_temp    0.463127
# processor_unit_units_status_cpu_board_gpu_core_temp    0.426790
# processor_unit_units_status_cpu_board_cpu_core_vol     0.248026
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.432137
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.015515
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.294802
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.241245
# Name: 5894, dtype: float64
# trainの日付の最大値:2018/6/01 00:00:00
# testの日付の最大値:2018/7/01 00:00:00
# 異常値と閾値の保存
# =====================================================================================
# 2回目の期間のモデル
# 該当期間の確認
# はじまり(train)2016/7/01 00:00:00
# 終わり(train)2018/7/01 00:00:00
# はじまり(test)2018/7/01 00:00:00
# 終わり(test)2018/8/01 00:00:00
# 2回目の期間のモデル作成開始
# 2回目の期間のトレーニングデータ数:17141
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=30, units_2=5, 試行回数=1, seed値 = 50
# c:\Users\keisu\Desktop\研究元ファイル\abnormal\research_abnormal\src\model\model_single_node_fixed_research_train_data.py:163: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   abnormal_scores = pd.concat([abnormal_scores,abnormal_score_df])
# Early stopping at epoch 2: loss and max error stopped improving.
#     Best loss: 0.25896114110946655, Current loss: 0.14365044236183167
#     Best max error: 0.44019508361816406, Current max error: 0.3598578870296478
# 各エポックの各データ（日付）誤差を保存しました：reconstruction_errors_per_epoch.csv
# モデルは収束しました。訓練は 2 エポックで停止しました。
# トレーニングデータの再構成誤差（平均）：0.15178937280995547
# トレーニングデータの再構成誤差（最大値）：0.35985784943579835
# モデルの更新: シード値=50
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=30, units_2=5, 試行回数=2, seed値 = 51
# Early stopping at epoch 2: loss and max error stopped improving.
#     Best loss: 0.2599613666534424, Current loss: 0.14351406693458557
#     Best max error: 0.43096616864204407, Current max error: 0.359897255897522
# 各エポックの各データ（日付）誤差を保存しました：reconstruction_errors_per_epoch.csv
# モデルは収束しました。訓練は 2 エポックで停止しました。
# トレーニングデータの再構成誤差（平均）：0.15146125858596815
# トレーニングデータの再構成誤差（最大値）：0.35989727076831723
# モデルの更新: シード値=51
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=30, units_2=5, 試行回数=3, seed値 = 52
# Early stopping at epoch 2: loss and max error stopped improving.
#     Best loss: 0.2553757429122925, Current loss: 0.14351660013198853
#     Best max error: 0.42664480209350586, Current max error: 0.35163235664367676
# 各エポックの各データ（日付）誤差を保存しました：reconstruction_errors_per_epoch.csv
# モデルは収束しました。訓練は 2 エポックで停止しました。
# トレーニングデータの再構成誤差（平均）：0.1514617675067098
# トレーニングデータの再構成誤差（最大値）：0.3516323471338827
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=30, units_2=5, 試行回数=4, seed値 = 53
# Early stopping at epoch 2: loss and max error stopped improving.
#     Best loss: 0.23683424293994904, Current loss: 0.14095625281333923
#     Best max error: 0.41619786620140076, Current max error: 0.36703839898109436
# 各エポックの各データ（日付）誤差を保存しました：reconstruction_errors_per_epoch.csv
# モデルは収束しました。訓練は 2 エポックで停止しました。
# トレーニングデータの再構成誤差（平均）：0.14971180380431615
# トレーニングデータの再構成誤差（最大値）：0.3670383823819962
# モデルの更新: シード値=53
# 結果: units_1_3=30, units_2=5,この時の再構成誤差：0.14971180380431615
# 2回目の期間のモデル作成終了
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 0s 311us/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step
# 最も再構成誤差が大きかったインデックス番号：5224
# 次の期間でも学習を続けます
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2期間での結果の概要
# トレーニングデータに対する再構成誤差の最大値かつ閾値
# 0.3670383823819962
# トレーニングデータに対する再構成誤差:0.14971180380431615
# トレーニングデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.113209
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.127147
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.029973
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.111539
# processor_unit_units_status_cpu_board_cpu_core_temp    0.093510
# processor_unit_units_status_cpu_board_gpu_core_temp    0.110772
# processor_unit_units_status_cpu_board_cpu_core_vol     0.184469
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.067833
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.158591
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.119211
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.063561
# dtype: float64
# テストデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.087333
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.086515
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.090520
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.102699
# processor_unit_units_status_cpu_board_cpu_core_temp    0.088252
# processor_unit_units_status_cpu_board_gpu_core_temp    0.099143
# processor_unit_units_status_cpu_board_cpu_core_vol     0.196149
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.032226
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.192098
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.017519
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.044989
# dtype: float64
# 閾値データの各特徴量ごとの再構成誤差
# processor_unit_units_status_cpu_board_cpu_fan          0.524206
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.399603
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.100138
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.537570
# processor_unit_units_status_cpu_board_cpu_core_temp    0.444549
# processor_unit_units_status_cpu_board_gpu_core_temp    0.434789
# processor_unit_units_status_cpu_board_cpu_core_vol     0.249588
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.376327
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.049343
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.341174
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.197457
# Name: 5224, dtype: float64
# trainの日付の最大値:2018/7/01 00:00:00
# testの日付の最大値:2018/8/01 00:00:00
# 異常値と閾値の保存
# =====================================================================================
# 3回目の期間のモデル
# 該当期間の確認
# はじまり(train)2016/8/01 00:00:00
# 終わり(train)2018/8/01 00:00:00
# はじまり(test)2018/8/01 00:00:00
# 終わり(test)2018/9/01 00:00:00
# 3回目の期間のモデル作成開始
# 3回目の期間のトレーニングデータ数:17129
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=20, units_2=2, 試行回数=1, seed値 = 50
# Early stopping at epoch 2: loss and max error stopped improving.
#     Best loss: 0.25824886560440063, Current loss: 0.21591241657733917
#     Best max error: 0.4560486674308777, Current max error: 0.4038577675819397
# 各エポックの各データ（日付）誤差を保存しました：reconstruction_errors_per_epoch.csv
# モデルは収束しました。訓練は 2 エポックで停止しました。
# トレーニングデータの再構成誤差（平均）：0.22383152608237813
# トレーニングデータの再構成誤差（最大値）：0.4038577754009477
# モデルの更新: シード値=50
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=20, units_2=2, 試行回数=2, seed値 = 51
# Early stopping at epoch 2: loss and max error stopped improving.
#     Best loss: 0.25649043917655945, Current loss: 0.1879107654094696
#     Best max error: 0.4597231149673462, Current max error: 0.4012805223464966
# 各エポックの各データ（日付）誤差を保存しました：reconstruction_errors_per_epoch.csv
# モデルは収束しました。訓練は 2 エポックで停止しました。
# トレーニングデータの再構成誤差（平均）：0.19612220727008603
# トレーニングデータの再構成誤差（最大値）：0.4012805249906005
# モデルの更新: シード値=51
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=20, units_2=2, 試行回数=3, seed値 = 52
# Early stopping at epoch 2: loss and max error stopped improving.
#     Best loss: 0.255230188369751, Current loss: 0.19017428159713745
#     Best max error: 0.45614778995513916, Current max error: 0.4043199419975281
# 各エポックの各データ（日付）誤差を保存しました：reconstruction_errors_per_epoch.csv
# モデルは収束しました。訓練は 2 エポックで停止しました。
# トレーニングデータの再構成誤差（平均）：0.19787883034302634
# トレーニングデータの再構成誤差（最大値）：0.40431989354062414
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=20, units_2=2, 試行回数=4, seed値 = 53
# Early stopping at epoch 2: loss and max error stopped improving.
#     Best loss: 0.2559794783592224, Current loss: 0.15661275386810303
#     Best max error: 0.4411935806274414, Current max error: 0.37018364667892456
# 各エポックの各データ（日付）誤差を保存しました：reconstruction_errors_per_epoch.csv
# モデルは収束しました。訓練は 2 エポックで停止しました。
# トレーニングデータの再構成誤差（平均）：0.1646523832357441
# トレーニングデータの再構成誤差（最大値）：0.37018363699213536
# モデルの更新: シード値=53
# 結果: units_1_3=20, units_2=2,この時の再構成誤差：0.1646523832357441
# 3回目の期間のモデル作成終了
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 0s 304us/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 19us/step
# 最も再構成誤差が大きかったインデックス番号：4518
# 次の期間でも学習を続けます
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 3期間での結果の概要
# トレーニングデータに対する再構成誤差の最大値かつ閾値
# 0.37018363699213536
# トレーニングデータに対する再構成誤差:0.1646523832357441
# トレーニングデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.118029
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.126543
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.034572
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.113905
# processor_unit_units_status_cpu_board_cpu_core_temp    0.094238
# processor_unit_units_status_cpu_board_gpu_core_temp    0.111602
# processor_unit_units_status_cpu_board_cpu_core_vol     0.186758
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.079174
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.160943
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.198309
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.128402
# dtype: float64
# テストデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.090251
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.074625
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.186163
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.126402
# processor_unit_units_status_cpu_board_cpu_core_temp    0.104413
# processor_unit_units_status_cpu_board_gpu_core_temp    0.097766
# processor_unit_units_status_cpu_board_cpu_core_vol     0.203410
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.060916
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.135395
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.083132
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.109699
# dtype: float64
# 閾値データの各特徴量ごとの再構成誤差
# processor_unit_units_status_cpu_board_cpu_fan          0.517696
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.431189
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.090451
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.547301
# processor_unit_units_status_cpu_board_cpu_core_temp    0.423049
# processor_unit_units_status_cpu_board_gpu_core_temp    0.471879
# processor_unit_units_status_cpu_board_cpu_core_vol     0.310213
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.235935
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.095676
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.427420
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.019054
# Name: 4518, dtype: float64
# trainの日付の最大値:2018/8/01 00:00:00
# testの日付の最大値:2018/9/01 00:00:00
# 異常値と閾値の保存
# data_exの日付の最大値:2019-02-04 23:00:02
# data_exのデータ数:26425
# data_exの最終月に含まれるデータ数:96
