# %% [markdown]
# ライブラリの呼び出し

# %%
import sys
import os

# 現在の作業ディレクトリを基にプロジェクトのルートディレクトリを設定
project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..','..'))
sys.path.append(project_root)
print(project_root)
# Out:
# c:\Users\keisu\Desktop\研究元ファイル\abnormal\research_abnormal

# %%
#必要ライブラリのインストール
from src import data
from src.model import model_single_node_fixed_research_train_data
import config

# %%
#モジュールの再リロード
import importlib
import custom_class.custom_learning_average_stopping_maxdata_max_stop
import src
import src.data
import src.model
import src.model.model_single_node_fixed_research_train_data
import src.model_basic_single_node_research_train_data

importlib.reload(src.data)
importlib.reload(custom_class.custom_learning_average_stopping_maxdata_max_stop)
importlib.reload(src.model.model_single_node_fixed_research_train_data)
importlib.reload(src.model_basic_single_node_research_train_data)
# Out:
# <module 'src.model_basic_single_node_research_train_data' from 'c:\\Users\\keisu\\Desktop\\研究元ファイル\\abnormal\\research_abnormal\\src\\model_basic_single_node_research_train_data.py'>

# %% [markdown]
# データの読み込み

# %%
#データの読み込み及び加工、コラムリストの取得
data_ex, data_original = data.data_complete()
# Out:
# キャッシュファイルからデータを読み込みます

# %% [markdown]
# ハイパーパラメータの設定

# %%
#ハイパーパラメータの設定

#最大エポック数
max_epochs = 100000

#ノード数
units = 11

#モデル決定の閾値（再構成誤差のパラメータ）
#この閾値を下回ることで十分な性能を持つモデルとする
#今回は使用しない
error_threshold = 1

# シード値の準備
seeds = [50]

#　初期化回数
num_retry = 1

# ユニット数の準備
unit13_1 = 40
unit2_1 = 10
unit13_2 = 30
unit2_2 = 5
unit13_3 = 20
unit2_3 = 2

units = [[unit13_1, unit2_1],[unit13_2, unit2_2],[unit13_3, unit2_3]]

# 学習バッチサイズ
batch_size=64

# 監視するエポック数
patience = 1000

# 学習変化の閾値
min_delta = 1

# 最大データの監視するエポック
patience_max = 1

# 最大データの閾値
min_delta_max = 1

# 何期間連続して予測を行うか
num = 3



#　詳細な出力
detail_log = True

#　どこまでの値より大きいデータ点をログの中で数えるか
confirm_datapoint = 0.004

#学習率
learning_rate = 1e-3

#トレーニング開始日
train_start = "2016/6/01 00:00:00"

#テスト開始日
test_start = "2018/6/01 00:00:00"



params = {"max_epochs":max_epochs, "units":units,
	"error_threshold":error_threshold, "seeds":seeds, "units":units, 
	"batch_size":batch_size, "patience":patience, "min_delta": min_delta, "patience_max":patience_max, "min_delta_max" : min_delta_max, "num":num, "train_start" : train_start, "test_start" : test_start,
    "num_retry": num_retry, "detail_log":detail_log, "confirm_datapoint":confirm_datapoint, "learning_rate":learning_rate}

# %%
#実験の実行及び結果の格納
abnormal_scores, thresholds = model_single_node_fixed_research_train_data.result(data_ex , params)
# Out:
# =====================================================================================
# 1回目の期間のモデル
# 該当期間の確認
# はじまり(train)2016/6/01 00:00:00
# 終わり(train)2018/6/01 00:00:00
# はじまり(test)2018/6/01 00:00:00
# 終わり(test)2018/7/01 00:00:00
# 1回目の期間のモデル作成開始
# 1回目の期間のトレーニングデータ数:17161
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=40, units_2=10, 試行回数=1, seed値 = 50
# Epoch 100: Loss = 0.019532, Max Error = 0.117365
#   Errors > 0.004: 17148 / 17161 (99.92%)
#
# Epoch 200: Loss = 0.013920, Max Error = 0.093430
#   Errors > 0.004: 17121 / 17161 (99.77%)
#
# Epoch 300: Loss = 0.008722, Max Error = 0.034152
#   Errors > 0.004: 15935 / 17161 (92.86%)
#
# Epoch 400: Loss = 0.007504, Max Error = 0.026769
#   Errors > 0.004: 15756 / 17161 (91.81%)
#
# Epoch 500: Loss = 0.005997, Max Error = 0.027396
#   Errors > 0.004: 12702 / 17161 (74.02%)
#
# Epoch 600: Loss = 0.005870, Max Error = 0.027467
#   Errors > 0.004: 12212 / 17161 (71.16%)
#
# Epoch 700: Loss = 0.005809, Max Error = 0.027437
#   Errors > 0.004: 12009 / 17161 (69.98%)
#
# Epoch 800: Loss = 0.005745, Max Error = 0.027365
#   Errors > 0.004: 11787 / 17161 (68.68%)
#
# Epoch 900: Loss = 0.005668, Max Error = 0.027298
#   Errors > 0.004: 11484 / 17161 (66.92%)
#
# Epoch 1000: Loss = 0.005625, Max Error = 0.027230
#   Errors > 0.004: 11336 / 17161 (66.06%)
#
# Early stopping at epoch 1001: loss and max error stopped improving.
#     Best loss: 0.2266014963388443, Current loss: 0.005624855402857065
#     Best max error: 0.4058353900909424, Current max error: 0.02722909301519394
# モデルは収束しました。訓練は 1001 エポックで停止しました。
# トレーニングデータの再構成誤差（平均）：0.006279573253723052
# トレーニングデータの再構成誤差（最大値）：0.02722910323456459
# モデルの更新: シード値=50
# 結果: units_1_3=40, units_2=10,この時の再構成誤差：0.006279573253723052
# 1回目の期間のモデル作成終了
# 537/537 ━━━━━━━━━━━━━━━━━━━━ 0s 445us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 最も再構成誤差が大きかったインデックス番号：17149
# 学習データの中に外れ値が発見されたので以降ではモデルの学習を行いません
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 1期間での結果の概要
# トレーニングデータに対する再構成誤差の最大値かつ閾値
# 0.02722910323456459
# トレーニングデータに対する再構成誤差:0.006279573253723052
# トレーニングデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.004026
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.004759
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.014324
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.003303
# processor_unit_units_status_cpu_board_cpu_core_temp    0.001964
# processor_unit_units_status_cpu_board_gpu_core_temp    0.003871
# processor_unit_units_status_cpu_board_cpu_core_vol     0.002722
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.001816
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.001309
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.001241
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.002057
# dtype: float64
# テストデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.019011
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.003341
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.065853
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.004863
# processor_unit_units_status_cpu_board_cpu_core_temp    0.005347
# processor_unit_units_status_cpu_board_gpu_core_temp    0.005048
# processor_unit_units_status_cpu_board_cpu_core_vol     0.003123
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.001697
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.001645
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.001306
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.001207
# dtype: float64
# 閾値データの各特徴量ごとの再構成誤差
# processor_unit_units_status_cpu_board_cpu_fan          0.021447
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.001257
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.087129
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.007097
# processor_unit_units_status_cpu_board_cpu_core_temp    0.005523
# processor_unit_units_status_cpu_board_gpu_core_temp    0.003346
# processor_unit_units_status_cpu_board_cpu_core_vol     0.002342
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.002073
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.000660
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.000084
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.000584
# Name: 17149, dtype: float64
# trainの日付の最大値:2018/6/01 00:00:00
# testの日付の最大値:2018/7/01 00:00:00
# 異常値と閾値の保存
# =====================================================================================
# 2回目の期間のモデル
# 該当期間の確認
# はじまり(train)2016/7/01 00:00:00
# 終わり(train)2018/7/01 00:00:00
# はじまり(test)2018/7/01 00:00:00
# 終わり(test)2018/8/01 00:00:00
# 2回目の期間のモデル作成開始
# 2回目の期間のトレーニングデータ数:17141
# 2回目の期間においてはすでにあるモデルを使用します
# 210/536 ━━━━━━━━━━━━━━━━━━━━ 0s 483us/step
# c:\Users\keisu\Desktop\研究元ファイル\abnormal\research_abnormal\src\model\model_single_node_fixed_research_train_data.py:163: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   abnormal_scores = pd.concat([abnormal_scores,abnormal_score_df])
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step
# 最も再構成誤差が大きかったインデックス番号：16874
# 次の期間でも学習を続けます
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2期間での結果の概要
# トレーニングデータに対する再構成誤差の最大値かつ閾値
# 0.02722910323456459
# トレーニングデータに対する再構成誤差:0.006279573253723052
# トレーニングデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.004026
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.004759
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.014324
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.003303
# processor_unit_units_status_cpu_board_cpu_core_temp    0.001964
# processor_unit_units_status_cpu_board_gpu_core_temp    0.003871
# processor_unit_units_status_cpu_board_cpu_core_vol     0.002722
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.001816
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.001309
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.001241
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.002057
# dtype: float64
# テストデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.024670
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.002088
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.089130
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.008140
# processor_unit_units_status_cpu_board_cpu_core_temp    0.006080
# processor_unit_units_status_cpu_board_gpu_core_temp    0.004466
# processor_unit_units_status_cpu_board_cpu_core_vol     0.002911
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.002572
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.002252
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.001478
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.001274
# dtype: float64
# 閾値データの各特徴量ごとの再構成誤差
# processor_unit_units_status_cpu_board_cpu_fan          0.021447
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.001257
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.087129
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.007097
# processor_unit_units_status_cpu_board_cpu_core_temp    0.005523
# processor_unit_units_status_cpu_board_gpu_core_temp    0.003346
# processor_unit_units_status_cpu_board_cpu_core_vol     0.002342
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.002073
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.000660
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.000084
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.000584
# Name: 17149, dtype: float64
# trainの日付の最大値:2018/7/01 00:00:00
# testの日付の最大値:2018/8/01 00:00:00
# 異常値と閾値の保存
# =====================================================================================
# 3回目の期間のモデル
# 該当期間の確認
# はじまり(train)2016/8/01 00:00:00
# 終わり(train)2018/8/01 00:00:00
# はじまり(test)2018/8/01 00:00:00
# 終わり(test)2018/9/01 00:00:00
# 3回目の期間のモデル作成開始
# 3回目の期間のトレーニングデータ数:17129
# 3回目の期間においてはすでにあるモデルを使用します
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 728us/step
# 最も再構成誤差が大きかったインデックス番号：17111
# 次の期間でも学習を続けます
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 3期間での結果の概要
# トレーニングデータに対する再構成誤差の最大値かつ閾値
# 0.02722910323456459
# トレーニングデータに対する再構成誤差:0.006279573253723052
# トレーニングデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.004026
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.004759
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.014324
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.003303
# processor_unit_units_status_cpu_board_cpu_core_temp    0.001964
# processor_unit_units_status_cpu_board_gpu_core_temp    0.003871
# processor_unit_units_status_cpu_board_cpu_core_vol     0.002722
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.001816
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.001309
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.001241
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.002057
# dtype: float64
# テストデータに対する特徴量ごとの再構成誤差の平均
# processor_unit_units_status_cpu_board_cpu_fan          0.048346
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.003202
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.183942
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.019565
# processor_unit_units_status_cpu_board_cpu_core_temp    0.010764
# processor_unit_units_status_cpu_board_gpu_core_temp    0.004354
# processor_unit_units_status_cpu_board_cpu_core_vol     0.002359
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.005698
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.003096
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.002060
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.002231
# dtype: float64
# 閾値データの各特徴量ごとの再構成誤差
# processor_unit_units_status_cpu_board_cpu_fan          0.021447
# processor_unit_units_status_cpu_board_cpu_bd_fan1      0.001257
# processor_unit_units_status_cpu_board_cpu_bd_fan2      0.087129
# processor_unit_units_status_cpu_board_cpu_bd_temp      0.007097
# processor_unit_units_status_cpu_board_cpu_core_temp    0.005523
# processor_unit_units_status_cpu_board_gpu_core_temp    0.003346
# processor_unit_units_status_cpu_board_cpu_core_vol     0.002342
# processor_unit_units_status_cpu_board_cpu_bd_vbat      0.002073
# processor_unit_units_status_cpu_board_cpu_bd_p3_3v     0.000660
# processor_unit_units_status_cpu_board_cpu_bd_p5v       0.000084
# processor_unit_units_status_cpu_board_cpu_bd_p12v      0.000584
# Name: 17149, dtype: float64
# trainの日付の最大値:2018/8/01 00:00:00
# testの日付の最大値:2018/9/01 00:00:00
# 異常値と閾値の保存
# data_exの日付の最大値:2019-02-04 23:00:02
# data_exのデータ数:26425
# data_exの最終月に含まれるデータ数:96
