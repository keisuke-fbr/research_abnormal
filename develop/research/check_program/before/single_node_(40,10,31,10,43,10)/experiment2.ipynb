# %% [markdown]
# ライブラリの呼び出し

# %%
import sys
import os

# 現在の作業ディレクトリを基にプロジェクトのルートディレクトリを設定
project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
sys.path.append(project_root)
project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..','..','..','..'))
sys.path.append(project_root)
print(project_root)
# Out:
# c:\Users\keisu\Desktop\研究元ファイル\abnormal\research_abnormal

# %%
#必要ライブラリのインストール
from src import data
from functions import model_basic
from custom_Class import custom_earlystopping
import config

# %%
#モジュールの再リロード
import importlib
import src
import functions.model_basic
import functions.model_function
import custom_Class.custom_earlystopping

importlib.reload(data)
importlib.reload(custom_Class.custom_earlystopping)
importlib.reload(functions.model_basic)
importlib.reload(functions.model_function)
# Out:
# <module 'functions.model_function' from 'c:\\Users\\keisu\\Desktop\\研究元ファイル\\abnormal\\research_abnormal\\develop\\search\\search_skip\\functions\\model_function.py'>

# %% [markdown]
# データの読み込み

# %%
#データの読み込み及び加工、コラムリストの取得
data_ex, data_original = data.data_complete()
# Out:
# キャッシュファイルからデータを読み込みます

# %% [markdown]
# ハイパーパラメータの設定

# %%
#ハイパーパラメータの設定

#最大エポック数
max_epochs = 2

#ノード数
units = 11

# シード値の準備
seeds = [50,51,52,53]


# 学習バッチサイズ
batch_size=64


# 学習条件のパラメータ
threshold_avg = 0.25
threshold_max = 0.41

# 何期間連続して予測を行うか
num = 1

#　初期化回数
num_retry = 4

#　詳細な出力
detail_log = True

#学習率
learning_rate = 1e-3

#トレーニング開始日
train_start = "2016/7/01 00:00:00"

#テスト開始日
test_start = "2018/7/01 00:00:00"



params = {"max_epochs":max_epochs, "unit":units, "seeds":seeds, "units":units, "threshold_avg":threshold_avg, 
          "threshold_max":threshold_max, "batch_size":batch_size,"num":num, "train_start" : train_start, "test_start" : test_start,
    "num_retry": num_retry, "detail_log":detail_log, "learning_rate":learning_rate}

# %%
#実験の実行及び結果の格納
abnormal_scores, thresholds = model_basic.result(data_ex , params)
# Out:
# =====================================================================================
# 1回目の期間のモデル
# 該当期間の確認
# はじまり(train)2016/6/01 00:00:00
# 終わり(train)2018/6/01 00:00:00
# はじまり(test)2018/6/01 00:00:00
# 終わり(test)2018/7/01 00:00:00
# 1回目の期間のモデル作成開始
# 1回目の期間のトレーニングデータ数:17161
#
# ===== unit2=10 の探索開始 =====
# unit2=10 に対するunit13探索開始点: 22
# ----------------------------------------------------------------------
# [unit10探索] unit13=22, unit2=10
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=22, units_2=10, 試行回数=1, seed値 = 50
# モデルは最大エポック数まで収束条件に達しませんでした。収束条件を満たさず終了しました。
# トレーニングデータの再構成誤差（平均）：0.28404328034138576
# トレーニングデータの再構成誤差（最大値）：0.39791222432978457
# 閾値を下回りませんでした1回目
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=22, units_2=10, 試行回数=2, seed値 = 51
# モデルは最大エポック数まで収束条件に達しませんでした。収束条件を満たさず終了しました。
# トレーニングデータの再構成誤差（平均）：0.2809467144961725
# トレーニングデータの再構成誤差（最大値）：0.3952480873179915
# 閾値を下回りませんでした2回目
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=22, units_2=10, 試行回数=3, seed値 = 52
# モデルは最大エポック数まで収束条件に達しませんでした。収束条件を満たさず終了しました。
# トレーニングデータの再構成誤差（平均）：0.2787988759644235
# トレーニングデータの再構成誤差（最大値）：0.4097985407006511
# 閾値を下回りませんでした3回目
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=22, units_2=10, 試行回数=4, seed値 = 53
# モデルは最大エポック数まで収束条件に達しませんでした。収束条件を満たさず終了しました。
# トレーニングデータの再構成誤差（平均）：0.2733599207948551
# トレーニングデータの再構成誤差（最大値）：0.4052312570107836
# 閾値を下回りませんでした4回目
# ------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------
# [unit10探索] unit13=44, unit2=10
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=44, units_2=10, 試行回数=1, seed値 = 50
# ✅ Early stopping at epoch 2: Avg=0.231111, Max=0.367927 < thresholds.
# モデルは最大エポック数まで収束条件に達しませんでした。収束条件を満たさず終了しました。
# トレーニングデータの再構成誤差（平均）：0.23288424156723297
# トレーニングデータの再構成誤差（最大値）：0.3679267907784674
# 閾値を下回るモデルを発見: units_1_3=44, units_2=10
# 🎉 最良モデル更新: unit13=44, unit2=10, 合計=98
#
# [探索の開始] unit13=33, unit2=10
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=33, units_2=10, 試行回数=1, seed値 = 50
# モデルは最大エポック数まで収束条件に達しませんでした。収束条件を満たさず終了しました。
# トレーニングデータの再構成誤差（平均）：0.26711225629397506
# トレーニングデータの再構成誤差（最大値）：0.39838049179503027
# 閾値を下回りませんでした1回目
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=33, units_2=10, 試行回数=2, seed値 = 51
# モデルは最大エポック数まで収束条件に達しませんでした。収束条件を満たさず終了しました。
# トレーニングデータの再構成誤差（平均）：0.26386185279026675
# トレーニングデータの再構成誤差（最大値）：0.37699186946087726
# 閾値を下回りませんでした2回目
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=33, units_2=10, 試行回数=3, seed値 = 52
# モデルは最大エポック数まで収束条件に達しませんでした。収束条件を満たさず終了しました。
# トレーニングデータの再構成誤差（平均）：0.2675339454421604
# トレーニングデータの再構成誤差（最大値）：0.39287790799386446
# 閾値を下回りませんでした3回目
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=33, units_2=10, 試行回数=4, seed値 = 53
# モデルは最大エポック数まで収束条件に達しませんでした。収束条件を満たさず終了しました。
# トレーニングデータの再構成誤差（平均）：0.2722009601591026
# トレーニングデータの再構成誤差（最大値）：0.3946729076001387
# 閾値を下回りませんでした4回目
# ------------------------------------------------------------------------------------------
# 再帰的に探索をします
# ===========================================================================================
# 再帰探索に入ります
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=38, units_2=10, 試行回数=1, seed値 = 50
# モデルは最大エポック数まで収束条件に達しませんでした。収束条件を満たさず終了しました。
# トレーニングデータの再構成誤差（平均）：0.2576210770590648
# トレーニングデータの再構成誤差（最大値）：0.390741986127636
# 閾値を下回りませんでした1回目
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=38, units_2=10, 試行回数=2, seed値 = 51
# ✅ Early stopping at epoch 2: Avg=0.249435, Max=0.393838 < thresholds.
# モデルは最大エポック数まで収束条件に達しませんでした。収束条件を満たさず終了しました。
# トレーニングデータの再構成誤差（平均）：0.2509347579816659
# トレーニングデータの再構成誤差（最大値）：0.3938375281052133
# 閾値を下回るモデルを発見: units_1_3=38, units_2=10
# ✅ 閾値を下回りました: unit13=38
# ===========================================================================================
# 再帰探索に入ります
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=35, units_2=10, 試行回数=1, seed値 = 50
# モデルは最大エポック数まで収束条件に達しませんでした。収束条件を満たさず終了しました。
# トレーニングデータの再構成誤差（平均）：0.25963840732602383
# トレーニングデータの再構成誤差（最大値）：0.40003101534742436
# 閾値を下回りませんでした1回目
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=35, units_2=10, 試行回数=2, seed値 = 51
# モデルは最大エポック数まで収束条件に達しませんでした。収束条件を満たさず終了しました。
# トレーニングデータの再構成誤差（平均）：0.26204879068477704
# トレーニングデータの再構成誤差（最大値）：0.38728030276281744
# 閾値を下回りませんでした2回目
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=35, units_2=10, 試行回数=3, seed値 = 52
# モデルは最大エポック数まで収束条件に達しませんでした。収束条件を満たさず終了しました。
# トレーニングデータの再構成誤差（平均）：0.2678554578900674
# トレーニングデータの再構成誤差（最大値）：0.4008057205387629
# 閾値を下回りませんでした3回目
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=35, units_2=10, 試行回数=4, seed値 = 53
# モデルは最大エポック数まで収束条件に達しませんでした。収束条件を満たさず終了しました。
# トレーニングデータの再構成誤差（平均）：0.26645434183742495
# トレーニングデータの再構成誤差（最大値）：0.40055678771322417
# 閾値を下回りませんでした4回目
# ------------------------------------------------------------------------------------------
# ❌ 閾値を下回りませんでした: unit13=35
# ===========================================================================================
# 再帰探索に入ります
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=36, units_2=10, 試行回数=1, seed値 = 50
# モデルは最大エポック数まで収束条件に達しませんでした。収束条件を満たさず終了しました。
# トレーニングデータの再構成誤差（平均）：0.2629441567996871
# トレーニングデータの再構成誤差（最大値）：0.3922820222067249
# 閾値を下回りませんでした1回目
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=36, units_2=10, 試行回数=2, seed値 = 51
# モデルは最大エポック数まで収束条件に達しませんでした。収束条件を満たさず終了しました。
# トレーニングデータの再構成誤差（平均）：0.271555393393328
# トレーニングデータの再構成誤差（最大値）：0.3983381133957783
# 閾値を下回りませんでした2回目
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=36, units_2=10, 試行回数=3, seed値 = 52
# モデルは最大エポック数まで収束条件に達しませんでした。収束条件を満たさず終了しました。
# トレーニングデータの再構成誤差（平均）：0.27167087197744666
# トレーニングデータの再構成誤差（最大値）：0.397599638484591
# 閾値を下回りませんでした3回目
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=36, units_2=10, 試行回数=4, seed値 = 53
# モデルは最大エポック数まで収束条件に達しませんでした。収束条件を満たさず終了しました。
# トレーニングデータの再構成誤差（平均）：0.2538938484410234
# トレーニングデータの再構成誤差（最大値）：0.40650449930148885
# 閾値を下回りませんでした4回目
# ------------------------------------------------------------------------------------------
# ❌ 閾値を下回りませんでした: unit13=36
# ===========================================================================================
# 再帰探索に入ります
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=37, units_2=10, 試行回数=1, seed値 = 50
# モデルは最大エポック数まで収束条件に達しませんでした。収束条件を満たさず終了しました。
# トレーニングデータの再構成誤差（平均）：0.2524885415709292
# トレーニングデータの再構成誤差（最大値）：0.3776260366831245
# 閾値を下回りませんでした1回目
# -----------------------------------------------------------------------------------------
# 探索中: units_1_3=37, units_2=10, 試行回数=2, seed値 = 51
# モデルは最大エポック数まで収束条件に達しませんでした。収束条件を満たさず終了しました。
